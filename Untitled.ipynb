# %%
from classes import *
import numpy as np, random, operator, pandas as pd, matplotlib.pyplot as plt

# %%
class Fitness:
    def __init__(self, route):
        self.route = route
        self.distance = 0
        self.fitness= 0.0
    
    def routeDistance(self):
        if self.distance ==0:
            pathDistance = 0
            for i in range(0, len(self.route)):
                fromCity = self.route[i]
                toCity = None
                if i + 1 < len(self.route):
                    toCity = self.route[i + 1]
                else:
                    toCity = self.route[0]
                pathDistance += fromCity.distance(toCity)
            self.distance = pathDistance
        return self.distance
    
    def routeFitness(self):
        if self.fitness == 0:
            self.fitness = 1 / float(self.routeDistance())
        return self.fitness

# %%
def createRoute(cityList):
    route = random.sample(cityList, len(cityList))
    return route

# %%
def initialPopulation(popSize, cityList):
    population = []

    for i in range(0, popSize):
        population.append(createRoute(cityList))
    return population

# %%
def rankRoutes(population):
    fitnessResults = {}
    for i in range(0,len(population)):
        fitnessResults[i] = Fitness(population[i]).routeFitness()
    return sorted(fitnessResults.items(), key = operator.itemgetter(1), reverse = True)

# %%
def selection(popRanked, eliteSize):
    selectionResults = []
    df = pd.DataFrame(np.array(popRanked), columns=["Index","Fitness"])
    df['cum_sum'] = df.Fitness.cumsum()
    df['cum_perc'] = 100*df.cum_sum/df.Fitness.sum()
    
    for i in range(0, eliteSize):
        selectionResults.append(popRanked[i][0])
    for i in range(0, len(popRanked) - eliteSize):
        pick = 100*random.random()
        for i in range(0, len(popRanked)):
            if pick <= df.iat[i,3]:
                selectionResults.append(popRanked[i][0])
                break
    return selectionResults

# %%
def matingPool(population, selectionResults):
    matingpool = []
    for i in range(0, len(selectionResults)):
        index = selectionResults[i]
        matingpool.append(population[index])
    return matingpool

# %%
def breed(parent1, parent2):
    child = []
    childP1 = []
    childP2 = []
    
    geneA = int(random.random() * len(parent1))
    geneB = int(random.random() * len(parent1))
    
    startGene = min(geneA, geneB)
    endGene = max(geneA, geneB)

    for i in range(startGene, endGene):
        childP1.append(parent1[i])
        
    childP2 = [item for item in parent2 if item not in childP1]

    child = childP1 + childP2
    return child

# %%
def breedPopulation(matingpool, eliteSize):
    children = []
    length = len(matingpool) - eliteSize
    pool = random.sample(matingpool, len(matingpool))

    for i in range(0,eliteSize):
        children.append(matingpool[i])
    
    for i in range(0, length):
        child = breed(pool[i], pool[len(matingpool)-i-1])
        children.append(child)
    return children

# %%
def mutate(individual, mutationRate):
    for swapped in range(len(individual)):
        if(random.random() < mutationRate):
            swapWith = int(random.random() * len(individual))
            
            city1 = individual[swapped]
            city2 = individual[swapWith]
            
            individual[swapped] = city2
            individual[swapWith] = city1
    return individual

# %%
def mutatePopulation(population, mutationRate):
    mutatedPop = []
    
    for ind in range(0, len(population)):
        mutatedInd = mutate(population[ind], mutationRate)
        mutatedPop.append(mutatedInd)
    return mutatedPop

# %%
def nextGeneration(currentGen, eliteSize, mutationRate):
    popRanked = rankRoutes(currentGen)
    selectionResults = selection(popRanked, eliteSize)
    matingpool = matingPool(currentGen, selectionResults)
    children = breedPopulation(matingpool, eliteSize)
    nextGeneration = mutatePopulation(children, mutationRate)
    return nextGeneration

# %%
def geneticAlgorithm(population, popSize, eliteSize, mutationRate, generations):
    pop = initialPopulation(popSize, population)
    print("Initial distance: " + str(1 / rankRoutes(pop)[0][1]))
    
    for i in range(0, generations):
        if (i%10 == 0):
            print("-- iteration %d -- " % i)
        pop = nextGeneration(pop, eliteSize, mutationRate)
    
    print("Final distance: " + str(1 / rankRoutes(pop)[0][1]))
    bestRouteIndex = rankRoutes(pop)[0][0]
    bestRoute = pop[bestRouteIndex]
    return bestRoute

# %%
import joblib as jb

def write_Slideshow_to_file(slideshow, output_name = "sexybaby.txt"):
    with open(output_name, "w") as file:
        file.write("{}\n".format(len(slideshow.slides)))
        for slide in slideshow.slides:
            ID = slide.id
            if len(ID) == 1:
                file.write("{}\n".format(ID[0]))
            else:
                file.write("{} {}\n".format(ID[0], ID[1]))

#Create a set of slides following the rationale of the groupment by biggest tags
def get_horizontals_from_collection(collection, groupby="average", filename=""):
    
    #Create a set of vertical and horizontal pictures
    null_photo = Photo(orientation="", tags=[])
    collection_V = []
    collection_H = []

    for photo in collection:
        if photo.orientation == "V":
            collection_V.append(photo)
        else:
            collection_H.append(photo)

    ##### Sort pictures in place by number of tags
    collection_V.sort(key=lambda photo: len(photo.tags), reverse=True)
    collection_H.sort(key=lambda photo: len(photo.tags), reverse=True)
    
    ##### generate slides
    m = len(collection_V)
    slides_fromVerticals = []
    index = 0
    if groupby == "2by2":
        while index < m:
            slides_fromVerticals.append(Slide([collection_V[index], collection_V[index+1]]))
            index += 2
    else:
        if m %2 == 1:
            collection_V = collection_V[1:]
        for i in range(m//2):
            slides_fromVerticals.append(Slide([collection_V[m - 1 - i], collection_V[i]]))
    
    slides_fromHorizontals = [Slide([photo]) for photo in collection_H]
    jb.dump(collection_V, "collection_V_{}.joblib".format(filename))
    jb.dump(collection_H, "collection_H_{}.joblib".format(filename))
    jb.dump(slides_fromVerticals, "slides_fromVerticals_{}_{}.joblib".format(groupby,filename))
    jb.dump(slides_fromHorizontals, "slides_fromHorizontals_{}.joblib".format(filename))
    return slides_fromVerticals, slides_fromHorizontals

def get_horizontals_from_file(filename, groupby="average"):
    return jb.load("slides_fromVerticals_{}_{}.joblib".format(groupby, filename)), jb.load("slides_fromHorizontals_{}.joblib".format(filename))

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("c_memorable_moments.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals

# %%
a = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=500)
# Out:
# Initial distance: -166.0
# 0 th distance: -166.0
# 10 th distance: -183.0
# 20 th distance: -210.99999999999997
# 30 th distance: -216.0
# 40 th distance: -223.0
# 50 th distance: -226.99999999999997
# 60 th distance: -220.0
# 70 th distance: -220.99999999999997
# 80 th distance: -225.0
# 90 th distance: -222.0
# 100 th distance: -226.0
# 110 th distance: -230.0
# 120 th distance: -226.0
# 130 th distance: -229.0
# 140 th distance: -226.0
# 150 th distance: -226.99999999999997
# 160 th distance: -224.0
# 170 th distance: -236.0
# 180 th distance: -236.0
# 190 th distance: -233.0
# 200 th distance: -232.0
# 210 th distance: -229.0
# 220 th distance: -230.0
# 230 th distance: -220.0
# 240 th distance: -233.99999999999997
# 250 th distance: -226.99999999999997
# 260 th distance: -226.0
# 270 th distance: -237.00000000000003
# 280 th distance: -236.0
# 290 th distance: -225.0
# 300 th distance: -225.0
# 310 th distance: -232.0
# 320 th distance: -236.0
# 330 th distance: -226.99999999999997
# 340 th distance: -226.99999999999997
# 350 th distance: -228.0
# 360 th distance: -226.0
# 370 th distance: -232.0
# 380 th distance: -232.0
# 390 th distance: -226.99999999999997
# 400 th distance: -225.0
# 410 th distance: -225.0
# 420 th distance: -224.0
# 430 th distance: -230.0
# 440 th distance: -228.0
# 450 th distance: -233.0
# 460 th distance: -228.0
# 470 th distance: -226.0
# 480 th distance: -231.0
# 490 th distance: -231.0
# Final distance: -226.0

# %%
a
# Out:
# [id= (309,), tags= {'tz1', 'tbv', 'tpc1', 't2z1', 'tvs1', 'tjz', 'td22', 't221'},
#  id= (676, 318), tags= {'t8l', 'tdn', 'tqk1', 'tft', 'tgg', 'td', 'tpr1', 't1', 'tbl', 'tmk', 't7j1', 't741', 'tm4', 't6d2', 'tt72', 't1g1', 't1z', 'tx42', 'th1'},
#  id= (374,), tags= {'t492', 't3c1', 'tfz1', 't8l1', 'tm8', 't6'},
#  id= (77,), tags= {'tr92', 't3n', 'tdb2', 't76', 'tz42', 't512', 'tr51'},
#  id= (314,), tags= {'t2m1', 'tjl', 'tv81', 'tb32', 'tz91', 'tx62', 'tn42', 'ttb2', 't011', 'th1', 'tr2', 'tvk', 't7p1', 'tm'},
#  id= (166,), tags= {'tk31', 't0j1', 't002', 'tkr1', 't052', 'tb12', 't3t', 't8c1', 't8j', 't39', 't2x1', 'td72'},
#  id= (102, 805), tags= {'td41', 't3k', 't8t1', 't4d2', 't161', 'tmj1', 't002', 't9p1', 'tf3', 'th42', 'tss1', 't33', 'tn4', 't39', 't471', 'tr91', 'tm42', 't0l1', 't7n'},
#  id= (11,), tags= {'t991', 't0t1', 'tp72', 'tnl', 'twn1', 'ttx1', 't4q1', 'tkn', 'th61', 't7n1', 'tkc2', 'tt'},
#  id= (209,), tags= {'tl72', 'thg1', 't181', 'tmf', 'tvr', 'tt', 'tl51'},
#  id= (720, 270), tags= {'tnl1', 'tpb2', 't4d1', 't8s1', 'tqv', 't6m', 't5w1', 't7b', 'tmf', 'tz', 'tcd1', 'tgt1', 'tld1', 'tbg', 't911', 'ttf', 'tzw', 'thg1', 't0g1'},
#  id= (586, 461), tags= {'tzg', 'tjs1', 'tts1', 't5c2', 'tsw', 'tm52', 'tnm', 'trs1', 'tfr1', 'tbb', 't4d2', 't3r1', 'tjp1', 'tbv', 'thn', 'tf21', 't9x1', 't5v1'},
#  id= (411,), tags= {'t5s', 't572', 'tn81', 't882', 'tpn1', 't88', 'tjh', 't802', 'twj1', 't162', 'tm21', 'tl72'},
#  id= (690,), tags= {'t3r1', 't3d2', 'tg61', 't032', 'td51', 'thr', 'tp4'},
#  id= (56,), tags= {'t8t1', 'tp12', 'tdg1', 'tsq1'},
#  id= (283,), tags= {'tt6', 't361', 'tbv', 'tqv', 'tfr1', 't4w', 't552', 't5v1'},
#  id= (541,), tags= {'t8b', 'tnv1', 'tg3', 't672', 't6j', 'tnl', 't1r', 'tk61', 'tms', 'tjl', 'trf', 't6h'},
#  id= (222,), tags= {'tvb', 'tbt', 'tdc', 'trm', 't032', 't8b1', 't902', 'tf2'},
#  id= (41,), tags= {'tr92', 'tqq', 'tz91', 't1g', 'tgb2', 'tqq1', 'tq31', 'trk', 't531', 't422'},
#  id= (276,), tags= {'trp', 't55', 'thc', 't771', 'th01'},
#  id= (64, 960), tags= {'t002', 'tfb1', 't141', 't4x', 't011', 'tl41', 't561', 'tf2', 't391', 't512', 'tk22', 'tf21', 'td7', 'trk', 't0m1', 't6d', 'twj1', 't181', 'tzt1'},
#  id= (874,), tags= {'t4r', 'tq52', 'twx1', 't91', 't0g1', 'twz', 'tm81'},
#  id= (29,), tags= {'t8f1', 'tr21', 'txf1', 'tdn', 'ts92', 'tgb2', 'tbb2', 'th1'},
#  id= (962,), tags= {'t481', 't34', 'tt11', 't672', 't62', 'ttv1', 'tw31', 'tq52', 't471', 'trt', 'tls1', 'tzt1', 'tjt', 'tt62'},
#  id= (275,), tags= {'tjs1', 'tzg', 't3m', 'tjj', 'tht1', 't242', 'tqq', 't882', 'tjr1', 't9d1', 'tn9', 'tvr', 'tjt'},
#  id= (527, 522), tags= {'ttc', 't7l', 't841', 'tlc', 'tfb', 'trc1', 'tq81', 't39', 't1', 'tx51', 'tfj', 'tmf', 'tzn', 'ttl', 't6d2', 'tt11', 't321', 'tf52', 'tbw'},
#  id= (516,), tags= {'t342', 'tzn', 't4t1', 'tld1', 'tqz1', 'tq81', 't06', 'tw82', 'tl6', 'td62'},
#  id= (265,), tags= {'ttn1', 'tgj1', 't34', 'tld1', 'tgq', 't351', 't4c2', 'th52', 'tl6', 'tvk', 't5w1'},
#  id= (996, 835), tags= {'tw11', 'tx82', 'tfz1', 'txw1', 't1s', 'tft', 't351', 'tf12', 't0w1', 'ttb2', 'tlb', 'tv1', 't8b1', 'tb5', 'trg1', 'thk', 'thb1', 'tmn', 't9d', 'tgp1'},
#  id= (669,), tags= {'tgc', 't812', 'tbj', 'tss1', 't752', 't4r', 'tqv', 't88', 't7s'},
#  id= (823,), tags= {'tv81', 'tjj', 't34', 't5l1', 'tld1', 'tkc1', 'tnl'},
#  id= (439,), tags= {'tl72', 'tzb2', 'tzr', 'tg71', 'tq52', 'tb8', 't692', 'tqc'},
#  id= (651, 227), tags= {'tmj1', 't412', 't8p', 't3c', 'tqb2', 'tnv1', 'tx2', 'tn81', 't861', 'tcf', 'tw3', 'trt1', 'tc22', 't8q', 'tk6', 't3w', 't001', 'tg41', 'tr42'},
#  id= (865,), tags= {'tgc', 'trt', 't242', 'tss1', 't8', 't49', 't3d', 't181', 't9g'},
#  id= (507,), tags= {'td32', 'tcn1', 'tzg', 'tbn1', 'trk', 'tgx', 'tph', 'tz22', 'tt4', 't4x1', 't2d1'},
#  id= (549,), tags= {'ttc', 't242', 't992', 'tm81', 'tq', 'tds', 'tkg', 't1c2', 'tm42', 'txg', 'td4'},
#  id= (326,), tags= {'t43', 'tfr1', 'tlr1', 't792', 'tmn', 'tvb1'},
#  id= (616,), tags= {'t9c', 't6r1', 'ts92', 'twt', 't952', 'tk6', 't5p', 'ttb2', 'tw12', 't4n1', 't7d', 'tr42'},
#  id= (272,), tags= {'t8t1', 'tht1', 'tz91', 'tss1', 't881', 't7p', 'ttb2', 't221', 't561', 't4x1'},
#  id= (729,), tags= {'tpb2', 't8z1', 't242', 't2c2', 'th7', 'tpb', 't031', 't032', 't0g1', 'tb7', 'tdp', 'tnq1'},
#  id= (279,), tags= {'tcn1', 'tg11', 'tt11', 'tst', 't6w', 'tzl', 'tzw', 'tpd', 'tr51'},
#  id= (560,), tags= {'tw11', 't1w', 'tj71', 't9q1', 'tkd', 't762', 't8b1', 'tv22'},
#  id= (870,), tags= {'t2w', 'txq', 't76', 't4g1', 'tbp1', 'tx8', 'tqt1', 'trz', 't4m1', 't701'},
#  id= (829,), tags= {'tn92', 'tr2', 'tjr1', 'thc', 't221', 'tvj'},
#  id= (398, 471), tags= {'t8t1', 'tp41', 't622', 't3b', 't2x1', 't7d', 't3x', 't5w1', 't1t', 'trw1', 't3l1', 'tzw', 'tl02', 'tz4', 't001', 't6h', 'tdt', 't861', 'tl51'},
#  id= (688,), tags= {'t3q1', 't9k', 't33', 't131', 'tk22', 'tvs1', 't3p', 'tt9', 'tc9', 'tc8', 't3x1'},
#  id= (764,), tags= {'tqv', 'tcj1', 'tl31', 'thh1', 'tqc', 'tf52'},
#  id= (192,), tags= {'t98', 't02', 'thk1', 't6c', 't882'},
#  id= (783, 108), tags= {'tkb1', 't922', 'twp1', 't4d1', 'tz62', 'tjm1', 'tjx1', 'ttm', 't6n1', 't6c', 't4g1', 'tg6', 'thn', 'tt82', 'tms', 'tjg1', 't74', 'tl72', 't0m'},
#  id= (316,), tags= {'t4c1', 'tpd', 'tbv', 't2t', 'tdn1', 'tnd1'},
#  id= (539,), tags= {'tb7', 't91', 't4t1', 'tc51', 'tpr1', 'tbx1', 't33', 'tb8', 'tp5', 't4d2', 'tm91', 't291'},
#  id= (317,), tags= {'tdv', 'tqk', 'tk5', 't9x1', 'tqk1'},
#  id= (73,), tags= {'tn3', 't5l', 'tz9', 'tvh', 't6x', 't7d', 'tpx', 't221', 'tnv'},
#  id= (565,), tags= {'t5f1', 't1q', 't882', 't012', 'tpd1', 'tz51', 't1', 't7n1'},
#  id= (100,), tags= {'txp1', 'tcf', 'tz42', 'tv', 'tj41', 'tq91', 'tvk', 'tdd1'},
#  id= (596,), tags= {'tz6', 'tqs', 't7d1', 't6z', 't672', 'thb1', 'tl6', 'th61', 'tf2'},
#  id= (154,), tags= {'tj91', 't4q1', 'tzz', 't34', 'tqf', 'thk1', 'tjr1', 'tpn1', 'tn22', 't912', 'ttm', 'txz', 't3h', 'tcn'},
#  id= (756,), tags= {'tj91', 'tts1', 't7j1', 't33', 'tc5', 'tk51', 't2d2', 'tns', 't7c2', 'ttb1', 'th8', 'tmf'},
#  id= (954,), tags= {'tg42', 'ttg', 't3b1', 'trw', 'trz1', 'tjj1', 'tnr', 'tcg1', 'tx91', 'tm31', 't7p1', 't4x1', 't291'},
#  id= (36, 973), tags= {'ttw1', 't6z', 't412', 'trq', 't242', 'tck', 't8h1', 'tqz1', 'tst', 'tvh', 'tpn1', 'tpb', 'tv61', 'twn1', 'tdp1', 't471', 'tlg1', 't261', 'tm9'},
#  id= (922,), tags= {'t7p1', 't242', 'tpb', 't3w', 'tsm1', 'thh1', 'tnj', 'tf91', 'tlz1'},
#  id= (70,), tags= {'tjs1', 't19', 'tpc', 't34', 't882', 'tg71', 'tvk', 't4q1', 'tgj', 't5r1', 'tkk1'},
#  id= (811,), tags= {'tnk', 'tzd1', 'tlb1', 't4r', 'td7', 't9k1', 'thg1', 't682'},
#  id= (235,), tags= {'tgc', 'tjl', 't38', 'ttc1', 'tlb1', 'ts7'},
#  id= (96, 857), tags= {'ttw1', 't0n', 'ttk1', 'tvc1', 'tvb', 'tzn', 't572', 'tn81', 't7v', 'tpn1', 't371', 'ts82', 't45', 'tgk', 'tdp1', 'ttc1', 'tmf', 'tvj', 'tv9'},
#  id= (203,), tags= {'tv7', 'twg1', 'tgp', 't131', 't332', 'tz61', 't7w', 't7n1', 'tv9'},
#  id= (122,), tags= {'tpz', 'tzk1', 'tf1', 't3q'},
#  id= (442,), tags= {'tqn', 'txk1', 'txf1', 't4d1', 't881', 'tg71', 'tf21', 't87', 't8w'},
#  id= (933,), tags= {'tw11', 'tgt1', 'tkz1', 't7v', 't3p', 't0w1', 'tq81', 'tng'},
#  id= (969,), tags= {'t361', 'tgx1', 'tf71', 't4t1', 'tf22', 't622', 'tz91', 'tpw', 't7h', 'thn', 't471', 'th02', 't651', 't6c'},
#  id= (420,), tags= {'tcw1', 'txk1', 'tls', 'thg1', 't0l1'},
#  id= (642,), tags= {'tf81', 'thk1', 'tkt', 'ts92', 't66'},
#  id= (680,), tags= {'tqx', 't8t1', 't4d2', 'tf42', 'ts92', 'tl5', 'tt'},
#  id= (450,), tags= {'tzk1', 'tf22', 't3q1', 'tn12', 'thz', 't532', 'tpd', 'thh1', 't0x1', 't181', 'tmn', 't062'},
#  id= (399, 670), tags= {'tn31', 't0j1', 'tlr1', 'tpb2', 'tlk', 'tz9', 'thb1', 'ts4', 't4d2', 't79', 't7n1', 't19', 'tcc', 'tr1', 'thp1', 'tf42', 'thc', 'th8', 'td62'},
#  id= (782, 195), tags= {'tcn1', 't002', 'txc2', 'trn', 't881', 'tz31', 'tgn', 't092', 'tp5', 't6h1', 'tr51', 't7p1', 't8w1', 't3g', 't5c', 'tft1', 'tfc', 't9h', 't0d2'},
#  id= (766,), tags= {'tt31', 'tts1', 'ths', 'tq91', 'tm81'},
#  id= (709, 330), tags= {'tk82', 'tqx', 'tjv1', 't391', 'tks', 'tw11', 't1b1', 'tf82', 't242', 'th42', 'tst', 'tsr1', 't091', 'tbm', 't7d', 'tl6', 'td01', 't621', 't861'},
#  id= (700, 256), tags= {'thj', 'tdz1', 't672', 'ttp', 'tqv', 't05', 't7d1', 't36', 't362', 'tx1', 't361', 't3m', 't3t', 'ttm1', 'tpc2', 'tq91', 't5r1', 'tx4', 't832'},
#  id= (671,), tags= {'t711', 'tmj1', 't8f', 't3q', 't3v', 'thv', 't7k1', 'tvl1', 'tn22', 't7d1'},
#  id= (731, 236), tags= {'t862', 'td81', 't8t1', 't161', 'twb2', 'tqb2', 'tsw', 'trb2', 'tfg1', 'tgn', 'tws1', 't7q1', 't452', 't8n', 'tsh', 'tk3', 'tv1', 'thc', 't82'},
#  id= (324, 521), tags= {'t4t1', 't2t', 'tdc1', 't6', 'tq52', 'ttz', 'tx52', 'tpr1', 'tm51', 't6t', 't1w', 'tt72', 't961', 'trm', 't47', 't181', 't621', 'tg31', 't4x1'},
#  id= (898, 105), tags= {'tjl', 'tqb2', 't76', 'tzl', 't4x', 't7d1', 'tb7', 'tnd', 't3m', 'tz02', 'tg62', 't6w', 't882', 't4r', 't41', 'tt9', 'tf12', 't74', 't9h'},
#  id= (160, 695), tags= {'td41', 'tmj1', 'tjs1', 't412', 'tpg1', 'tp82', 't7d1', 't1w', 'tm6', 'tbm1', 't5v1', 'tt9', 'tq01', 't381', 't8b1', 'ttz1', 't1v1', 't982', 't19'},
#  id= (850,), tags= {'t4t1', 'tqq', 'tvh', 't74', 'ttz1', 'tvr', 'tkc', 'tx51'},
#  id= (43,), tags= {'trs1', 'td7', 'tkr1', 't9z1', 'tzk1'},
#  id= (959,), tags= {'tzw', 'tsw', 't6w1', 't8n', 'tv32'},
#  id= (141,), tags= {'txf1', 't3q', 'tdp1', 't9v', 'tdp'},
#  id= (585, 273), tags= {'t711', 'tzg', 'tw11', 'tcc', 't3b1', 't8c2', 't21', 't6n', 't141', 'tft', 'tv32', 'ttd', 'tj82', 't532', 't0g1', 'tv02', 'tnr1', 'tt42', 'tvc1'},
#  id= (427, 409), tags= {'t161', 'tx71', 't4t1', 't242', 'tsw', 'tph1', 't532', 'tdp', 't6x', 't8w', 't19', 't3r1', 'trl1', 't342', 't55', 'tp21', 'tv1', 'tq91', 't4m1'},
#  id= (71, 760), tags= {'tgc', 'tqx', 'tnb1', 'tgt1', 't002', 'tdv', 't3p1', 'tsr', 'tkc1', 'tpn1', 't3t', 'tww', 'tfr1', 'tbm', 't001', 'th8', 't712', 'thn1', 'tmf'},
#  id= (58, 40), tags= {'tcl1', 'ts21', 't6x1', 'tq52', 'tsf', 't84', 'tdn1', 'tr51', 'tq62', 'td32', 'tx1', 'tv7', 'tfx', 'tsp1', 'tbv', 't0s', 't6h', 'tlz1'},
#  id= (140,), tags= {'t991', 'tkt1', 'tm52', 'tr5', 'tfw', 't9d1', 't1s', 't2r1'},
#  id= (257, 770), tags= {'t3k', 't8l', 'tsq', 't3c', 'tk42', 't242', 'tz91', 't881', 'tk31', 't63', 'tz02', 't6t', 'tkt1', 'tpc1', 'tlq', 'tvf', 'tw8', 'tv1', 'tl72'},
#  id= (789, 285), tags= {'t3r1', 'tlf1', 'tvc2', 't242', 't3q', 'tld1', 'tss1', 'tjr', 'tvs1', 't612', 'twd1', 'tkc1', 't2b', 'tx', 't7k1', 't1s', 't0s', 't782', 'tnf'},
#  id= (707,), tags= {'tsq', 'tr61', 'tjb1', 't281', 'tcc', 'tdb2', 'tv1', 'ttm', 'tvk', 't78'},
#  id= (291, 740), tags= {'ts42', 'tdb', 't8l', 'tsv1', 't21', 't141', 't171', 'tdn1', 'tvs', 'tx92', 'tpg1', 't1w', 'tt11', 'thb', 'tqp1', 'tw8', 't0r', 'tnj', 't4x1'},
#  id= (202,), tags= {'t412', 'tkf1', 'tbd1', 'tpc', 't881', 'tt8', 'tv32', 'tz82', 'tw', 't3l', 'tvc1'},
#  id= (631, 424), tags= {'twz', 't161', 'tqb2', 'tjb1', 'tbp1', 'tr82', 't9z1', 't7q1', 'tl72', 'tbv', 'tlh1', 'tz61', 'tbv1', 'td7', 'tqj', 't0g1', 't1k1', 'tq91', 't0l1'},
#  id= (509,), tags= {'t8t1', 'tcc', 'thn', 'tm02', 'tdb2', 'trj', 'td02', 'tc21', 't471', 'tzx', 't1', 'th11'},
#  id= (191, 817), tags= {'t942', 't4d1', 't8h1', 't672', 'tzl', 'tr42', 'th11', 'th42', 'tc81', 't432', 't33', 't332', 'tnl', 'tl9', 'tn12', 'tl72', 'tvk', 't0l1', 't4x1'},
#  id= (584,), tags= {'t8t1', 't161', 't3p1', 'tp41', 't8h1', 't532', 't0w1', 't692', 't5c1', 't1'},
#  id= (139,), tags= {'t6z', 't991', 'tht1', 'tzn', 'tq41', 'tfc2', 'tk9', 'tv21', 'tzf1', 'tl', 't4w', 'tzt1'},
#  id= (884, 150), tags= {'twg1', 't242', 'tsp', 'tm81', 'tg71', 't59', 't7g', 't1', 't212', 't872', 'tpc', 't9', 'tq01', 't9d1', 'tf12', 'tz82', 'tb02', 'tz11', 'tjw1'},
#  id= (280, 625), tags= {'t2m1', 'td11', 'tq02', 't3q1', 'tsq1', 'tt72', 't28', 'tbx1', 'td31', 'tm81', 't13', 'tjm1', 't6g1', 't0f1', 't6v', 'tpr1', 't7p1', 'ts3', 'tkc'},
#  id= (902, 88), tags= {'t0j1', 'tlr1', 't81', 't4d', 'tnp1', 't971', 'trt', 't212', 'tqq', 'th42', 't351', 'tst1', 'tk22', 'tv61', 't2x', 'tpt1', 'trj1', 't932', 't12'},
#  id= (176,), tags= {'twg1', 'tcn1', 't4x', 't6r', 't5w1', 'tx51'},
#  id= (164,), tags= {'tc61', 'tjq1', 't4x', 'twz', 't21', 'tj22'},
#  id= (824, 130), tags= {'t991', 'txp', 'twq1', 'tn4', 't7q1', 't5', 't7g', 'tv9', 'tr02', 't4g', 'tpc1', 'tst1', 'tt82', 't89', 'tq01', 'tz82', 'ts71', 'tzt1', 't11'},
#  id= (574,), tags= {'tbs1', 'tww', 'tk71', 'tpc', 'tm42', 'tpq1', 'tz61'},
#  id= (225,), tags= {'t38', 'tsq1', 't9k', 'tpb', 'tww', 'tlm', 'trt', 'trr', 'tsw1'},
#  id= (602,), tags= {'tgb2', 'tvf', 't7m', 'tf42', 't6r'},
#  id= (538,), tags= {'tpw1', 'tf81', 'tt11', 'tfb1', 'tzk1', 'tv8'},
#  id= (57, 80), tags= {'twg1', 'tw81', 'tx71', 't76', 'tb11', 'tfb1', 't2t', 't7d1', 'tx51', 't63', 'tm72', 'th6', 'tn81', 't9k', 'tww', 'tcl', 'tjl', 'tvn1'},
#  id= (592,), tags= {'tbz1', 'tf11', 't9z1', 't0d', 't7p1', 'th11'},
#  id= (412,), tags= {'tl3', 't8t1', 't161', 'tkg', 'tgs', 't572', 't271'},
#  id= (84, 797), tags= {'t691', 'tj32', 'tqv1', 'tj', 't76', 'tj82', 'tm81', 't9f1', 'tfr1', 't921', 't011', 'tdn1', 't7q1', 't771', 't3r1', 'tgx1', 'ttf1', 'th62', 't2q'},
#  id= (460,), tags= {'tv81', 'tcj', 't34', 'tg91', 'tm81', 'tq52', 'ttw', 'tbm', 't5m'},
#  id= (598, 242), tags= {'t711', 'tw01', 'ths1', 't5c2', 't3b', 't2g', 'tq81', 'ttb1', 't7g1', 'tsj1', 'ttl', 'tqq', 't911', 'ttd', 'tsr1', 't802', 't692', 'tz42', 'tzt1'},
#  id= (889,), tags= {'tk82', 'th2', 'tsw', 't2t', 't0c', 'tkx1', 'tbm', 'tqc', 'tdn1', 'tnf', 'tdd1', 't5v1', 'tm9'},
#  id= (506,), tags= {'twg1', 'tn6', 'tcb', 'tpr1', 't861'},
#  id= (37, 93), tags= {'t58', 'tjj1', 't532', 't86', 'tc2', 't7q1', 't271', 'tmq', 'tff', 'ts7', 'tpc1', 't3g', 'tq32', 't6z1', 'tf42', 't0s', 't221', 't9h'},
#  id= (753, 146), tags= {'t3r1', 'tbb1', 'tj91', 't1p1', 't8l', 'tv81', 't711', 't0t1', 'tt21', 'ttb1', 'tj9', 'tlc1', 't13', 'tvl', 't7d', 't8h', 'tb5', 'tr2', 'tt'},
#  id= (497,), tags= {'tgc', 'tzg', 't6z', 'tdz1', 'tnm', 'tqz1', 'tt71', 'trq1', 'tqw1', 't9d1', 'tc2', 'tc21', 't2r', 't19'},
#  id= (378,), tags= {'tjs1', 'tv81', 'tgt1', 'tpc1', 'tpj1', 'ttc2', 't19'},
#  id= (633, 410), tags= {'twc', 't711', 'tpb2', 'tfz1', 'tz91', 'tz9', 'tn71', 't1l1', 't0f1', 'tdh1', 'tkf', 't772', 'tb1', 'tcx1', 'tgz', 'tv92', 't8b1', 'tzk1', 'trx'},
#  id= (319,), tags= {'thf', 't6c1', 't33', 'tvf', 't2', 'tbx', 'ttg1', 't452'},
#  id= (206, 912), tags= {'tn31', 't991', 'tpb2', 'tbj', 'tm7', 't1q', 't9c1', 't9h1', 't5g1', 'tgb2', 'tgn', 'tc6', 'thb1', 'thf1', 'tfj', 'tp61', 'twn1', 'tcl', 'trr'},
#  id= (234, 573), tags= {'td41', 'tx9', 't3m', 'tqb2', 't581', 't141', 'tz21', 'tc72', 't9c1', 'td', 't4x', 'tr1', 'tfl1', 'tc6', 't4q1', 't0d1', 'tz22', 'tz4', 't471'},
#  id= (696, 169), tags= {'tgc', 'thj1', 'tb', 't951', 'tk51', 'tgb2', 't1s', 'tm42', 'tdn1', 'tr51', 'tv7', 'tkr1', 'tk9', 'thh1', 'tnr', 'tww', 'thg1', 'tc62', 't431'},
#  id= (305,), tags= {'tsq1', 'tsw', 'tzj', 'tk91', 't7v', 'tb12', 't211', 'th9', 'tn4', 'tdb2', 'tf12'},
#  id= (201,), tags= {'tqc', 't9c', 'tpc', 'tt82', 'td91', 't8x', 't0c2', 'tcp', 't0f1', 't422', 'th8', 'ts81', 't1w1'},
#  id= (98,), tags= {'t8t1', 't491', 'tkt1', 'tz21', 'trb', 'th5', 'trk', 'tc2', 't1s', 'tvk', 't09'},
#  id= (909, 44), tags= {'tjb1', 'th3', 'tqz1', 't0c', 't1l1', 't4x', 't7k1', 't13', 't1s', 'ttb', 'tq62', 'tgp1', 't412', 't6f1', 't3m', 't5l', 't4r', 'tj12', 't352'},
#  id= (456,), tags= {'tg7', 'tk31', 't5h1', 'tm9', 't6w', 't8v1', 'tn71', 'tqz', 't4q1', 't5r1', 'txd1'},
#  id= (694,), tags= {'tg7', 'tzv', 't002', 'tb11', 't9h'},
#  id= (945, 27), tags= {'tgc', 'tnl1', 'tx71', 't242', 'thv', 'tr82', 'tpr1', 'tbb1', 'tx1', 't361', 't1w', 'tc41', 'tf9', 'tn12', 'tl51', 't692', 'thh1', 'thr', 'td62'},
#  id= (786,), tags= {'tx1', 't5f1', 't3c1', 'tm52', 'tp21', 'tv1', 'tv02', 't181', 't2r'},
#  id= (174,), tags= {'tm41', 'tdm1', 'tw6', 't381', 't0f1', 'tzl', 'tm9'},
#  id= (220,), tags= {'tvf', 'trk', 'tq01', 'td51', 'tfq1'},
#  id= (54, 837), tags= {'tjc', 't3k', 'tjs1', 'tw11', 't4t1', 't5g1', 't14', 'tq11', 'tf01', 'tjt', 't7n1', 'tr02', 'tv9', 't3c1', 'tc81', 't8p1', 't8k', 'tzt1', 't9t1'},
#  id= (106,), tags= {'th22', 'tbd1', 't672', 'thz', 't56', 'tk6', 'th52', 'trk', 't9z1', 'tf01', 't5v1'},
#  id= (207, 619), tags= {'tzg', 'tcn1', 't002', 'tlr1', 'tnm', 't511', 't532', 't9j1', 't6z', 'tld1', 'tvs1', 'twd1', 'tn12', 't802', 'tj41', 't471', 'tls1', 'tlz1', 'tl51'},
#  id= (81,), tags= {'tx71', 'tqb2', 'tc51', 'tb22', 'tqf', 'tn12', 't532', 'tpd', 'th1', 'th8', 'tzz1', 'tsw1'},
#  id= (887,), tags= {'tf01', 'tlf1', 't43', 't8t1', 't3m', 't1r1', 'tt21', 'tt82', 'tr5', 't941', 't8l1', 'tmt'},
#  id= (473,), tags= {'tmj1', 't232', 't9c', 't3q1', 't572', 't9z1', 't4d2', 'tr51'},
#  id= (871, 188), tags= {'tk31', 'tt6', 'tl3', 'tdw', 't81', 't8h1', 't46', 'tp72', 'tqh1', 'ts9', 'tz41', 'tw1', 't011', 'tjx1', 'tq21', 't7q1', 't74', 't7n1', 't19'},
#  id= (430,), tags= {'t002', 'tmx', 't441', 'ttd', 't0b1', 'tz22', 'twh', 't65', 'tt4'},
#  id= (678,), tags= {'tcv1', 'tt6', 't0j1', 'tb02', 't9c1', 'tx51'},
#  id= (599, 388), tags= {'tg7', 'ttw1', 'tzg', 'tvb', 't5w', 't55', 'tt11', 'tqt1', 't962', 't2b', 'tk6', 'thc1', 'ttr', 'tjr1', 'tn61', 'tw', 'ts4', 't651', 'td62'},
#  id= (777,), tags= {'tl72', 't58', 'tbj', 't5p1', 'ttd', 't9g1', 'tlm', 'tjl', 'tq21', 'tv02', 'tvr', 't27'},
#  id= (149,), tags= {'tdv', 't0z', 'tbd1', 't6l1', 'tfz1', 'tn4', 'tqz', 'tmr1', 'tz22', 't651', 'tvr', 'tjw', 'tv9'},
#  id= (834, 947), tags= {'tl72', 'tpg1', 't9p1', 't3c1', 't0k1', 'tbq1', 't141', 'tx41', 't2t', 'tn12', 't9q1', 't3w', 'tlm', 'tvg', 'ttm', 't4n1', 'ttb1', 'trt', 'tvk', 't6c'},
#  id= (260,), tags= {'tp62', 'tqx', 't8l', 't0j1', 'tjb1', 'tld1', 'tj2', 't33', 't8', 'tgn', 't86', 'tzn1', 'txg', 'tnf'},
#  id= (240,), tags= {'tg7', 't5g', 'tm41', 't1q', 't511', 'tcq', 'tnw', 't0l1'},
#  id= (930, 903), tags= {'td41', 'tqx', 'tj1', 'tw11', 't7j1', 'tcc', 't34', 'tbq1', 't46', 't26', 'tx41', 'tk22', 'tjj1', 't802', 'tzw', 'tjr1', 'tb02', 't6x', 't2q'},
#  id= (638,), tags= {'tr02', 'tzb1', 'tp61', 'tf22', 'tr5', 'tds', 'tr1', 'tpk', 'tq81', 'tlx1', 'tb7', 'tnf', 't5j', 't892'},
#  id= (246, 808), tags= {'t072', 't34', 'tn3', 'tfz1', 'tm7', 'tg71', 'tvh', 't722', 'tgb2', 'tzl', 'tdb2', 't7q1', 't8l1', 't9k', 't66', 'thn', 't7c1', 't471', 't181'},
#  id= (717, 304), tags= {'tl21', 't34', 't1g', 'tc61', 'tcw1', 'tg12', 'tz72', 'tnf', 'th11', 'ttw1', 'tpc', 'tdx', 'tt82', 't4r', 't3p', 'tn', 'tl01', 'tl6', 't291'},
#  id= (354,), tags= {'t7l1', 'twj', 'tqq', 'tq42', 'thn', 't291'},
#  id= (239,), tags= {'tqs', 't2m', 'tv1', 't531', 't881', 'tj82', 'tgp1'},
#  id= (692,), tags= {'ttw1', 't6k1', 'tq52', 't232', 'tbj', 't2q1', 't9f1'},
#  id= (804,), tags= {'tcc', 't6r1', 'tss1', 'tsp', 'tpz', 'tnc2', 't1l1', 'thc'},
#  id= (277,), tags= {'t63', 'tm2', 't452', 't3f1', 't8h1', 'thq1', 't3g1', 't7h', 't851', 'tf42', 'tmf', 'th11', 'tdg'},
#  id= (320,), tags= {'t3k', 't161', 'tx71', 'tdg1', 'tn6', 't0t1', 'tb1', 'tlr1', 'tbc1', 'tss1', 'th62', 'tn01', 't19'},
#  id= (110,), tags= {'td7', 't481', 't021', 't7j1', 'tfc2', 'tqm1'},
#  id= (641,), tags= {'t35', 't5k', 'tdv', 'tpg1', 'tkq1', 'tp41', 'tfc2', 't9q1', 'tmc', 'tww', 't561'},
#  id= (788, 155), tags= {'ttk1', 't38', 'tht1', 't8g1', 't13', 't1l1', 't011', 't7d', 'tj8', 'tz22', 'tq12', 'ttb', 'tk31', 't7f1', 't3c1', 'tpc1', 'thg1', 'trr', 'tdg'},
#  id= (492, 405), tags= {'t291', 't64', 't38', 't991', 't412', 'tqb2', 'trv', 't3g', 'tz21', 't6w', 'tlg', 't3w', 'tlt1', 't74', 'tlg1', 'tvk', 'tpt', 'tj8', 'tl51'},
#  id= (332,), tags= {'t291', 't4w', 't8w', 'tf42', 'ts2', 't861', 't392'},
#  id= (698, 307), tags= {'t0j1', 'tq02', 't292', 'tp9', 'ttp', 't3w', 'tgn1', 't7q1', 'tv7', 'tl3', 't6z', 'tc11', 't882', 't8', 'tms', 'tlm', 'tdp1', 'tz42', 't4x1'},
#  id= (978,), tags= {'thf', 'tpg1', 'tf4', 'tbz1', 'tft', 'tll1', 't031', 't86', 'td62'},
#  id= (836,), tags= {'tcv1', 'tqd', 'tn51', 't452', 't042', 't242', 't4f1', 'trm', 'tlm', 'tl01', 'tz42', 'trr', 't5j', 'tmf'},
#  id= (997,), tags= {'thh', 't881', 'tpn1', 't3b2', 't311', 't6c', 't452', 't19'},
#  id= (830,), tags= {'t1j1', 'tx6', 'tw11', 'tlr1', 'tsv1', 'tz9', 'ttt', 'tww', 't0r', 't011', 'tw', 't78'},
#  id= (238, 566), tags= {'tjb1', 't0f1', 'ts62', 't9r', 'th42', 't3g', 'tm7', 't8w', 't332', 'tnh', 'tvf', 't501', 'tpd', 'tm3', 't381', 't011', 'tb5', 'tdp', 't452'},
#  id= (493,), tags= {'tr82', 'tzm1', 'tsw', 'tq91', 'tvc1'},
#  id= (103,), tags= {'tcv1', 'tmc1', 'txf1', 't55', 'tkt1', 'tvt1', 'tq52', 'tzs', 'ttb1', 'tl72', 'tj8', 'td62'},
#  id= (854,), tags= {'tnx', 't002', 'tf62', 't1q', 't1k', 'tt3'},
#  id= (282,), tags= {'tqz', 't1h', 'tjw1', 'tbj', 'tnh'},
#  id= (906,), tags= {'t5m1', 'twp', 't232', 't4d1', 't3c1', 'tt21', 't8k1', 'twz', 't621'},
#  id= (128, 697), tags= {'t2c', 'tx1', 't0j1', 'tqb2', 't4d1', 'tz9', 't0c', 't3j1', 't831', 't3p', 'td', 't032', 'thg1', 'thp1', 'td82', 't381', 'tdk1', 'tf01', 't9d'},
#  id= (892, 91), tags= {'tcn1', 't8l', 'tw11', 't6r1', 'tm7', 'tqh', 't381', 'tx52', 'tdn1', 'tjt', 'tgt1', 't6t', 'tbv', 'tn12', 't0g', 'tnt', 'thh1', 't621', 'tlz1'},
#  id= (582, 290), tags= {'tp62', 't8t1', 'tvc2', 't991', 'tjj', 'tfb1', 't511', 'tk22', 'tjr1', 't881', 'tqv', 'tm81', 'tpn1', 't0q', 'tdr1', 't311', 'tl42', 'tq21', 't112'},
#  id= (347,), tags= {'tv7', 'tvc1', 't6t', 'tdn', 'tz21', 'th5', 'tjq', 'ttc1', 'tfj', 'tf2'},
#  id= (78,), tags= {'th82', 'tmj', 'tlb1', 'tr41', 'tsl', 'tf21', 't4r', 'tmc', 't8w', 'tpb', 't1z1', 't2z', 'tj41', 'th11'},
#  id= (893,), tags= {'tv7', 't692', 'tp12', 't6t', 't011', 'tv6', 'tgp1'},
#  id= (423,), tags= {'t991', 't7j1', 't33', 't882', 'tl9', 't4r', 'tdb2', 't851', 'thp1', 'th1', 'tb7', 'tmf'},
#  id= (59, 794), tags= {'t5m1', 'th51', 'tb7', 'tfj', 'tqb2', 't9c1', 'tt41', 'tc1', 'tb62', 'thc1', 'tn4', 'tpp', 'tk6', 'tvc', 'ttx1', 't7d1', 'tls1', 'tzk1', 'td62'},
#  id= (216,), tags= {'tg7', 'tv7', 'td41', 't1w', 't0t1', 'tzv1', 'tn4', 't762', 't7c2', 'tr1', 'tjx1', 'ttm', 'tw51'},
#  id= (512, 344), tags= {'tbr', 't7t1', 't3q', 't511', 't77', 'tqh', 't4x', 'ttd1', 't7q1', 't212', 'tmf', 'tg7', 't361', 'tkr1', 't6w', 'tm92', 'th8', 'trr', 'tm9'},
#  id= (4,), tags= {'t2m1', 'tsj1', 'tv81', 'trn', 't4t1', 't6r1', 'tld1', 'tpb', 't9q1', 'tz41', 't892', 'tt'},
#  id= (659, 413), tags= {'t161', 'tsw', 't8h1', 't141', 't7v', 'tzl', 't1g', 'tms1', 'tjr1', 't09', 't2p', 'tkr1', 'tbv', 't512', 'tpd', 'tlm', 'tj41', 'thc', 'tls1'},
#  id= (927, 144), tags= {'tz02', 'tb21', 'tvq1', 'tcv', 'twt1', 'tfz1', 'tjt', 't512', 'tk22', 't061', 't9q1', 't802', 't8j', 't5d1', 't8b1', 't1x', 'th91', 't0b2', 't1'},
#  id= (148,), tags= {'tjb2', 'tq3', 'tbj', 't882', 'tn12', 'ttj1', 't9n', 'td51', 't1v1', 't0f1', 'tl72', 'trx'},
#  id= (229,), tags= {'tdv', 't3m', 'tc7', 't9k', 'tqz1', 't3t', 'tz72', 'tfj', 'tzm1'},
#  id= (14,), tags= {'thc1', 't622', 't9z1', 't1n1', 'tfj'},
#  id= (754,), tags= {'t002', 'tzh', 'thc1', 't692', 'tbm', 't471', 't12', 't75', 'tt'},
#  id= (986,), tags= {'t2k', 'tq9', 't3q1', 'tzs1', 'tbx1', 'td', 'tgn', 't692', 't69', 'tdd1', 't7p1'},
#  id= (466, 617), tags= {'ttk1', 't0h1', 't0j1', 'tdg1', 'tbd', 't141', 't2t', 'tn71', 't86', 't7w', 't2x1', 'tqc', 't7q1', 'tlw1', 't561', 'tpc', 'tfc2', 'ts92', 't7p1'},
#  id= (742,), tags= {'t6d2', 'tlx', 't462', 't8h1', 't622', 't4d2', 't7n1'},
#  id= (781, 138), tags= {'tlq1', 'tdz1', 't622', 'tz9', 'tqz1', 't3j1', 'tlc2', 'tl42', 'trt', 't7t', 'tw62', 'th42', 'twb1', 'tgb', 'tbv1', 'tzw', 'tcl', 't3x1', 't471'},
#  id= (910, 49), tags= {'txw', 'tz91', 'tkc1', 'tvk', 'td', 'tkv1', 'tv9', 'ttw1', 'tx6', 'tpc', 'tfc2', 't512', 'tkj1', 't1x', 'twn', 'tb02', 'tr42', 'tbn'},
#  id= (478, 426), tags= {'ttw1', 't002', 'tqb2', 't0t1', 'tp01', 'tvs1', 't012', 't7b2', 't5g1', 'twf1', 't032', 't762', 'tl8', 't442', 'tpm', 'tdn1', 't75', 'tdq1', 'tdg'},
#  id= (483,), tags= {'t3m', 't141', 'tm11', 'tpn1', 'tq01', 'tc2', 't4q1', 't4c2', 't7q1'},
#  id= (655,), tags= {'t7d1', 't0w1', 'tq12', 'tfz1', 'tjj1', 't122'},
#  id= (338, 474), tags= {'t3r1', 'tqs', 't161', 'tmj', 't3q', 'tsj', 't0t1', 't0c', 't881', 'tvh', 'td7', 'tnj', 'tv52', 't78', 't9b1', 'tdd1', 't4d2', 'tdq1', 'tl51'},
#  id= (421,), tags= {'tsw', 'th42', 't672', 't692', 'tbw1', 'tb92', 'tdp', 'th11', 'tfj'},
#  id= (255,), tags= {'t7d1', 'trv', 'tm1', 'tp41', 't8n', 'twd1', 't1v1', 't5w1', 't112'},
#  id= (172, 624), tags= {'ttk1', 'tt52', 'txf1', 'tvb', 't9c', 'trz1', 't8h1', 'tbv1', 'tc61', 'trk', 'tfr1', 'tf42', 'tgw1', 't381', 'tjl', 't9j1', 't6j1', 't8l1', 'tgg1'},
#  id= (668, 327), tags= {'ttk1', 't0j1', 'tdm1', 't9c1', 'thv', 'tr82', 'tcw1', 't39', 'th61', 'ttw1', 'tdg', 't9k', 'thc2', 'tpb', 'tb02', 't001', 'tdd1', 'trr', 't291'},
#  id= (540,), tags= {'tbf1', 'tln', 't3s1', 'tq01', 'twc2', 'txg', 't7p1'},
#  id= (193,), tags= {'tx71', 'tpc1', 'tfb1', 'tz21', 'tb72', 'tzq1', 't8l1', 'tdg'},
#  id= (406,), tags= {'tpc1', 'tv01', 't33', 't041', 'tk6', 'thw', 't462', 'tdd1', 't4d2'},
#  id= (971,), tags= {'ttb2', 't921', 't7d', 'trt', 'td62'},
#  id= (806, 133), tags= {'t3k', 'tpl1', 't6', 't88', 'tdb2', 'trt', 'tsk1', 't452', 't771', 'tkf', 'tn62', 'tqf', 't512', 't2q1', 't332', 'tgz', 'tb02', 'tlz1', 'tzm1'},
#  id= (5,), tags= {'t822', 'tbn1', 't3b1', 'tn3', 't771', 't882', 't332', 'tfg1', 'ttc1', 't51', 't7d1', 't071'},
#  id= (564, 289), tags= {'tts1', 'ts21', 't88', 'tg12', 't0f1', 't462', 'tt61', 't82', 't222', 'tw21', 'tn81', 'tcg', 't4r', 'tk6', 't031', 'tlm', 'ttg1', 'tlz1', 'tzm1'},
#  id= (938,), tags= {'tg7', 't3j1', 't3d', 'tfc2', 'tvm1', 't3w1'},
#  id= (311,), tags= {'tmj1', 'tg71', 'tc61', 'tr31', 'tfr1', 't2l', 'tnd1', 't452', 't771'},
#  id= (416,), tags= {'t7d1', 't6z', 'tc42', 'tx11', 'tsx', 't511', 'tz61', 't591', 't2x1', 'tf42', 't171', 'tmp', 't861', 'tjc1'},
#  id= (899,), tags= {'ttg', 'tzg', 'tts1', 'tkr1', 'tvh', 't3p', 't4r', 't2m', 't7c2', 'tbm', 'tvr', 'tgp1'},
#  id= (895,), tags= {'t35', 'tmj1', 't6z1', 'ts8', 't0l1', 't212', 'tn12'},
#  id= (779,), tags= {'tpg1', 'tsr', 'tc42', 't512', 'tk22', 'twv1', 'thd', 'tr1', 't162', 'ttc1', 't1s', 'td51', 't212', 'tt'},
#  id= (502,), tags= {'tlr1', 't38', 't34', 'tn3', 't3v1', 't021', 'thc1', 't4n1', 'tb5', 't78'},
#  id= (21,), tags= {'t742', 'tgb1', 't16', 't561', 't332', 'tfl1', 'tgw1', 't4j1', 't0v1', 'tlz1', 'tv9'},
#  id= (627,), tags= {'tt02', 'tpb2', 't32', 't8n', 'tvs1', 'tz61', 'tv32', 't332', 'tn12', 't6r', 't0s'},
#  id= (967, 841), tags= {'tg7', 't8t1', 't412', 'tx71', 'thl', 't901', 'tb1', 't34', 't81', 'tlb1', 'tqs1', 'trk', 'tww', 'tzt1', 'tdb2', 'ttb1', 't4c2', 'th61', 'tjt', 't4x1'},
#  id= (308,), tags= {'t9w', 'tw92', 't2r1', 't561', 'tfb2'},
#  id= (924,), tags= {'t361', 'trv', 'tdc2', 'tsw', 'tt11', 'tp41', 'tcb1', 'tt21', 't0c', 't39', 'tb5', 'txg', 'tlj'},
#  id= (940, 31), tags= {'tt01', 'tx81', 'tm7', 'tkc1', 't1c', 'tg71', 'tsb2', 't542', 't4c2', 'tv8', 't2g1', 'tvs1', 't882', 't6w', 't0j', 't692', 't7q', 't4m1', 't73'},
#  id= (117, 856), tags= {'twg1', 'tg71', 'tv', 't2', 't7w', 'tnf', 'tvr', 'tfj', 't7f1', 't931', 't1w', 'tt72', 'tgf', 'trq1', 'tvx1', 'tfg', 'tf42', 't1v1', 't4x1'},
#  id= (104, 795), tags= {'tqp', 'tcv1', 'tq91', 'tjb1', 'tqk1', 't3f', 'txb', 'tft', 't881', 'tqv', 't7k1', 'tv02', 'tv9', 't2w', 't0t1', 'tt91', 'thk1', 'thc', 'tdd1'},
#  id= (359, 583), tags= {'t0k', 'trt', 'tbn1', 'tzq', 't42', 'thv', 't7v', 'tm81', 't4r', 't3t', 'tgz', 'tp21', 'tqz', 't3p', 't411', 'tq91', 'tvk', 'thl1', 'tmp'},
#  id= (268,), tags= {'t342', 'tzn', 't81', 'tx01', 't0l1'},
#  id= (180, 721), tags= {'tp9', 't1l1', 'th52', 't2x1', 'ttb1', 't4p', 'tv9', 't19', 'tt6', 't361', 'twz1', 'tcj', 't4', 't4r', 'td7', 'tww', 'tzb', 'tb41', 'thc'},
#  id= (702,), tags= {'td', 'tht1', 'tdp1', 'tqc', 'tbj', 't511', 't392'},
#  id= (905,), tags= {'tjc', 'tr01', 'tqq', 't6d2', 'tm7', 'tsr1', 'tpd', 'tlz', 't6b', 'tl72', 't251'},
#  id= (74,), tags= {'thc1', 'ths1', 'tv', 'tqh', 'tj41', 'tpn1'},
#  id= (112,), tags= {'tg7', 'thc1', 'ttn', 'tzt1', 't911', 'txf'},
#  id= (224, 832), tags= {'t711', 't8t1', 'tjb1', 'tfb1', 'tm7', 't7v', 'tg71', 'tqh', 'tck1', 'tpr1', 'txm', 'tfx1', 'tp72', 'tlm', 'tbm', 'tq01', 'tj41', 't4x1', 'tjw1'},
#  id= (839,), tags= {'t3c1', 'tc11', 'tkc1', 'thc1', 'tm32', 'tq01', 't9x1', 't1s'},
#  id= (916, 51), tags= {'tvc1', 't4t1', 't242', 't8h1', 'tz8', 'ttb2', 't4x', 't5w1', 't1j1', 'tl3', 'tgt1', 'tz02', 't6t', 'tkr1', 'tq21', 'tn12', 'thc', 'tw52', 'tdg'},
#  id= (75,), tags= {'tqs', 't6t', 't6r1', 't0k1', 'tg32', 'thv', 'tr42'},
#  id= (660, 376), tags= {'tn31', 't691', 'tzg', 'ts91', 'tsw', 't8t', 'tz62', 'tfr1', 't2', 'tfj', 'tn51', 'tvb', 't351', 't33', 'tdl1', 'tpb', 't9b', 'tc21', 't0m'},
#  id= (163, 689), tags= {'tr02', 'tp62', 'tv7', 'txb2', 'tsb1', 'tfj1', 'tm52', 'tz61', 't0c1', 't2h', 'twd1', 'tt82', 't3r', 't1l1', 't392', 't762', 't4n1', 't3h', 't4x1'},
#  id= (896,), tags= {'tr02', 'tn51', 't4g', 't3v', 'tr5', 'td7', 'tv1', 'tpx', 'tqc', 'tpr1', 'tdg'},
#  id= (594,), tags= {'t1j1', 'twg1', 'tz9', 't93', 't3j1', 't802', 'tj41', 'tkn', 'tw52', 't0l1', 't19'},
#  id= (555,), tags= {'tw81', 't7p1', 'ttl1', 'tjt1', 't0p', 'tk61', 'tbw1', 't0t', 'tf42', 'tb7', 'tpq1', 'tr42', 'thr1'},
#  id= (842,), tags= {'tz1', 'txf1', 'tn8', 'tz9', 't7p1', 'tfm', 't101'},
#  id= (949, 891), tags= {'tp51', 'twg1', 'tcn1', 't132', 't022', 'tqb2', 'tdm1', 't1j', 'trv', 't792', 'tm42', 'trc2', 'th72', 'tk22', 'tjj1', 'ts01', 't921', 'tzn1', 't6c', 'tjw1'},
#  id= (517, 355), tags= {'ttc', 't4t1', 't55', 't0t1', 'tfq1', 'tpw', 'tt21', 'tz61', 'tnx1', 't5r', 't2', 'tx12', 'tms1', 'tlm', 't8b1', 'tlc1', 'tm42', 't6c', 't861'},
#  id= (567,), tags= {'t931', 'tz9', 't6p1', 'tsr1', 't1q1', 'tsk', 'tzt1', 'tv1', 't1s', 'tw', 'tl6', 'ts4', 'th61', 'tf2'},
#  id= (271, 643), tags= {'t5v', 'ttw1', 'tl4', 'tsn1', 'txq', 'tm1', 't1w', 'tld1', 'tfz1', 'tz91', 't2t', 'tqv', 'tp52', 't4x', 't1s', 't74', 'tl6', 't2v', 'tzm1'},
#  id= (179,), tags= {'tvv1', 'tjs1', 't002', 't9k', 'tx41', 'tpq', 'tjx', 'tm7', 'tms', 'tlm', 'tq81', 'tzp1', 'tl72', 'tr51'},
#  id= (623,), tags= {'tw11', 'txf1', 't38', 't412', 'tj02', 't021', 't4k1', 't5b1', 'thg1', 'tqc1', 'tc', 'tkl1', 't452'},
#  id= (948,), tags= {'tsx1', 'tgn', 't1d1', 'tkc1', 't071'},
#  id= (792,), tags= {'t202', 'th42', 'tpr', 'td', 'tb8', 'tpp', 'ttc1', 'tvf', 'tx72', 'tgn1', 't6c', 'tlz1'},
#  id= (278,), tags= {'t0l', 't4h1', 't3j1', 'tsf1', 'tmt1', 'thh1', 'tx61', 'tvn1', 't1'},
#  id= (546,), tags= {'twg1', 'tqr1', 'tt32', 'tmd1', 't332', 't6f', 't051', 'tqv', 'tww', 'tjm1', 'tqz', 'tz22', 'tdp', 'tm51'},
#  id= (211,), tags= {'tm42', 'tsv1', 'tqq', 't6d2', 'tkd1', 'twl1', 'tp3', 't3w1', 'tnl', 't3p', 'tb5', 'tz22', 't5r1'},
#  id= (605,), tags= {'tj7', 'tzn', 'tkw1', 'tz91', 'trk', 't8j', 'tq81', 't8l1', 'tlz1'},
#  id= (673, 402), tags= {'tz6', 't6r1', 'tvd', 't0c', 'tmp1', 't9c1', 'tmg1', 't532', 't3x', 'tlg1', 'tr81', 'tdp', 'tzm', 'tgm1', 't2f', 'tqf', 't351', 't321', 't9d1'},
#  id= (863,), tags= {'t5s', 'tf81', 'tq51', 'tt82', 'tz81', 't8j', 'tj8', 't5w1', 't721'},
#  id= (60,), tags= {'th81', 'tl82', 'tm2', 'ts12', 't241', 'thn', 'tv02', 'tr42', 'tgp1'},
#  id= (807,), tags= {'thc1', 'tms', 'tww', 'tpc', 'tg6', 'txg', 'td62'},
#  id= (621,), tags= {'tcv1', 't0h1', 'tss', 'ts6', 'tt22', 'tdn1'},
#  id= (876, 915), tags= {'t3r1', 't711', 'ttg', 'tsq', 't161', 'tht1', 'tqq', 't76', 'tn51', 'tdn', 'tk01', 'tbv1', 'tp21', 't37', 'tqz', 't8x1', 'tv1', 'tr6', 'tj3', 'tfj'},
#  id= (95, 866), tags= {'tr02', 'trn', 'tl31', 't3c1', 't81', 'tn3', 'tqk1', 't0c', 'tkc1', 'tdm1', 'tm7', 't561', 'tqv', 'tpp', 'tdp1', 'tv02', 'ttm', 'tpp1', 'tl6'},
#  id= (132,), tags= {'twg1', 't8q', 'ttn', 'tfm1', 'tw02', 't771'},
#  id= (116, 705), tags= {'t711', 'twg1', 'tjs1', 't072', 't6t', 't76', 'tq91', 't6d2', 't0c1', 'tpb', 'tr82', 'tcw1', 't86', 'tmt1', 'tv02', 'thb1', 'tdp', 'tkm1', 'tgg1'},
#  id= (809,), tags= {'trc1', 'tmp1', 't732', 't1w', 'twd', 'th61', 't512'},
#  id= (232,), tags= {'tdv', 'td32', 't6q1', 'tlr', 't9s1', 't1k1', 'tj8', 't6b2', 'tjt'},
#  id= (691,), tags= {'tqs', 'tw11', 't1r1', 'tqk1', 't6c2'},
#  id= (868, 72), tags= {'tj1', 'tx71', 't34', 'tnb2', 'thk1', 'tj82', 'tq8', 't6q', 't71', 'tc4', 't651', 'tg7', 'tn41', 'th42', 'tpn1', 't332', 'tt12', 'tsb', 't531'},
#  id= (974, 894), tags= {'tgc', 'tt32', 't511', 'tjj1', 't88', 'tjc2', 't6x', 'tnf', 't561', 'tf2', 'td41', 'tl3', 't6t', 'ttt', 'ttr1', 't0w1', 'tk6', 'thg1', 'th1', 'tr2'},
#  id= (131, 977), tags= {'tjb1', 'tbj', 'tkq', 'tfr1', 'tdb2', 'tph', 't7d', 'td41', 't6t', 'tx82', 'tkr1', 't911', 'tzr', 'th41', 'tz61', 'tcl', 't8b1', 'thc', 't421'},
#  id= (610,), tags= {'tb91', 'txf1', 'thc2', 'tgr1', 'tq01', 'tlw1', 'tnj', 'tdd1', 'txx', 't771'},
#  id= (600, 204), tags= {'th82', 't991', 't6r1', 'tv32', 'tgn', 'tqz', 't83', 'tlj', 'tn82', 'tx51', 'tr02', 'tz52', 't412', 'tr5', 't4r', 'trk', 'tl72', 'tzk1', 't291'},
#  id= (657, 199), tags= {'tx71', 'tts1', 'tr52', 't55', 'tj72', 'tn81', 'th42', 'tlv1', 't512', 'tb5', 't5v1', 'tf21', 'txq1', 'tp21', 'tr1', 'tq81', 't8b1', 't0f1', 'tc82'},
#  id= (208,), tags= {'trl1', 'tdz1', 't2d', 'tvh', 'tgb2', 't6z1', 't7w', 'thp1', 'trc', 't431', 'tdx1'},
#  id= (281,), tags= {'tq91', 'tdg1', 't5p1', 'tt21', 'tq7', 'tzr', 't532', 't9n', 't181', 't651', 't5v1', 'tgp1'},
#  id= (776,), tags= {'t8f', 'tgh', 'txd', 'tmg', 'tpc1', 't2t', 'tv4', 't7d1'},
#  id= (918, 156), tags= {'t1j', 't64', 'txf1', 't5b2', 'trz1', 'tpc1', 'tk22', 't7j', 'tzw', 't6x', 'tgn', 't692', 't311', 'thh1', 'tsd1', 'tdp', 'tkv1', 'th11', 'tm9'},
#  id= (908,), tags= {'tp62', 't55', 'tx41', 'tv32', 't68', 't3w', 't74', 't7g1'},
#  id= (485,), tags= {'tbs1', 'tcv1', 'tkf', 'twz1', 'tvb', 'tg62', 'tq82', 'th61', 't2m', 't6k', 'thb1', 't2f1'},
#  id= (745,), tags= {'tvb', 'tdz', 'tg62', 'tpc1', 't5p1', 'tvb1', 'thc2', 'tdd', 'trk', 'ttm', 'tz92', 'td51', 'thc', 'tvk'},
#  id= (152, 744), tags= {'t991', 'tdc2', 'tz91', 'tm7', 'tqz1', 't7s1', 'tc61', 'tv', 'tdb2', 't011', 'tpx1', 'ttb1', 'tm42', 't8l1', 'tld1', 'th31', 'trk', 'tqm', 'thh1'},
#  id= (649,), tags= {'td32', 't86', 'th1', 'tq12', 't1'},
#  id= (992,), tags= {'tk82', 'tqs', 'tt01', 'tpb2', 'tqv1', 'tpc', 'tp41', 'tfc2', 'tqp1', 'thc', 'tpr1'},
#  id= (769, 18), tags= {'txf1', 'tjb1', 'tsv1', 't1w', 'tl21', 't572', 'tq7', 'tc12', 'tkj', 'tgb2', 't2m', 't332', 'tr82', 't13', 'tq01', 't5r1', 't271', 'tcb2', 'tf7'},
#  id= (472,), tags= {'t2g1', 't361', 't0j1', 't232', 'tbc1', 'tsp', 'tr32', 't2m', 'tk7', 'tnp1', 'tmt1', 'tv91', 'tj41', 't9x1'},
#  id= (24,), tags= {'tp62', 't711', 't691', 'ttj', 'tx7', 't13', 'tq91', 'txg'},
#  id= (87,), tags= {'t38', 'tht1', 'tm1', 'tdg1', 't6d2', 't21', 'tqb', 'tg71', 't3p', 't9d1', 'tj41', 'tx52', 'tlr'},
#  id= (127,), tags= {'t2m1', 'tg', 'tvq1', 'tm1', 't3g', 'thh1', 'tjj1', 't0b', 't0g1', 'tzb', 'tgj', 'tw52', 'tc92', 'tm9'},
#  id= (366, 572), tags= {'t481', 't0j1', 'tpv1', 'tj1', 't6z', 'tsq', 't9c', 't34', 't3g', 't81', 't131', 'trg', 'tt82', 'thz', 'tgk', 'tgj', 'tlk', 'tsk1', 'tt'},
#  id= (440,), tags= {'tl3', 'tpc', 'tc11', 't562', 'tk6', 'tgc2', 'tns', 't8r1'},
#  id= (107,), tags= {'tsr1', 't9h', 'tf22', 'tl6', 'tnm', 'tgq1'},
#  id= (816, 259), tags= {'t3k', 't711', 't702', 't351', 'tkc1', 't6p', 't1g', 'thn', 'tf21', 'tqv', 'txs', 't86', 'tdb2', 'tfq', 'twz', 't03', 't7n1', 't861', 'tmf'},
#  id= (210,), tags= {'t33', 'trr', 'tc6', 't4d2', 'ts2'},
#  id= (526,), tags= {'tg7', 't661', 't64', 't8n', 't9k', 'tf41', 'tb9', 'ttb2', 't621'},
#  id= (576,), tags= {'tdv', 'tsh1', 'tcn1', 'th8', 't1w', 'tqz1', 't341', 't0m1', 'tp8', 'tz01', 'thg1', 't8b1', 'tw52'},
#  id= (9,), tags= {'t391', 'ts12', 'tcc', 'tj82', 'td42', 'tzw', 't762', 't471', 't3x', 'tqg', 'tr42'},
#  id= (28,), tags= {'tr02', 'tm9', 'tk31', 'tzg', 't4v1', 'tbn1', 'trn', 'tx2', 'tkg1', 't5w1', 't6r', 'tdp', 't6c', 'tf2'},
#  id= (161, 932), tags= {'ttc', 'txl', 'tzg', 't002', 't381', 'td82', 't7d', 't462', 'td41', 't412', 'tqc2', 'tf22', 't93', 'tfp1', 'tp21', 't031', 't74', 't7p1'},
#  id= (975,), tags= {'t4g1', 'tdg', 'tm7', 'tst', 'tm81', 't1n1', 't861', 'tt4'},
#  id= (587, 249), tags= {'t2b2', 't76', 'thw1', 't091', 'tjr1', 'tx01', 't9j1', 'tjx1', 't9z1', 'th11', 'txx1', 'tvc2', 'ttv', 'tvr1', 'tw71', 't5f1', 't4r', 'ttc1', 'tdp1'},
#  id= (486,), tags= {'t051', 't3k', 'tdb1', 'thr', 'tqk1', 't782', 'tx72'},
#  id= (453,), tags= {'tsd', 'tqd', 'tz82', 't471', 't6j1', 't511', 'twd1'},
#  id= (685, 386), tags= {'tjc', 't161', 'twj', 'tdm1', 'ts61', 'txb', 'tkc1', 't511', 't252', 'ts22', 't6h1', 't6c', 'tgt1', 'tp82', 'tt41', 'tc5', 't2m', 'trr', 'td62'},
#  id= (579, 336), tags= {'tw81', 'tw32', 'tdg1', 't3q', 't9d', 'tkr1', 'tst', 'tqv', 't6z1', 'ttb2', 'tcl', 'tq5', 'tc6', 'thb1', 'tzx', 'tvn1', 'tjt', 'tlz1', 'tv9'},
#  id= (761,), tags= {'tgc', 'tmj1', 't3m', 'tz02', 'tmv', 't3p1', 'ttj', 'tfc2', 'tjr', 'tg5', 'tcl', 'txg', 'th61', 'tds1'},
#  id= (626,), tags= {'tjq1', 't6t', 't011', 'tjr', 't512'},
#  id= (981, 982), tags= {'tr21', 't9x', 'tpz1', 't242', 't3q', 'tk61', 'tdb2', 'tm42', 't651', 't8l1', 'twf', 't1', 'tcj', 't412', 'tld1', 'tqb', 'tz61', 'tt9', 'tpd', 'th91'},
#  id= (90,), tags= {'th1', 't691', 'tqv1', 'tm1', 'trn', 'ts02', 't351', 'td82', 'ttb2', 'tjr1', 't1v', 't5v1'},
#  id= (844,), tags= {'t5v', 't4r1', 'txk1', 't161', 't5l1', 'tm7', 'tkc1', 't031', 't651', 'tc82'},
#  id= (556,), tags= {'tm32', 'tzn', 'ttb1', 't462', 't9k', 'tv32'},
#  id= (917,), tags= {'tpl', 'twx1', 'tn4', 'tkr1', 't66', 't5w1', 'tcn'},
#  id= (121,), tags= {'tpp1', 'tr3', 'tq01', 't3b1', 't0f1', 'th8', 'td2'},
#  id= (223, 653), tags= {'t8n1', 't361', 't6z', 'tht1', 'ths', 't33', 'tl32', 'tj9', 't562', 't9l', 't49', 'tz82', 'tj41', 'tcc2', 'tpx', 'ts22', 'trr', 'tgp1'},
#  id= (295, 735), tags= {'tkw', 'tjs1', 'tpb2', 't582', 't4d1', 'tdn', 't2t', 'tc61', 't4x', 't7k1', 'tn4', 'tv02', 't9j1', 'tsg', 'tbz1', 't572', 'twm', 'tdd1', 't5v1'},
#  id= (790,), tags= {'tkl', 'txf1', 'td51', 't622', 'tc11', 't6d', 't0f'},
#  id= (126, 737), tags= {'t711', 't0p1', 't8t1', 'tn51', 't7j1', 't1h', 'tsq1', 'tbz1', 'tnb2', 't622', 't911', 'tr5', 'tnm1', 'tqh', 'ttb2', 'tx01', 't212', 'tr42', 'tdg'},
#  id= (739,), tags= {'ttw1', 't7v1', 'tsj1', 't4b1', 'tpg1', 'tzj1', 'tfp', 'tlw', 'tc2', 'twc2', 't1v1', 't452', 'tsg'},
#  id= (532,), tags= {'t3k', 't8l', 'tw81', 'tjn', 'tfz', 't001', 'tnz1', 't3w', 't0x', 'tz22', 't651'},
#  id= (652,), tags= {'tn51', 't311', 'tn3', 'tt11', 'tcz', 'tvr', 't771'},
#  id= (667,), tags= {'tjs1', 'tw11', 'tfr1', 't7x', 't292', 'tqz1', 't651'},
#  id= (919, 147), tags= {'tg7', 'twg1', 'tkb1', 'tmv', 't1q', 'tcf', 'tqz1', 'tk22', 't6w', 'tnp1', 't3b2', 't871', 't13', 'tj41', 'tw', 't381', 't3c2', 'tzt1', 't7n1'},
#  id= (215, 858), tags= {'tk82', 'tjb1', 'tbj', 'tm52', 'tj82', 'tc2', 'tp6', 't0f1', 't78', 'tx72', 'tmf', 'ttw1', 'thz', 'trq1', 'trk', 'thg1', 'tj41', 'tv1'},
#  id= (2, 833), tags= {'tmj1', 'tgt1', 't5r1', 't4t1', 't201', 'tg11', 't81', 't6r1', 'tgc1', 'tbj', 'tfs1', 'tb6', 't7b2', 'td7', 't652', 't4q', 't001', 'tb7', 'tlm1'},
#  id= (491,), tags= {'t88', 't2', 't6t', 'tn32', 'tfd', 'tc81', 't9h'},
#  id= (396,), tags= {'t4t1', 'tn3', 'tlb1', 'tn81', 't592', 't6k1', 't69', 'tf42', 'th8'},
#  id= (349,), tags= {'t3c1', 'tk81', 'th4', 'tq7', 't3v1', 't1g', 'twn1', 'tv', 'trt', 'tvr', 'tzm', 't452'},
#  id= (387,), tags= {'tl3', 't291', 't482', 'tdz1', 'tlb2', 'th42', 't441', 't9q1', 'tqp1', 'tf42', 'trt', 'tj51', 'tt4'},
#  id= (880,), tags= {'t2m1', 'txw', 't2t', 'th61', 't592', 'tpb', 't3w', 'td01', 't6h', 'tj41', 'tjr1', 't4z1'},
#  id= (178,), tags= {'td41', 'tc11', 'tkc1', 'tzw', 'tpd', 't4l1', 'thk1', 'tdd1', 'tvb2'},
#  id= (628, 345), tags= {'tv7', 'tj91', 'tkf', 'thg', 't3q', 'tpb1', 'tb11', 'tbj', 't351', 't831', 't2m', 'tc91', 'trc1', 'tjr1', 'tb5', 'trt', 'tb02', 't0l1', 'tz22'},
#  id= (293,), tags= {'tj91', 'tsz', 'tw81', 'tf51', 'tfc2', 'tsp'},
#  id= (640,), tags= {'t8l', 't6d2', 'tt11', 'tfv', 'twc1', 'tv52', 'tjm', 't3'},
#  id= (644,), tags= {'tsc1', 'tcc', 'tbv', 'tz21', 'tvs1', 'tx7', 't6f', 't762', 'thp1', 't9z1', 't221', 'tf01'},
#  id= (529, 490), tags= {'tkf', 'thz1', 'tct', 'tmj1', 'tqb2', 't81', 'tb32', 't0c', 'tvb1', 'tsp', 'tnl', 'tvf', 'thc1', 't211', 'tmx1', 'tjr1', 'tb5', 'tzk1', 'tf01'},
#  id= (749, 118), tags= {'t2c1', 'tk8', 't21', 'tsp', 'tmz1', 't762', 't39', 'tb7', 't651', 'tjt', 'txf1', 'tz02', 'tcc', 't721', 't1b2', 'tv1', 'tgj', 'tnj', 'tlb'},
#  id= (465, 434), tags= {'tgt1', 't64', 't7j1', 'tjl1', 't822', 't0j1', 'tn81', 'tl92', 'tst1', 'tq8', 'td42', 'tk61', 'tzw', 'tvx1', 't7d1', 't6h', 'tnf', 'tr71', 'tt'},
#  id= (964,), tags= {'t481', 'tzn', 'tgh1', 'tr82', 'trk', 't8x', 'tlm', 't8j', 'tj41', 't4n1', 't7d1', 'ts51', 't8w'},
#  id= (274,), tags= {'ttw1', 'ts51', 'tz61', 'tcw1', 'tr7', 'td22', 'td82', 'tw52'},
#  id= (634, 438), tags= {'tf71', 'tn3', 't9s1', 'tt21', 'tv32', 'tlg', 'tr82', 't22', 't2n1', 'tb7', 'tmf', 'tkr1', 'tk32', 't1m1', 'tnl', 'tcl', 'tgk1', 'tdp1', 't0l1'},
#  id= (548, 481), tags= {'tjs1', 'tx71', 't242', 't511', 't7v', 't13', 't86', 't7k1', 'tf02', 'tw', 't4d2', 'tr51', 't07', 'tm62', 'tld1', 'tgw', 'tr5', 'tcs1', 't861'},
#  id= (558, 339), tags= {'tjs1', 'tmg', 't2t', 't302', 't9n1', 'tgn', 't13', 't102', 't4d2', 't61', 't3r1', 'tmf', 'tm9', 'tpg1', 'tw21', 't5f1', 'thp1', 't1v1', 'tvc1'},
#  id= (741,), tags= {'t7d', 't38', 't8b1', 'th1', 't0b1', 'thh1'},
#  id= (391,), tags= {'tdc2', 'tbn1', 'tdg1', 't3g', 'tv32', 'tmh1', 't7c2', 't74', 'thb1', 'txg'},
#  id= (712,), tags= {'t1j1', 'tl31', 't622', 'tx41', 't511', 'tnj', 'th92', 't74', 'tm42', 't84', 't19'},
#  id= (722,), tags= {'td81', 't031', 't002', 'tlz1', 'td62'},
#  id= (985, 15), tags= {'tlb1', 't9n1', 't2w1', 'tjq', 'tzg1', 't452', 'td4', 'tg7', 'txf1', 'tm62', 'tkt1', 'tz21', 'tc5', 'td91', 'td7', 't471', 'tdp1', 't6d1', 't82'},
#  id= (19,), tags= {'tdg1', 't7z1', 'tnb2', 'tqb1', 't1c', 'thn', 'td7', 'tk6', 't4w', 'tv1', 'thb1', 'tc01', 'tt'},
#  id= (335, 726), tags= {'tv81', 't38', 't3p1', 'tqj1', 'tvh', 't532', 'tfb', 't642', 't491', 'tcc', 't5f1', 't6d2', 'tj42', 'thn', 'tr5', 't8h', 'th1', 't181', 'tnj'},
#  id= (221, 615), tags= {'t58', 't81', 'twp1', 'thv', 't532', 't2', 'tgt', 't78', 'tjt', 'tfc2', 'tz21', 'tjh', 'tpd', 't471', 't791', 't181', 't04', 't7p1', 'td62'},
#  id= (480,), tags= {'tvb', 'tkx', 't76', 'trt', 'txx', 'tc3', 't871', 'td51', 't791', 'tqc', 'tpr1', 't7l1', 'tf2'},
#  id= (713,), tags= {'tp21', 'tg12', 'tcj1', 't76', 't8h1', 't8n', 't9p'},
#  id= (429,), tags= {'twg1', 't8f', 'tkg1', 'tbq', 'tvb1', 't8t', 't1p', 't13', 'tz4', 't011', 'tg52', 't0b1'},
#  id= (501, 373), tags= {'t3r1', 'tkf', 'trn', 'tq3', 't8h1', 'tbr1', 't6n', 't9n1', 'tc71', 'tl9', 'tqp1', 't0w1', 'trq1', 'tq01', 'td82', 'tlc1', 'th8', 'ttt1', 'tmz'},
#  id= (630, 444), tags= {'t8l', 't991', 'tm82', 'tft', 'tq52', 'tc61', 't3w', 'trc1', 'tc6', 'tb5', 'tbh1', 'tg7', 'tvc2', 'tvs1', 't4r', 't6z1', 'tbw1', 'tz5', 'tmt'},
#  id= (463,), tags= {'tq3', 'tt82', 'tsr1', 'tc61', 'tqh', 't3x1', 'tpd', 'tqv', 'tc6', 'tkx', 'tjt'},
#  id= (50,), tags= {'tl2', 'txf1', 'tbd1', 'tr11', 'tpc1', 't3g', 't6r1', 't4b2', 't31', 'tgn', 'tr1', 't682', 'trr'},
#  id= (397,), tags= {'t5v1', 't38', 'tn21', 't7c2', 't2j1', 't452'},
#  id= (647,), tags= {'tk6', 't9q', 't3q1', 'tt11', 'tt72', 't881'},
#  id= (218, 662), tags= {'tjs1', 't342', 'tbn1', 't38', 'tts1', 't8h1', 'tg62', 'tvd', 'tk52', 't332', 'tcz1', 'tr82', 'twv', 'tr1', 'tdp1', 'tm02', 'tvk', 't6x', 't8l1'},
#  id= (340,), tags= {'tsj1', 'tv61', 'twn1', 't312', 'tqg1', 'tf22'},
#  id= (185, 840), tags= {'tsq', 't4d1', 't8h1', 'tbd', 'tdb2', 't6x', 'tvm', 'tgp1', 't972', 't361', 'tv62', 't33', 'thn', 'tnl', 't0c2', 'ttc1', 'tl6', 'tlk', 'tdd1'},
#  id= (343, 703), tags= {'tgc', 'tcv1', 't5h1', 't8l', 't2t', 'tmg1', 'tr4', 't2x1', 't462', 'tw51', 't19', 't6z', 't5f1', 't6d2', 't0j', 't692', 'tw91', 't832', 't9p'},
#  id= (42,), tags= {'t88', 'tj9', 't2f', 'tp7', 'thc'},
#  id= (531,), tags= {'td32', 'tjn1', 'tcl', 't4g1', 't6n1', 'tf01'},
#  id= (370,), tags= {'tgc', 'txn1', 'tgt1', 'tm51', 't992', 'tvs1', 'tgl1', 't74', 'ttm', 'tb02', 'tlz1', 't291'},
#  id= (250, 547), tags= {'t5d', 't222', 'tqv1', 'ttk', 'tqf1', 'tbj', 'tvh', 't0w1', 't4c2', 't86', 'trm', 't541', 't4l1', 'trz', 'ts51', 'ts2', 'tf7', 't9t1'},
#  id= (261,), tags= {'tjc', 'tj91', 't361', 't6d1', 'tk7', 'tf12', 'tb5', 't452', 'tjw1'},
#  id= (650,), tags= {'t64', 't5f1', 'tfc2', 'tt21', 't0c', 't521', 'ttp', 'tr8', 't7x', 'tf42'},
#  id= (158, 956), tags= {'t8b', 'tqb2', 'tn3', 't21', 'txb', 'tn71', 'tfr1', 'tjr1', 't6h1', 't7q1', 'td41', 't391', 'tw32', 'tz21', 'tpg', 'th02', 'tvk', 't9h', 'trs'},
#  id= (684, 173), tags= {'t151', 't8t1', 'tcm', 'tp41', 'tkr1', 'tzq', 'tss1', 'tpc1', 'tlv1', 'tnm', 'tks1', 'tr82', 'td', 'tl9', 't86', 't3w', 't842', 't7d1', 't9w1'},
#  id= (69, 885), tags= {'tc02', 't76', 't4m1', 't49', 'ttb1', 'tlv', 't65', 't9j', 'tgp1', 'ttw1', 'tk', 't63', 't6t', 't3g', 'tbv1', 'tnl', 'tsd1', 'tlz1'},
#  id= (436,), tags= {'t6z', 't161', 'tf71', 't8h1', 't2d', 'tjz', 'tk02', 't471', 'tj41', 'tv22'},
#  id= (510, 482), tags= {'t4r1', 't161', 't9p1', 'tvz1', 'tz9', 'tkc1', 'tc61', 'tvn', 't4l', 't2x1', 't561', 'tfr', 'tcs', 't1w', 'tpn1', 't3p', 't2m', 'tdp1', 'tb02'},
#  id= (979, 861), tags= {'t002', 't4x', 'tbh1', 't5w1', 'th11', 't3r1', 'tm9', 'tbc2', 'tn51', 'tth', 't3b1', 't241', 'tbv', 'th42', 't3g', 'tq32', 'tc21', 't001', 'tn91', 't291'},
#  id= (333,), tags= {'tgb2', 't2', 't0t1', 'tz22', 't0b1'},
#  id= (820,), tags= {'tw81', 'trv', 'tz02', 'tn3', 't881', 'tnl', 'tp21', 'ttb1', 'tq91', 't9j'},
#  id= (1,), tags= {'tzb1', 'trn', 'twt1', 't81', 'tc51', 't6c', 'tgr'},
#  id= (197,), tags= {'th81', 'tcv1', 'th1', 't3m', 't5f1', 't72', 'thn', 'tv32', 'tj3', 'tzb', 'tbm', 't5j1', 'tqt', 't8l1'},
#  id= (0, 115), tags= {'t17', 'tjb1', 't8g1', 'tvh', 'tgb2', 'tmz1', 'thc1', 't7c2', 'tjx1', 'txm', 't1l', 't8l1', 't361', 'tg6', 'twd1', 't5b1', 't8b1', 'tw52'},
#  id= (352,), tags= {'tgc', 't3r1', 't8l', 't3p1', 'ttd', 'td7', 't9x1', 'th1', 'tz42', 'tt42'},
#  id= (170,), tags= {'t3k', 't342', 'tqq1', 't692', 'tx82', 'tl71'},
#  id= (803,), tags= {'t711', 'tjn1', 'tqc', 'tg62', 'th42', 't302', 'tj82', 'tqv', 'tb02', 'thb1', 't4d2', 't4x1'},
#  id= (944,), tags= {'tmj1', 'tk92', 'tz21', 't952', 'tcw1', 'trm', 'tfw', 'tcq1', 'tls1', 'thr1'},
#  id= (514,), tags= {'t4d1', 'tv21', 'trm', 'tft1', 't86', 't8b1', 't11', 'tf2'},
#  id= (907,), tags= {'tfj', 't55', 'tgb1', 'tvs1', 'tfp', 't3x1', 't921', 'thp1', 'tgj', 'tbz', 'tf2'},
#  id= (939,), tags= {'tr02', 'tvc1', 'tsq', 't662', 'tj', 't3b1', 't5f1', 't771', 't33', 't7g1', 'ttb2', 't621', 'tdf1'},
#  id= (217,), tags= {'t2m1', 'tt31', 'tm1', 't5f1', 'tqf', 'tqz1', 'td92', 't13', 'tsb', 't47', 'tp91', 'tdn1', 't1l', 'tr42'},
#  id= (812,), tags= {'t931', 'tbv', 'tt21', 'tpb', 'tt9', 't011', 'tq21', 'tdp', 'tvr', 'tf01'},
#  id= (774, 6), tags= {'t502', 'tpz1', 't9s', 't291', 't951', 'tj62', 'tr51', 't9c1', 't3p', 'tgn', 'tcl', 't14', 't011', 'td82', 'tgd1', 'tzt1', 'trx', 'tlb', 't7q'},
#  id= (577, 414), tags= {'tvc1', 't232', 'tsw', 'tr62', 'tbv', 'tdt1', 'tz61', 'tt82', 'tv32', 't2m', 'tcl', 't591', 't2x1', 'td61', 'tr2', 'tws1', 'tgp1', 'tvr', 'tf2'},
#  id= (828, 99), tags= {'t2m1', 't711', 'tjb1', 'twb2', 't622', 't082', 'tt21', 'tn2', 't221', 'td', 't13', 'td82', 'tx01', 't1s', 't982', 't3r1', 'tf42', 'tfn', 't0m'},
#  id= (831,), tags= {'td32', 'tgt1', 'tqz1', 'tm81', 'tzl', 'tpr', 't7k1', 't4w', 'tb7', 'trr'},
#  id= (768,), tags= {'tmj1', 't991', 'tsc', 'tjb1', 't5f1', 't6d2', 'tzb2', 't9k', 't5p1', 'thm1', 't152', 't4x'},
#  id= (348,), tags= {'t0j1', 'tbj', 'tg71', 'tdc', 't3z', 'tqp1', 't9h', 't1d1', 't7d', 'tqc', 'tmn', 'tv9'},
#  id= (351,), tags= {'t862', 'tnz1', 'tzn', 't1w', 'tk21', 't9h'},
#  id= (109,), tags= {'tl2', 't0h1', 'tw81', 'tzn', 't3m', 't242', 'tfk1', 't2s', 't881', 'tpn1', 'twb', 'tq91', 'tpr1', 'tf2'},
#  id= (403, 470), tags= {'tv81', 'tqb2', 'tdg1', 'tn3', 'tvz', 'tjj1', 't1g', 'trp1', 'ttb2', 'tq81', 'tj01', 't5w1', 't63', 'tn81', 'tq71', 't882', 'tsl', 'thh1', 'tdd1'},
#  id= (428, 525), tags= {'ttk1', 'txx1', 't1v', 't2c1', 't55', 'ts92', 't4f', 't351', 'tk22', 't801', 'tzd', 'tst', 'tc5', 'tjj1', 'ttb2', 't8b1', 'tb5', 't1', 'tgp1'},
#  id= (925,), tags= {'tg7', 'tct', 'tht1', 'tkt1', 'tp3', 'tz22', 'tkh1', 'th11'},
#  id= (38,), tags= {'tdr', 'tjs1', 't3c1', 't2t', 'tf32', 'tnl', 't7w', 'tdb2', 'tdp1', 'thp1', 'tb5', 'tsg', 'tv9'},
#  id= (970,), tags= {'tx71', 'tp41', 't3j1', 'tj92', 'tms', 'tqz', 't7x', 'tjr1', 'trz', 'tdd1'},
#  id= (17,), tags= {'t2m1', 'tqp1', 'tcx', 'tpd', 'tdz1'},
#  id= (593,), tags= {'t361', 't6q1', 'tqd1', 'tdg1', 'tk4', 't7j1', 'tv21', 't641'},
#  id= (479,), tags= {'t6r1', 'tfc2', 't512', 't3v1', 't3j1', 'tx91', 't5', 'tv61', 'tcl', 'tp7', 'trr', 'tkb2'},
# ...
#  id= (743,), tags= {'t3k', 'tjt1', 'tq5', 't8h', 't011', 't7d', 't001', 't221', 'tr51', 't291'},
#  id= (233,), tags= {'t671', 'tg2', 'tb21', 't6d2', 'tbq1', 'tc21', 't1v1', 'tdp', 'tgp1'},
#  id= (142,), tags= {'tk82', 'trk1', 'tzh', 'tc11', 'tnt1', 'thv', 't0w1', 'tt4', 'tvc1'},
#  id= (337, 716), tags= {'tdv', 'twc', 't072', 't991', 'tjb1', 't4t1', 'trv', 'tn4', 'tjx1', 'tqn1', 't7q1', 'tx51', 'tq62', 'tkf1', 'tpc', 'thz', 't3p', 't471', 'tv22'},
#  id= (253, 581), tags= {'t601', 'tt21', 'tfv', 't8m', 'tv32', 't88', 'thc1', 'ttz1', 'tkm1', 'ttw1', 't0t1', 'tkr1', 't8c2', 't3g', 'tfn1', 'trv1', 't8h', 't0b', 'tbm'},
#  id= (384, 701), tags= {'tdb', 't9z', 't3q', 'tcz1', 'tgb2', 'tmc', 'ts32', 't4x', 't2', 'tq81', 'tjv', 'thh', 't572', 'tqf', 'tmm1', 'twb1', 'tpd', 'tn22', 'tjw1'},
#  id= (860,), tags= {'t491', 'tn3', 'ts92', 'tqj1', 'tdv1', 'tsm', 'tjj1', 't332', 't13', 't561', 'tjw1'},
#  id= (219,), tags= {'t0j1', 'tvb', 'trv', 'tck', 'tnl1', 'tt21', 't4h1', 't252', 'tbm', 'tc6', 'thh1', 't0f1', 't0b1', 'tw51'},
#  id= (736,), tags= {'tqq', 't3q1', 'tj', 't141', 't2t', 'tt21', 'tlk1', 'tk1', 'tnl', 'tdn1', 'tdg'},
#  id= (292,), tags= {'tcv1', 't81', 't202', 't911', 'tt21', 'tkn1', 't882', 'tkp', 't3x1', 'tpt', 'tp1'},
#  id= (589, 458), tags= {'tl31', 'tjb1', 'tn3', 'tv2', 'tsp', 'tr82', 'trb1', 't1s', 'tb7', 'tgp1', 't5k', 't1t1', 'tqq', 't351', 'tvg1', 'tv1', 'tb02', 't23', 't861'},
#  id= (515,), tags= {'tc61', 'tzw', 'tr9', 'tc21', 't3z1', 'tx51'},
#  id= (125,), tags= {'t2m1', 'tq91', 'trt', 't8p', 'tx71', 'th42', 'tfz1', 'tx7', 't2m', 't692', 'tx', 'tc52', 't7n1', 'tdq1'},
#  id= (167,), tags= {'tt2', 't792', 'tcc', 'tld1', 'tsb1', 'tdk', 'tmh', 'tmr1', 't431', 't6d', 'tt'},
#  id= (699, 162), tags= {'tbf', 'th82', 'tx71', 'tq3', 'tsp', 'tmc2', 'tq1', 'tr82', 't532', 'ttb2', 't4x', 'tkm', 'th11', 'td41', 'tzn', 'tt72', 'tcl', 'tdp1', 'tgj'},
#  id= (759, 297), tags= {'tnw1', 'tkf', 't82', 'tsg1', 'tb4', 'tn51', 't81', 'tj82', 't4c2', 't921', 'tdf', 't9x1', 'twz', 'thp1', 'tdb2', 'tq81', 't762', 'td02', 'tkz'},
#  id= (704,), tags= {'t711', 'tx3', 't482', 'tm9', 'tzl', 'tjr1', 'tzf', 'tq21', 'tll', 'tff1', 'tr51', 't9t1'},
#  id= (859,), tags= {'tr82', 'tq52', 't312', 'ttb2', 'tlz1'},
#  id= (554,), tags= {'tg7', 't55', 'tt21', 't5z1', 't9q1', 't5t1', 'tng1', 't102', 'tb71', 'trx'},
#  id= (441,), tags= {'t802', 't4d1', 'th1', 'tnf', 'tjt', 'tjz'},
#  id= (520,), tags= {'t0h1', 't522', 'tnj', 't5t', 'tld1', 't3g', 't8l1'},
#  id= (666, 368), tags= {'trw', 'tj4', 't5p', 'tqh', 'thc1', 'tdb2', 'tj8', 't1', 't6c', 't4s', 'ttw1', 'tmx', 't8n', 't33', 'tf21', 'tr5', 'tm01', 'tzx', 'tdd1'},
#  id= (159,), tags= {'t711', 'tt6', 'tgt1', 'txf1', 't3b1', 'tzq1', 'tc2', 't74', 't561', 't82'},
#  id= (7,), tags= {'t2m1', 'twg1', 'ttc', 'tdm1', 't5p1', 'tk6', 't2x1', 'tjp'},
#  id= (367,), tags= {'t2m1', 'tb01', 'tx5', 't93', 'tzr', 'tsm', 'tpn1', 'tr1', 't8j', 'tdp1', 'tnj', 't6c', 't861'},
#  id= (449, 392), tags= {'t3p1', 'thw1', 'tql', 'tk52', 'tj82', 'tqh', 'tn4', 'tch', 'thb1', 'tm42', 'tp62', 'tgt1', 't41', 'thd', 'tlm', 'tbm', 'tqg1', 't382', 't861'},
#  id= (62,), tags= {'tp32', 't5f', 'tqb', 'tr5', 'txh', 't8b1', 'tw52', 'tt'},
#  id= (734,), tags= {'tvl1', 'tvj1', 'tf41', 't1', 'tr42'},
#  id= (852,), tags= {'t76', 't2d', 't0c', 'tkc1', 't6z1', 't532', 'tdp1', 'tkx', 'tr42'},
#  id= (468,), tags= {'td41', 'tbb1', 'tpg1', 't1w', 'tn3', 'tpc', 't5q', 'ttx', 'tk62', 'tc6', 't4n1', 'tw', 't9j1'},
#  id= (92,), tags= {'tqx', 't691', 't4d1', 't9k', 'tz12', 'tvs1', 't9s1', 'tl9', 't86', 'tvl1', 't0f1', 't4c2'},
#  id= (888,), tags= {'tk82', 'tx11', 'tnm', 't511', 't13', 'txj1', 'tnt', 'tdp1', 't4q1', 'trx'},
#  id= (535, 455), tags= {'t942', 't121', 't9c1', 't011', 't1s', 't462', 'tlg1', 'tm42', 'tq72', 'tds1', 't071', 'tmm1', 'tc5', 'txh', 'tr1', 'tc21', 't1v1', 't5v1', 't3l'},
#  id= (418, 469), tags= {'tqb2', 'tcf', 't7w', 'trc1', 't762', 't0b1', 'tjt', 'tt4', 't19', 'tt6', 'tld1', 't4', 'thz', 't3p', 't2p1', 'tmw', 'tq01', 'th8', 't2v'},
#  id= (353, 459), tags= {'t3k', 'tzk1', 't64', 'tbn1', 'tl31', 'tbz1', 't66', 't612', 't192', 'tp3', 't7m1', 'td', 'tqw', 'ttb1', 'tw52', 'tt22', 'tb7', 'tlj', 'tdg'},
#  id= (752, 243), tags= {'t3k', 'tq3', 'tm1', 'tdn', 'tft', 't1g', 't452', 'th1', 'tmj1', 't391', 'tf22', 't512', 'tn12', 't0w1', 'tft1', 'tzc2', 'tf42', 't5r1', 't632'},
#  id= (595, 244), tags= {'t2m1', 'tkf', 't4b1', 'tb32', 'tm1', 'tlb1', 't6d2', 'tx41', 'tmd', 't081', 'tn12', 'tl9', 'tzw', 'tb51', 't3x1', 'thp1', 'twz', 't221', 'txs1'},
#  id= (771,), tags= {'tw11', 't461', 'tfd', 'tn81', 'tks1', 't9b2', 'trk', 't0d1', 't762', 'tx01', 'ttz1', 'tq21', 't4d2', 'tx31'},
#  id= (818, 953), tags= {'t6z', 'tlj1', 'tvc2', 't9c', 'tn81', 'tdn', 'tnm', 't0l', 't4', 'tq52', 't3x1', 't7w', 't762', 'tl8', 't4q1', 'tv02', 'trg1', 't0b1', 'tzt1', 't751'},
#  id= (810, 984), tags= {'tkf', 'tjs1', 'tzg', 'trv', 'tc51', 't8m1', 'twp', 'tpb2', 't242', 'tc11', 'tbg1', 'tg71', 'tt12', 'tc22', 'tft1', 't762', 'trc1', 'thk1', 'td71', 'td62'},
#  id= (878,), tags= {'t4m', 't2b1', 'tc82', 't532', 'thr', 'tjr1', 't1v1', 't221', 'tr42', 'tt'},
#  id= (875,), tags= {'tjb', 'tfb1', 'tqk1', 't511', 'tsz', 'tbm', 'twz', 'tw42'},
#  id= (693,), tags= {'t0v', 'tcv1', 't3c', 'tq32', 'tt82', 'tsm1', 'tjh1', 'tcn'},
#  id= (732,), tags= {'t7n1', 't361', 't002', 'tm71', 't5f1', 't92', 'twp1', 'tn81', 'tkq', 't4p1', 't2', 'txr1', 'tvq', 't5v1'},
#  id= (346,), tags= {'tsx1', 'tl9', 'tlm', 'tl91', 'tpc1', 't7p1', 'tth1'},
#  id= (123, 763), tags= {'t342', 'tfx', 't5q', 'tgm', 'tx2', 'tt21', 'tdc1', 't29', 't6z1', 't501', 't9d1', 'td51', 'tvj1', 'tb02', 'thc', 'thg1', 't7p1', 't7n1', 'tzm1'},
#  id= (608, 452), tags= {'tx41', 'tsb2', 'tfr1', 'ttb2', 't891', 'tzf', 't462', 'tpj', 't0r1', 't6d2', 'tz2', 'tvs1', 'tr5', 'tqp1', 't1m', 't0w', 't181', 'tlm1', 'tm9'},
#  id= (725,), tags= {'th1', 't361', 'th6', 'tb', 'tt3', 'tr5', 'tr32', 't7j', 't921', 't0g1', 'tg21', 'th8', 't861', 'tfj'},
#  id= (356,), tags= {'twg1', 'tqv1', 'tq81', 'tp41', 'tkr', 't7v', 'thn'},
#  id= (965, 853), tags= {'t852', 't0z', 't3m', 'tx71', 't4t1', 'tn3', 'tbv', 't4f', 'tt8', 'tp9', 'tvh', 'tr5', 't86', 'tjz1', 'tp31', 't181', 't0f1', 't8l1', 'txd1'},
#  id= (364,), tags= {'tvf1', 'tqb2', 'tqf', 'tz21', 't221', 't5q1', 'tc21', 'tq81', 'tnj', 't1r', 't4d2', 'tr51'},
#  id= (604,), tags= {'t76', 't8n', 'tkg1', 'tz31', 'tt82', 'tb62', 'twn1', 't7n1', 'tf2'},
#  id= (767,), tags= {'tz81', 't86', 't5c2', 'tld1', 'tsx', 'tzt1'},
#  id= (784,), tags= {'tm81', 'tbm', 'tpt1', 't74', 't332'},
#  id= (999, 8), tags= {'t76', 'tz9', 't3j1', 'tc61', 'tlf', 't561', 't1', 'tqx', 'tcd', 'tpc', 't911', 'tl51', 'tr5', 't3t', 'tk6', 't031', 't4q', 'tdd1', 'tm9'},
#  id= (375, 437), tags= {'txf1', 'tqb2', 'ttl1', 'tqf', 't2t', 'tkx1', 'tdj', 'ttc2', 'tk22', 't332', 't33', 'trp1', 't3t', 't4m1', 't8j', 'twz', 't0f1', 'tn72', 'tzt1'},
#  id= (48,), tags= {'tpg1', 't3c1', 'tmd', 'tk22', 'tr82', 'tb9', 'td7', 'tt9', 'tlm', 'twz', 't78'},
#  id= (723,), tags= {'tgt1', 'tc51', 'tpb2', 't622', 'tnv', 'ttf', 't001', 'tn12', 'tz82', 't0x', 't4n1', 't6r', 'tgj', 't1'},
#  id= (682,), tags= {'t3k', 'tn81', 'tz9', 'tqz1', 'trs1', 'trr1', 'td82', 't602'},
#  id= (119, 988), tags= {'twg1', 'tn7', 'tjb', 'tt21', 'tc61', 'td', 'tvl', 'txc', 'tf02', 'ts22', 'tdp', 't6c', 'tmj1', 'tfc2', 'tnq', 't332', 'tvf', 't001', 't902'},
#  id= (68, 929), tags= {'t2m1', 't991', 't81', 't4d1', 'tpn', 'tqz1', 'trm1', 'tb5', 'tx1', 't291', 't1x1', 'tk31', 'tkr1', 'tw62', 'ttt', 'tln1', 't6t1', 'tkh', 'tdg'},
#  id= (248, 800), tags= {'t691', 't991', 't4t1', 't9f', 'tvh', 'tr82', 't7c2', 't7d', 'tf01', 'txf1', 'tkf1', 'tpc', 't6d2', 'tbk1', 't882', 'twn1', 'thk', 'tzk1'},
#  id= (457,), tags= {'ttk1', 'tz02', 'tm52', 'tj82', 'tv32', 't131', 'tqv', 'tpn1', 't821', 't1r', 'tjt', 'tk72'},
#  id= (120,), tags= {'tm9', 'tzg', 't38', 'tkc1', 't6k1', 't3x1', 'tr1', 'trh', 'tnf', 'tzm1'},
#  id= (189,), tags= {'tkf', 't6z', 't1', 'tdg1', 'tpc', 'tpc1', 'tpd', 'td82', 't6c', 'tmz'},
#  id= (462,), tags= {'tsq', 'tx71', 'tdm1', 't1n', 'tx41', 'tl1', 'td92', 'tvk', 't532', 't762', 't0b1'},
#  id= (476, 524), tags= {'t5n1', 'txh1', 'tqj1', 'tc61', 't2', 'tn4', 'tns', 't0f1', 'tt61', 't48', 't1n1', 'tq92', 't5p1', 'tfl', 't911', 'tc5', 'trq1', 't5c', 't9d1'},
#  id= (998,), tags= {'tpl', 't3p1', 'tfc2', 't42', 'tjj1', 'tdk', 't311', 't24', 't6c', 'tvc1'},
#  id= (322, 543), tags= {'tw81', 'tsv1', 't942', 'tbd1', 't622', 'tx32', 'tnx1', 'tx21', 'tv', 't0b1', 't212', 'tbc2', 't3m', 't6t', 'tlh', 'ttp1', 'thp1', 't7b1', 'tdd1'},
#  id= (715, 151), tags= {'tx1', 't3q1', 'tfk1', 't9k', 'tx41', 'tkc1', 'tk22', 't302', 'thc1', 't3w', 't921', 't692', 'tdp1', 'thx1', 't602', 'tgj1', 'tzk1', 't7n1', 'tjw1'},
#  id= (34,), tags= {'tvc2', 't6t', 'tbv', 't9s1', 'tz91', 't351', 'tnr', 'tv32', 't882', 't9d1', 'tr2', 't7q1'},
#  id= (111,), tags= {'tg7', 't991', 'txz1', 'tqk1', 't3p', 't2m', 'tl9', 'tcl', 'tqc', 't9w1'},
#  id= (980, 20), tags= {'tj21', 'tf', 'tvw', 'tv32', 'txr', 't2x1', 'tqc', 'tvr', 'tmf', 't112', 'tvc2', 't3g', 'trh1', 'tvs1', 't6w', 't8q', 'tcl', 't0g1', 't5x'},
#  id= (747,), tags= {'tcv1', 't0j1', 'tl21', 'tpc', 'tc5', 'tpb'},
#  id= (718,), tags= {'t0j1', 'thx', 'tqq', 't4d1', 'tt11', 'tq2', 'tr5', 'ttz', 'tbc', 'tgp1'},
#  id= (258,), tags= {'t3p', 't231', 'tv91', 't9h', 'tmh', 't33'},
#  id= (267,), tags= {'t2c', 'ttk1', 'tlr1', 'tz02', 'tv8', 'tbj', 'tq52', 't7d1', 'tsg'},
#  id= (648,), tags= {'t481', 't6r1', 't911', 'tq52', 'td', 'tkp', 't8h', 't011', 'tdp1', 'tbh', 't1', 'th11'},
#  id= (569,), tags= {'tmj1', 'tzw', 't64', 'tkt1', 'tg1'},
#  id= (300,), tags= {'td41', 'tsh1', 'tkf', 'tc51', 'thc', 'tcf', 'tst', 'tnt', 't692', 't311', 't471', 'thr', 't6m'},
#  id= (487, 537), tags= {'t2k', 'tn3', 't9m1', 'tq51', 'tg3', 'tvh', 'trt1', 'tql1', 'tpr1', 'tqx1', 'tvr', 'tp71', 'tsg', 'tn51', 'tpg1', 'tn81', 'tft1', 't8h', 'thq'},
#  id= (706,), tags= {'tr02', 'tk82', 'tn51', 't7f', 't8w1', 't622', 'twk1', 't312', 'tr1', 'tpx1', 't181', 't452', 'trx'},
#  id= (380,), tags= {'thj1', 'trc1', 't1v1', 't4l', 't111', 't2q', 't6g'},
#  id= (711, 165), tags= {'tmj1', 't2n', 't3m', 't1w', 'tzs1', 'tm5', 'tm7', 'tqh1', 'tl61', 'tlm', 'trc1', 'tc21', 'tq01', 'tr1', 't001', 'tnj', 't0l1', 'tm61', 'tv8'},
#  id= (607, 454), tags= {'tjc', 'tg72', 'tts1', 'tpb2', 't131', 'tg4', 'tvh', 'tb62', 'tz22', 'tpp1', 'tf01', 'tr02', 't342', 'tkr1', 't961', 'tq01', 'thg1', 'thk1', 'tvk'},
#  id= (728,), tags= {'t412', 'tq22', 'tht1', 't5f1', 't622', 'tlh1', 't2', 'tn4', 'trm', 't2x1', 't3l', 'tgp1', 'th11', 'tdg'},
#  id= (361,), tags= {'t63', 'tcn1', 'tz91', 'tz82', 't9x1', 'tw22', 'tf42', 't9j1', 'th12', 'tl22'},
#  id= (687,), tags= {'thj1', 't4g1', 'tbj', 'tvb1', 'ttq', 'tr82', 'tqh', 't3h1', 'th91'},
#  id= (315,), tags= {'t78', 'tv92', 'tm02', 't0c', 't8m', 't861', 'tv4'},
#  id= (23,), tags= {'tt11', 'tk22', 'tg22', 't952', 't1c', 't402', 't1s', 't74', 'ttm', 'tzt1', 't0d2', 'tf2'},
#  id= (85, 12), tags= {'t711', 't691', 't3b', 'txv', 'twc2', 'tt4', 't232', 't6t', 'tpb', 'tt51', 'tv61', 'tcl', 't44', 't001', 't3d1', 't0l1', 't721', 'tdg'},
#  id= (611,), tags= {'t9q1', 't38', 't7p1', 't7d', 'tbj', 'tlt', 'tpn'},
#  id= (312,), tags= {'tqv', 'tnj', 'tkr1', 'th42', 't0s', 't9q', 'tjj1'},
#  id= (877,), tags= {'t8l', 'txj', 'tt72', 'tn81', 'tld1', 't26', 't001', 't0g', 'tfg1', 'tnc2', 'tqp1', 'tdk1', 'tx51'},
#  id= (310, 714), tags= {'tdr', 't4t', 'tx41', 'tsz', 'twk', 't83', 't1s', 't9j1', 'tp5', 'tmv1', 't4v1', 't662', 'tpc1', 't66', 'tww', 'tft1', 'tg52', 'tls1', 't291'},
#  id= (935,), tags= {'tg7', 't7v1', 't8j1', 'tqv1', 'tvz', 't141', 'tk22', 'twz', 't861'},
#  id= (448,), tags= {'tn81', 't6b1', 'tfc1', 'trd1', 'tl6'},
#  id= (976,), tags= {'thl1', 't2', 'td51', 't6n1', 't2z1', 't66'},
#  id= (983,), tags= {'tgl', 't3n', 'tp81', 'tnj', 't6h', 't7l1', 'tvr'},
#  id= (637, 383), tags= {'tjq1', 't9t', 't6r1', 'tq51', 'tnm', 'tx41', 'tj82', 'tqv', 't2', 'txg', 't762', 't5b', 'th61', 't5w1', 't3b1', 'tbv', 't2m', 'thr', 't221'},
#  id= (477,), tags= {'tr5', 'tjf1', 'thb1', 'trr', 'tv9'},
#  id= (802,), tags= {'tk31', 'tgt1', 'tfz1', 'tfc2', 't082', 't351', 't7b2', 'tgc2', 't7k1', 't471', 'tz22', 'tzt1', 't0l1', 'tsg'},
#  id= (827,), tags= {'tgc', 'tsq1', 'tcf', 'tmx1', 'tx01', 'thc', 'tg32', 'td62'},
#  id= (575,), tags= {'tjs1', 'tx71', 'tp41', 'tm42', 't0l1', 'tsg'},
#  id= (883, 153), tags= {'tp32', 't161', 'tdj1', 't3p1', 'tx41', 't881', 'tj82', 't1l1', 't4x', 'tqh', 'ttz1', 't462', 'tb7', 't7q1', 'tr02', 'tbl1', 't9k', 'tvs1', 'trl'},
#  id= (645,), tags= {'tdv', 'tr02', 't57', 'twp', 't64', 'tdz1', 'tkt1', 'tt11', 'tf72', 'tm81', 't7w', 't6h', 'tvr', 'ttb'},
#  id= (302,), tags= {'tkf', 't232', 'tbn1', 't0j1', 'td1', 't2p', 't131', 'thn', 'tdp1', 't6r', 't641', 'tnj'},
#  id= (632, 422), tags= {'t691', 'tw81', 'tr72', 't1p1', 'tw72', 't141', 'tjj1', 'tr82', 'ttx1', 'tm9', 't55', 'txc1', 'td7', 't0w1', 't3x1', 'tgk1', 'thr', 't0l1', 'tn5'},
#  id= (467,), tags= {'t3r1', 'tht1', 'tdz1', 'tvz1', 'tcr', 'tx41', 'tnl', 'ttf1', 'tn71', 'tt9', 'ttc1', 't001'},
#  id= (597,), tags= {'t64', 'tpg1', 'thp', 'tsv1', 't0t1', 'tb31', 'tm7', 't5s1', 'tv9'},
#  id= (890,), tags= {'t8l', 'tt7', 'tmq1', 'tbh', 'tq31', 't4r', 'tk61', 'txj1', 'tbb2', 't4s1', 'tzp1', 'tq91', 'tvr', 'tvc1'},
#  id= (228,), tags= {'tdg1', 'tfz1', 'th21', 'tzx1', 't001', 'tkj', 'tnl', 'tg71', 'tfc1', 't2x1', 't181', 'tzk1'},
#  id= (785,), tags= {'td71', 'tzk1', 'tz02', 't55', 't572', 't0f1', 'tzr'},
#  id= (951,), tags= {'t2m1', 'trt', 't6t', 't8h1', 't6d2', 'tm02', 'tp6', 'tqc', 't1c1', 't561', 't7n1'},
#  id= (658,), tags= {'tcn1', 'tw11', 't81', 'tn3', 't421', 'th61', 'tt92'},
#  id= (815,), tags= {'tkf', 'tht1', 't4k', 'trk', 'tn71', 't2', 'tlm', 'tm42', 't771'},
#  id= (819,), tags= {'t0r1', 'tl9', 't4h', 't9c', 't81', 't2x1', 'tj82'},
#  id= (663,), tags= {'twr', 't76', 'tvs1', 't001', 'tv', 'tpd', 't1s', 't1v1', 't4m1', 'tf2'},
#  id= (400,), tags= {'tj91', 'tbw', 't6q1', 'tm52', 'tww', 'tn4', 'tw52', 'tkh1', 'tzm1'},
#  id= (551,), tags= {'tvc1', 't0j1', 'tqv1', 'tnj1', 't8h1', 'tfq1', 'tnl', 'thp1', 'tnr1', 'tqc', 'tvk', 'tzm1'},
#  id= (245,), tags= {'tw2', 't15', 't68', 'trr', 'tw5', 'twq', 'tfh1', 't0f1', 't1v1', 't4d2'},
#  id= (498, 494), tags= {'tzg', 'tv81', 't9w', 't881', 'tv32', 'tc61', 'tq52', 't7k1', 'tqc', 'tdp', 't212', 'tn51', 't4g1', 'tlh', 'ttd', 't3p', 'thb2', 'twz', 'tl6'},
#  id= (269, 765), tags= {'t5s', 'tr22', 't38', 'tpb2', 't4d1', 't1q', 'tq52', 't4x', 'tr9', 'tb5', 't9z1', 'tr81', 't19', 't232', 'ttj', 'tpn1', 't3p', 't8b1', 'tdd1'},
#  id= (882, 182), tags= {'t3k', 't3c1', 't8d1', 'tsw', 'tz9', 't881', 'tbv1', 'tgb2', 'tms', 'tc8', 'thq', 'tlz', 'thb1', 't6x', 'tgp1', 't8l1', 'th11', 'tf2'},
#  id= (738,), tags= {'trt1', 't6m1', 'tv1', 'tb5', 'tm7', 'tn5'},
#  id= (331, 612), tags= {'ttk1', 'tmb2', 't481', 'tl31', 't812', 't19', 'tkr1', 'tz12', 'tgb2', 'twv1', 'tsv', 'thg1', 'tg81', 't011', 'tz22', 't3d1', 'trr', 't6c', 'tv9'},
#  id= (46, 825), tags= {'t8l', 't0h1', 't4b', 'tqq', 'tqb2', 'tkt1', 'tfk1', 'tx41', 'tmw1', 't511', 'tgb2', 'tk6', 'tfr1', 't921', 't091', 'tcq', 't1s', 'tgn', 't011'},
#  id= (496, 372), tags= {'t3p1', 'tz9', 'tx41', 't511', 't3k1', 'tm81', 'tcw1', 'tgn', 'tv31', 'tj8', 'tpr1', 'tkf', 'tt6', 'tfc2', 't4r', 'tbm', 'tz82', 'tgj', 't0s'},
#  id= (552, 475), tags= {'tdn', 't301', 'tvh', 'tq52', 'tp', 'thc1', 'tl7', 'tx01', 'tjt', 'tf01', 't28', 'tzr', 'twd1', 'tt82', 't4c1', 't311', 't9d1', 'tvk', 'td62'},
#  id= (334,), tags= {'twg1', 'tzg', 'tbv', 'tpr1', 't001', 'thn'},
#  id= (55, 801), tags= {'t481', 't0j1', 'tpg1', 'tn3', 'tkt1', 'tvp', 't28', 'td', 'twv1', 'td7', 'tpd', 'tjx1', 'tb92', 't181', 'tpr1', 'tq11', 't7p1', 'tcb2', 'tfj'},
#  id= (79, 814), tags= {'tk82', 'tj91', 't4v', 'tcv1', 'tsx', 'tqz1', 'tz9', 'tv', 't912', 't8c', 'tqc', 't65', 't452', 't822', 't1w', 'tj6', 'tdd', 'tpd', 't12'},
#  id= (536,), tags= {'tpc1', 'tbv', 'tqz1', 't4j', 'tsr1', 't9d1', 'tzt1', 't291'},
#  id= (306, 553), tags= {'t2m1', 'tx71', 't76', 'tm1', 'tx41', 't09', 't6z', 'tgt1', 'tzn', 'tzc1', 'tbv', 'tn12', 'tt82', 't52', 't8z', 't181', 'tl6', 't9p'},
#  id= (914,), tags= {'tc51', 'tv72', 'tsw', 't971', 'tn81', 'tgf1'}]

# %%
sh = SlideShow(a, None)

# %%
write_Slideshow_to_file(sh, "output_c.txt")

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("b_lovely_landscapes.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals

# %%
b_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200)
# Out:
# Initial distance: -33.0
# -- iteration 0 --
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-b75d635abc2c> in <module>()
# ----> 1 b_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200)
#
# <ipython-input-29-d6fbcc2763c8> in geneticAlgorithm(population, popSize, eliteSize, mutationRate, generations)
#       6         if (i%10 == 0):
#       7             print("-- iteration %d -- " % i)
# ----> 8         pop = nextGeneration(pop, eliteSize, mutationRate)
#       9
#      10     print("Final distance: " + str(1 / rankRoutes(pop)[0][1]))
#
# <ipython-input-12-3664d27a38a8> in nextGeneration(currentGen, eliteSize, mutationRate)
#       3     selectionResults = selection(popRanked, eliteSize)
#       4     matingpool = matingPool(currentGen, selectionResults)
# ----> 5     children = breedPopulation(matingpool, eliteSize)
#       6     nextGeneration = mutatePopulation(children, mutationRate)
#       7     return nextGeneration
#
# <ipython-input-9-ddecda5fd205> in breedPopulation(matingpool, eliteSize)
#       8
#       9     for i in range(0, length):
# ---> 10         child = breed(pool[i], pool[len(matingpool)-i-1])
#      11         children.append(child)
#      12     return children
#
# <ipython-input-8-114ce1284ef4> in breed(parent1, parent2)
#      13         childP1.append(parent1[i])
#      14
# ---> 15     childP2 = [item for item in parent2 if item not in childP1]
#      16
#      17     child = childP1 + childP2
#
# <ipython-input-8-114ce1284ef4> in <listcomp>(.0)
#      13         childP1.append(parent1[i])
#      14
# ---> 15     childP2 = [item for item in parent2 if item not in childP1]
#      16
#      17     child = childP1 + childP2
#
# KeyboardInterrupt:

# %%
sh_b = SlideShow(b_file, None)
write_Slideshow_to_file(sh_b, "output_b.txt")

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("d_pet_pictures.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals
d_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200)

# %%
sh_d = SlideShow(d_file, None)
write_Slideshow_to_file(sh_d, "output_d.txt")

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("e_shiny_selfies.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals
e_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200) 
sh_e = SlideShow(e_file, None)
write_Slideshow_to_file(sh_e, "output_e.txt")

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("a_example.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals
a_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200) 
sh_a = SlideShow(a_file, None)
write_Slideshow_to_file(sh_a, "output_a.txt")
