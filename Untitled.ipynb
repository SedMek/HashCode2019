# %%
from classes import *
import numpy as np, random, operator, pandas as pd, matplotlib.pyplot as plt

# %%
class Fitness:
    def __init__(self, route):
        self.route = route
        self.distance = 0
        self.fitness= 0.0
    
    def routeDistance(self):
        if self.distance ==0:
            pathDistance = 0
            for i in range(0, len(self.route)):
                fromCity = self.route[i]
                toCity = None
                if i + 1 < len(self.route):
                    toCity = self.route[i + 1]
                else:
                    toCity = self.route[0]
                pathDistance += fromCity.distance(toCity)
            self.distance = pathDistance
        return self.distance
    
    def routeFitness(self):
        if self.fitness == 0:
            self.fitness = 1 / float(self.routeDistance())
        return self.fitness

# %%
def createRoute(cityList):
    route = random.sample(cityList, len(cityList))
    return route

# %%
def initialPopulation(popSize, cityList):
    population = []

    for i in range(0, popSize):
        population.append(createRoute(cityList))
    return population

# %%
def rankRoutes(population):
    fitnessResults = {}
    for i in range(0,len(population)):
        fitnessResults[i] = Fitness(population[i]).routeFitness()
    return sorted(fitnessResults.items(), key = operator.itemgetter(1), reverse = True)

# %%
def selection(popRanked, eliteSize):
    selectionResults = []
    df = pd.DataFrame(np.array(popRanked), columns=["Index","Fitness"])
    df['cum_sum'] = df.Fitness.cumsum()
    df['cum_perc'] = 100*df.cum_sum/df.Fitness.sum()
    
    for i in range(0, eliteSize):
        selectionResults.append(popRanked[i][0])
    for i in range(0, len(popRanked) - eliteSize):
        pick = 100*random.random()
        for i in range(0, len(popRanked)):
            if pick <= df.iat[i,3]:
                selectionResults.append(popRanked[i][0])
                break
    return selectionResults

# %%
def matingPool(population, selectionResults):
    matingpool = []
    for i in range(0, len(selectionResults)):
        index = selectionResults[i]
        matingpool.append(population[index])
    return matingpool

# %%
def breed(parent1, parent2):
    child = []
    childP1 = []
    childP2 = []
    
    geneA = int(random.random() * len(parent1))
    geneB = int(random.random() * len(parent1))
    
    startGene = min(geneA, geneB)
    endGene = max(geneA, geneB)

    for i in range(startGene, endGene):
        childP1.append(parent1[i])
        
    childP2 = [item for item in parent2 if item not in childP1]

    child = childP1 + childP2
    return child

# %%
def breedPopulation(matingpool, eliteSize):
    children = []
    length = len(matingpool) - eliteSize
    pool = random.sample(matingpool, len(matingpool))

    for i in range(0,eliteSize):
        children.append(matingpool[i])
    
    for i in range(0, length):
        child = breed(pool[i], pool[len(matingpool)-i-1])
        children.append(child)
    return children

# %%
def mutate(individual, mutationRate):
    for swapped in range(len(individual)):
        if(random.random() < mutationRate):
            swapWith = int(random.random() * len(individual))
            
            city1 = individual[swapped]
            city2 = individual[swapWith]
            
            individual[swapped] = city2
            individual[swapWith] = city1
    return individual

# %%
def mutatePopulation(population, mutationRate):
    mutatedPop = []
    
    for ind in range(0, len(population)):
        mutatedInd = mutate(population[ind], mutationRate)
        mutatedPop.append(mutatedInd)
    return mutatedPop

# %%
def nextGeneration(currentGen, eliteSize, mutationRate):
    popRanked = rankRoutes(currentGen)
    selectionResults = selection(popRanked, eliteSize)
    matingpool = matingPool(currentGen, selectionResults)
    children = breedPopulation(matingpool, eliteSize)
    nextGeneration = mutatePopulation(children, mutationRate)
    return nextGeneration

# %%
def geneticAlgorithm(population, popSize, eliteSize, mutationRate, generations):
    pop = initialPopulation(popSize, population)
    print("Initial distance: " + str(1 / rankRoutes(pop)[0][1]))
    
    for i in range(0, generations):
        if (i%10 == 0):
            print("-- iteration %d -- " % i)
        pop = nextGeneration(pop, eliteSize, mutationRate)
    
    print("Final distance: " + str(1 / rankRoutes(pop)[0][1]))
    bestRouteIndex = rankRoutes(pop)[0][0]
    bestRoute = pop[bestRouteIndex]
    return bestRoute

# %%
import joblib as jb

def write_Slideshow_to_file(slideshow, output_name = "sexybaby.txt"):
    with open(output_name, "w") as file:
        file.write("{}\n".format(len(slideshow.slides)))
        for slide in slideshow.slides:
            ID = slide.id
            if len(ID) == 1:
                file.write("{}\n".format(ID[0]))
            else:
                file.write("{} {}\n".format(ID[0], ID[1]))

#Create a set of slides following the rationale of the groupment by biggest tags
def get_horizontals_from_collection(collection, groupby="average", filename=""):
    
    #Create a set of vertical and horizontal pictures
    null_photo = Photo(orientation="", tags=[])
    collection_V = []
    collection_H = []

    for photo in collection:
        if photo.orientation == "V":
            collection_V.append(photo)
        else:
            collection_H.append(photo)

    ##### Sort pictures in place by number of tags
    collection_V.sort(key=lambda photo: len(photo.tags), reverse=True)
    collection_H.sort(key=lambda photo: len(photo.tags), reverse=True)
    
    ##### generate slides
    m = len(collection_V)
    slides_fromVerticals = []
    index = 0
    if groupby == "2by2":
        while index < m:
            slides_fromVerticals.append(Slide([collection_V[index], collection_V[index+1]]))
            index += 2
    else:
        if m %2 == 1:
            collection_V = collection_V[1:]
        for i in range(m//2):
            slides_fromVerticals.append(Slide([collection_V[m - 1 - i], collection_V[i]]))
    
    slides_fromHorizontals = [Slide([photo]) for photo in collection_H]
    jb.dump(collection_V, "collection_V_{}.joblib".format(filename))
    jb.dump(collection_H, "collection_H_{}.joblib".format(filename))
    jb.dump(slides_fromVerticals, "slides_fromVerticals_{}_{}.joblib".format(groupby,filename))
    jb.dump(slides_fromHorizontals, "slides_fromHorizontals_{}.joblib".format(filename))
    return slides_fromVerticals, slides_fromHorizontals

def get_horizontals_from_file(filename, groupby="average"):
    return jb.load("slides_fromVerticals_{}_{}.joblib".format(groupby, filename)), jb.load("slides_fromHorizontals_{}.joblib".format(filename))

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("c_memorable_moments.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals

# %%
a = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200)
# Out:
# Initial distance: -172.0
# -- iteration 0 --
# -- iteration 10 --
# -- iteration 20 --
# -- iteration 30 --
# -- iteration 40 --
# -- iteration 50 --
# -- iteration 60 --
# -- iteration 70 --
# -- iteration 80 --
# -- iteration 90 --
# -- iteration 100 --
# -- iteration 110 --
# -- iteration 120 --
# -- iteration 130 --
# -- iteration 140 --
# -- iteration 150 --
# -- iteration 160 --
# -- iteration 170 --
# -- iteration 180 --
# -- iteration 190 --
# Final distance: -226.99999999999997

# %%
a
# Out:
# [id= (631, 424), tags= {'td7', 't1k1', 't0l1', 'tbv', 't161', 't7q1', 'tlh1', 'twz', 'tz61', 'tr82', 'tbp1', 'tjb1', 'tq91', 't9z1', 't0g1', 'tqj', 'tqb2', 'tl72', 'tbv1'},
#  id= (627,), tags= {'t32', 'tv32', 'tpb2', 't6r', 'tn12', 'tvs1', 't8n', 't332', 'tt02', 'tz61', 't0s'},
#  id= (532,), tags= {'tw81', 't3w', 'tfz', 't3k', 't8l', 't651', 't0x', 'tnz1', 'tz22', 't001', 'tjn'},
#  id= (107,), tags= {'tgq1', 'tl6', 't9h', 'tnm', 'tf22', 'tsr1'},
#  id= (629,), tags= {'tw81', 't3m', 'tpb', 't1j1', 't391', 't512', 'tt21', 't6t', 't8s', 'ttc', 't432', 't152'},
#  id= (974, 894), tags= {'tgc', 'th1', 'ttr1', 't88', 'tl3', 't6x', 'tnf', 'td41', 't6t', 'ttt', 't0w1', 'tr2', 'tf2', 'thg1', 't561', 'tt32', 'tjj1', 't511', 'tk6', 'tjc2'},
#  id= (421,), tags= {'tbw1', 'tsw', 'th42', 'tfj', 't672', 'tdp', 't692', 'tb92', 'th11'},
#  id= (55, 801), tags= {'td7', 'tq11', 't0j1', 'td', 'tpg1', 'tjx1', 't481', 'tfj', 'tpr1', 'tcb2', 'tkt1', 'tpd', 'tn3', 't7p1', 't28', 't181', 'tb92', 'twv1', 'tvp'},
#  id= (84, 797), tags= {'tj82', 't011', 't2q', 'tj32', 'ttf1', 't7q1', 't9f1', 'tm81', 'tj', 'tdn1', 't771', 'tfr1', 'tqv1', 'th62', 't3r1', 't76', 't691', 't921', 'tgx1'},
#  id= (41,), tags= {'t531', 'tqq', 't422', 'trk', 'tgb2', 'tq31', 'tqq1', 'tr92', 'tz91', 't1g'},
#  id= (779,), tags= {'tk22', 'thd', 'tpg1', 't162', 't1s', 'tsr', 'tr1', 'td51', 't512', 't212', 'twv1', 'tt', 'tc42', 'ttc1'},
#  id= (907,), tags= {'tgj', 't3x1', 'tf2', 'tbz', 'tgb1', 'tfj', 'tfp', 'tvs1', 't55', 't921', 'thp1'},
#  id= (596,), tags= {'t7d1', 'tf2', 'th61', 't672', 'tl6', 'thb1', 'tqs', 'tz6', 't6z'},
#  id= (734,), tags= {'tvl1', 'tf41', 'tr42', 't1', 'tvj1'},
#  id= (696, 169), tags= {'tgc', 't431', 'thh1', 'tkr1', 't951', 'tk9', 'thj1', 'tv7', 'tb', 'tww', 'tnr', 'tr51', 'tk51', 'tdn1', 't1s', 'thg1', 'tgb2', 'tm42', 'tc62'},
#  id= (311,), tags= {'t771', 'tmj1', 't2l', 'tfr1', 'tc61', 'tnd1', 't452', 'tr31', 'tg71'},
#  id= (824, 130), tags= {'tr02', 'tz82', 't7q1', 't89', 'tq01', 't7g', 'tpc1', 't11', 'tst1', 'tv9', 'tn4', 'tzt1', 'tt82', 'ts71', 't5', 't991', 't4g', 'twq1', 'txp'},
#  id= (177,), tags= {'t911', 'tw11', 'tnj', 'td4', 't2b1', 'thb1', 'tgn1', 'ttd1'},
#  id= (161, 932), tags= {'t7d', 'tp21', 't93', 'tzg', 't412', 't381', 'tfp1', 'td41', 't462', 'txl', 'td82', 't74', 'tf22', 't7p1', 't031', 'tqc2', 'ttc', 't002'},
#  id= (736,), tags= {'t3q1', 'tdn1', 'tdg', 'tnl', 'tqq', 't2t', 'tk1', 'tt21', 'tlk1', 't141', 'tj'},
#  id= (427, 409), tags= {'trl1', 't19', 'tx71', 't6x', 't161', 't55', 'tph1', 'tv1', 'tsw', 't8w', 't342', 't242', 'tq91', 't4m1', 'tdp', 't4t1', 't3r1', 't532', 'tp21'},
#  id= (611,), tags= {'t7d', 'tpn', 't7p1', 'tbj', 't38', 't9q1', 'tlt'},
#  id= (728,), tags= {'tdg', 'tgp1', 'trm', 't412', 't3l', 'tn4', 'tq22', 't622', 'tht1', 'tlh1', 't2x1', 't2', 't5f1', 'th11'},
#  id= (95, 866), tags= {'trn', 'tdp1', 'tqv', 'tkc1', 'tv02', 't561', 'tr02', 'tm7', 't81', 't0c', 'tl31', 'tl6', 't3c1', 'tn3', 'ttm', 'tpp1', 'tpp', 'tqk1', 'tdm1'},
#  id= (925,), tags= {'tp3', 'tkh1', 'tg7', 'tkt1', 'tht1', 'tz22', 'th11', 'tct'},
#  id= (515,), tags= {'tc21', 'tzw', 'tr9', 't3z1', 'tx51', 'tc61'},
#  id= (167,), tags= {'tdk', 't431', 'tmr1', 'tt2', 't792', 'tsb1', 'tcc', 'tmh', 't6d', 'tld1', 'tt'},
#  id= (986,), tags= {'td', 't3q1', 'tgn', 'tdd1', 'tbx1', 'tq9', 'tzs1', 't2k', 't692', 't7p1', 't69'},
#  id= (487, 537), tags= {'tn51', 't8h', 'tq51', 'tql1', 'tqx1', 'tg3', 'tsg', 't9m1', 'thq', 'tpg1', 'tft1', 'tn81', 'tp71', 'tpr1', 't2k', 'tn3', 'tvr', 'trt1', 'tvh'},
#  id= (335, 726), tags= {'t6d2', 'tr5', 't491', 'th1', 't8h', 'tj42', 't5f1', 'tv81', 'tqj1', 'tnj', 't38', 't3p1', 't642', 'thn', 't181', 'tcc', 't532', 'tvh', 'tfb'},
#  id= (784,), tags= {'t74', 'tbm', 'tm81', 'tpt1', 't332'},
#  id= (598, 242), tags= {'t911', 't5c2', 'ths1', 't2g', 'tz42', 'ttb1', 'ttd', 't3b', 'tsj1', 'tw01', 't802', 'ttl', 'tqq', 'tzt1', 't711', 't7g1', 't692', 'tsr1', 'tq81'},
#  id= (85, 12), tags= {'tv61', 't44', 't721', 't0l1', 't3d1', 't3b', 'tt4', 't6t', 'tcl', 'tdg', 'tpb', 'twc2', 't711', 't691', 'txv', 'tt51', 't001', 't232'},
#  id= (328,), tags= {'thv', 'trf1', 'tg62', 't7k1', 't2x1', 'tlz1', 'tdg1', 't131', 't5j1'},
#  id= (560,), tags= {'tj71', 'tkd', 't1w', 'tw11', 'tv22', 't9q1', 't762', 't8b1'},
#  id= (493,), tags= {'tzm1', 'tvc1', 'tsw', 'tr82', 'tq91'},
#  id= (396,), tags= {'tlb1', 'tn81', 't592', 't4t1', 'tn3', 'th8', 't6k1', 'tf42', 't69'},
#  id= (29,), tags= {'ts92', 'th1', 'tdn', 'txf1', 't8f1', 'tgb2', 'tbb2', 'tr21'},
#  id= (759, 297), tags= {'t9x1', 'tb4', 'tn51', 'tj82', 'tsg1', 't81', 'tkf', 't82', 'tkz', 'tdf', 'tnw1', 't762', 'td02', 'twz', 't921', 'thp1', 'tdb2', 't4c2', 'tq81'},
#  id= (608, 452), tags= {'tr5', 'tqp1', 't6d2', 'tm9', 'tvs1', 'tlm1', 'tz2', 'tx41', 'ttb2', 't462', 'tsb2', 't891', 'tpj', 't1m', 'tfr1', 'tzf', 't181', 't0w', 't0r1'},
#  id= (450,), tags= {'tzk1', 't3q1', 'tmn', 'thh1', 'tf22', 'tn12', 'thz', 't0x1', 'tpd', 't181', 't532', 't062'},
#  id= (277,), tags= {'thq1', 't63', 'tdg', 't3g1', 't7h', 'th11', 't8h1', 't3f1', 'tmf', 't452', 't851', 'tm2', 'tf42'},
#  id= (293,), tags= {'tw81', 'tsz', 'tf51', 'tsp', 'tfc2', 'tj91'},
#  id= (36, 973), tags= {'trq', 'tv61', 't261', 'tpb', 'tlg1', 'tm9', 't242', 't471', 't8h1', 'tqz1', 'tpn1', 'tck', 't412', 'twn1', 'tdp1', 'ttw1', 'tvh', 't6z', 'tst'},
#  id= (275,), tags= {'t9d1', 't3m', 'tjs1', 'tzg', 'tjr1', 't242', 'tqq', 'tjt', 'tn9', 'tht1', 'tjj', 'tvr', 't882'},
#  id= (864,), tags= {'tgc', 'tpg1', 't3g1', 'tjs1', 'td92', 't311', 't3t', 'tms1', 'tqx1', 'tp21', 'tnb', 't881'},
#  id= (767,), tags= {'tsx', 'tld1', 'tz81', 't5c2', 't86', 'tzt1'},
#  id= (554,), tags= {'tg7', 't9q1', 'tng1', 'tt21', 't55', 'trx', 'tb71', 't102', 't5t1', 't5z1'},
#  id= (465, 434), tags= {'t7d1', 'tjl1', 't0j1', 'tl92', 'td42', 'tr71', 'tst1', 'tvx1', 'tn81', 'tq8', 'tnf', 't7j1', 'tt', 't6h', 'tzw', 't64', 'tgt1', 'tk61', 't822'},
#  id= (898, 105), tags= {'t4r', 't6w', 'tzl', 'tz02', 't9h', 'tjl', 't7d1', 't41', 'tt9', 't74', 'tnd', 't3m', 'tg62', 't4x', 'tf12', 't882', 'tqb2', 'tb7', 't76'},
#  id= (265,), tags= {'t34', 't5w1', 'tgq', 'ttn1', 'tvk', 'tl6', 'th52', 'tgj1', 'tld1', 't351', 't4c2'},
#  id= (646,), tags= {'tqx', 'tm81', 't551', 't351', 'txf1'},
#  id= (849,), tags= {'t6r', 'tj41', 't372', 'tt82', 't241', 't332', 'tr82', 'tr51'},
#  id= (473,), tags= {'t4d2', 't3q1', 't9c', 'tmj1', 't9z1', 't572', 'tr51', 't232'},
#  id= (600, 204), tags= {'tr5', 't4r', 'tzk1', 'th82', 'tn82', 'tr02', 'tgn', 't291', 'tqz', 'tl72', 'tv32', 'tx51', 'tz52', 'trk', 't6r1', 't991', 'tlj', 't412', 't83'},
#  id= (745,), tags= {'thc', 'tz92', 'tg62', 'thc2', 'td51', 't5p1', 'tvk', 'trk', 'tdz', 'tvb', 'tdd', 'ttm', 'tvb1', 'tpc1'},
#  id= (830,), tags= {'tlr1', 't78', 't011', 'tw11', 't1j1', 'tz9', 'tsv1', 'tw', 't0r', 'ttt', 'tww', 'tx6'},
#  id= (25,), tags= {'tnn', 't1v1', 't661', 'tvf', 'tj91', 'tw', 'tr51', 'tvb1', 't2m', 'tf42'},
#  id= (931,), tags= {'t7d', 'tjx1', 'tf3', 'tqq', 'tz61', 'tnv', 'ttc1', 'tqf'},
#  id= (682,), tags= {'t3k', 'tn81', 'tz9', 't602', 'trs1', 'trr1', 'tqz1', 'td82'},
#  id= (649,), tags= {'th1', 'td32', 't1', 'tq12', 't86'},
#  id= (73,), tags= {'t7d', 't221', 'tz9', 't6x', 't5l', 'tpx', 'tn3', 'tnv', 'tvh'},
#  id= (845,), tags= {'tp2', 'tnj', 't1j1', 'tf71', 't38', 't64', 'twz', 't412', 'tb42', 't69'},
#  id= (633, 410), tags= {'tgz', 'tzk1', 'tdh1', 'tb1', 't772', 'tv92', 't0f1', 't8b1', 't1l1', 'trx', 'tpb2', 'tkf', 'tz9', 't711', 'tn71', 'tcx1', 'twc', 'tfz1', 'tz91'},
#  id= (154,), tags= {'t3h', 'tzz', 'thk1', 't34', 'tn22', 'tcn', 'tjr1', 'txz', 't4q1', 'tj91', 'tpn1', 'ttm', 't912', 'tqf'},
#  id= (651, 227), tags= {'tcf', 't3w', 'tx2', 't861', 't8q', 'tmj1', 't3c', 't412', 'tn81', 'tqb2', 'tc22', 't8p', 'tg41', 'tr42', 'tw3', 'trt1', 't001', 'tnv1', 'tk6'},
#  id= (776,), tags= {'t7d1', 'tmg', 'tgh', 'tv4', 'tpc1', 't2t', 't8f', 'txd'},
#  id= (975,), tags= {'tdg', 't861', 't4g1', 'tt4', 't1n1', 'tm81', 'tm7', 'tst'},
#  id= (340,), tags= {'tv61', 'tsj1', 'tf22', 'twn1', 'tqg1', 't312'},
#  id= (876, 915), tags= {'tsq', 'tv1', 'tn51', 'ttg', 'tk01', 'tfj', 'tqq', 'tdn', 't161', 't711', 'tr6', 'tqz', 'tj3', 't8x1', 't3r1', 'tht1', 't76', 'tp21', 't37', 'tbv1'},
#  id= (467,), tags= {'tt9', 'tdz1', 'tnl', 'tvz1', 't3r1', 'tht1', 'ttf1', 'tx41', 'tn71', 'tcr', 'ttc1', 't001'},
#  id= (967, 841), tags= {'t34', 'th61', 'tlb1', 't901', 't412', 'tg7', 'tx71', 't81', 'tb1', 'ttb1', 'tzt1', 'trk', 'tjt', 't8t1', 't4x1', 'tqs1', 'tww', 'thl', 'tdb2', 't4c2'},
#  id= (886,), tags= {'tj82', 'tcm1', 'tfr1', 't041', 'thg1', 'tdr', 't4x1', 'tb7', 't131'},
#  id= (212,), tags= {'t981', 'tnm', 't2g1', 't381', 't9k', 'tt52', 't8m', 'tf31'},
#  id= (176,), tags= {'t4x', 't6r', 'twg1', 't5w1', 'tcn1', 'tx51'},
#  id= (349,), tags= {'t3v1', 'tv', 'tzm', 'tk81', 'trt', 'th4', 't3c1', 't452', 'tq7', 'tvr', 'twn1', 't1g'},
#  id= (358,), tags= {'t34', 'tc21', 'tgp1', 't561', 'tv12', 'tg72', 'tbd1', 'tm02', 't0s'},
#  id= (979, 861), tags= {'tn51', 'tm9', 'tbh1', 'tbv', 't291', 'tbc2', 'tth', 't3g', 'tc21', 't5w1', 't3b1', 'th42', 't001', 'tq32', 'tn91', 't241', 't3r1', 't4x', 'th11', 't002'},
#  id= (357,), tags= {'t9x1', 'tr41', 't1w1', 'tnz1', 'tsf1', 'th42'},
#  id= (865,), tags= {'tgc', 'tss1', 't242', 't8', 't3d', 'trt', 't181', 't9g', 't49'},
#  id= (360,), tags= {'td', 'thv1', 't63', 't501', 't9c', 'tk2', 'tl2', 't572', 'tnf', 't7c2', 't322', 't001'},
#  id= (539,), tags= {'tb8', 't4d2', 't91', 't33', 'tm91', 'tbx1', 'tpr1', 't291', 't4t1', 'tb7', 'tp5', 'tc51'},
#  id= (420,), tags= {'tcw1', 'tls', 'txk1', 't0l1', 'thg1'},
#  id= (655,), tags= {'tjj1', 'tfz1', 'tq12', 't122', 't7d1', 't0w1'},
#  id= (391,), tags= {'tv32', 't74', 'txg', 'tmh1', 'tdc2', 'thb1', 'tbn1', 't7c2', 'tdg1', 't3g'},
#  id= (558, 339), tags= {'tvc1', 't4d2', 't13', 't1v1', 'tgn', 'tm9', 'tw21', 't2t', 't5f1', 't102', 'thp1', 'tpg1', 't302', 'tjs1', 'tmg', 't61', 't9n1', 't3r1', 'tmf'},
#  id= (213,), tags= {'tjk', 'tpg1', 't8w', 'tcv1', 't1m1', 't6f', 't76', 't8b1'},
#  id= (312,), tags= {'tjj1', 'tqv', 't9q', 'tkr1', 'tnj', 'th42', 't0s'},
#  id= (387,), tags= {'tqp1', 'tdz1', 'th42', 'tlb2', 'tj51', 't482', 'tl3', 't9q1', 't291', 'tt4', 't441', 'trt', 'tf42'},
#  id= (906,), tags= {'t621', 't8k1', 't5m1', 'tt21', 't3c1', 't4d1', 'twz', 'twp', 't232'},
#  id= (870,), tags= {'txq', 't4g1', 'trz', 't4m1', 't76', 't2w', 'tx8', 't701', 'tbp1', 'tqt1'},
#  id= (890,), tags= {'tvc1', 't4r', 'tbh', 't4s1', 'tbb2', 'txj1', 't8l', 'tq91', 'tq31', 'tvr', 'tmq1', 'tzp1', 'tt7', 'tk61'},
#  id= (377,), tags= {'tj8', 'tw52', 't7p1', 'tfz1', 'tbt1', 'tbv1', 'tgb'},
#  id= (950,), tags= {'t9x1', 'tx61', 't74', 'tdn1', 't4v1', 't38', 't1b', 'tc72', 't55', 't5v1', 't631', 't5j1', 'tv52'},
#  id= (586, 461), tags= {'t9x1', 't4d2', 'tzg', 'tbv', 't5v1', 'tsw', 'tjs1', 'tm52', 'tnm', 'tfr1', 'tf21', 'tts1', 't3r1', 'tjp1', 'trs1', 'thn', 'tbb', 't5c2'},
#  id= (79, 814), tags= {'tj6', 'tv', 't12', 'tj91', 'tpd', 'tdd', 't4v', 'tsx', 't822', 't65', 'tqc', 't1w', 'tcv1', 'tz9', 'tqz1', 't8c', 't452', 't912', 'tk82'},
#  id= (38,), tags= {'tb5', 'tjs1', 'tv9', 'tdr', 'tnl', 't7w', 't2t', 't3c1', 'tdb2', 'tf32', 'thp1', 'tdp1', 'tsg'},
#  id= (691,), tags= {'tw11', 't1r1', 'tqs', 't6c2', 'tqk1'},
#  id= (245,), tags= {'t4d2', 'tw5', 'tfh1', 't1v1', 't15', 'twq', 't0f1', 'tw2', 'trr', 't68'},
#  id= (711, 165), tags= {'trc1', 't1w', 't3m', 'tqh1', 't2n', 'tc21', 'tmj1', 'tm5', 'tnj', 'tr1', 't0l1', 'tm61', 'tm7', 'tzs1', 'tl61', 'tv8', 'tlm', 'tq01', 't001'},
#  id= (380,), tags= {'t4l', 't111', 'trc1', 't1v1', 't6g', 't2q', 'thj1'},
#  id= (964,), tags= {'t8j', 't7d1', 't4n1', 't481', 'tj41', 't8w', 'tr82', 't8x', 'tgh1', 'trk', 'tlm', 'tzn', 'ts51'},
#  id= (829,), tags= {'thc', 'tvj', 't221', 'tjr1', 'tn92', 'tr2'},
#  id= (317,), tags= {'t9x1', 'tdv', 'tk5', 'tqk', 'tqk1'},
#  id= (574,), tags= {'tpq1', 'tm42', 'tbs1', 'tz61', 'tww', 'tpc', 'tk71'},
#  id= (479,), tags= {'t3j1', 't3v1', 'tv61', 'tp7', 'tkb2', 'trr', 't512', 't6r1', 't5', 'tfc2', 'tx91', 'tcl'},
#  id= (811,), tags= {'td7', 't4r', 'tlb1', 'thg1', 't682', 'tnk', 't9k1', 'tzd1'},
#  id= (352,), tags= {'tgc', 'td7', 't9x1', 'th1', 't8l', 't3p1', 'tz42', 'ttd', 't3r1', 'tt42'},
#  id= (143, 675), tags= {'td9', 'tkv1', 'thc1', 'tpg1', 't1h1', 't6z1', 'tq81', 't9k', 'tl31', 'tfm', 't2t', 'tzw', 'tvr', 't76', 'trg', 'tpn1', 'tk12', 'tbv1', 't062'},
#  id= (60,), tags= {'tv02', 'tgp1', 'th81', 't241', 'tm2', 'thn', 'tr42', 'tl82', 'ts12'},
#  id= (89,), tags= {'tjn1', 'tb5', 'tsh1', 't7v', 'thr', 'tq91', 't9k', 't0c', 't8f1', 'td52', 'tv11', 'tr42'},
#  id= (668, 327), tags= {'ttk1', 'thc2', 't291', 'tr82', 'trr', 'ttw1', 't39', 't0j1', 'thv', 'tcw1', 'th61', 'tdg', 'tpb', 'tdd1', 't9k', 't9c1', 'tb02', 't001', 'tdm1'},
#  id= (68, 929), tags= {'tln1', 't2m1', 'tb5', 'tkr1', 'tk31', 't291', 'ttt', 't1x1', 'tx1', 'tpn', 'tdg', 'tw62', 't81', 'tkh', 't6t1', 't4d1', 'trm1', 'tqz1', 't991'},
#  id= (221, 615), tags= {'tz21', 't78', 't471', 'tjt', 'tpd', 'tfc2', 't58', 't2', 'tgt', 'tjh', 'thv', 't791', 't81', 'twp1', 't7p1', 't181', 'td62', 't532', 't04'},
#  id= (556,), tags= {'tv32', 't9k', 'tm32', 't462', 'tzn', 'ttb1'},
#  id= (764,), tags= {'tqc', 'tqv', 'tcj1', 'tf52', 'thh1', 'tl31'},
#  id= (109,), tags= {'tw81', 'tf2', 't2s', 't3m', 't242', 'tl2', 'tpr1', 'tq91', 'twb', 't0h1', 'tzn', 'tpn1', 't881', 'tfk1'},
#  id= (597,), tags= {'tpg1', 'tv9', 't0t1', 't5s1', 'tsv1', 'thp', 'tb31', 't64', 'tm7'},
#  id= (951,), tags= {'tqc', 't6d2', 't2m1', 't561', 't8h1', 'trt', 't6t', 'tm02', 't1c1', 't7n1', 'tp6'},
#  id= (638,), tags= {'tb7', 'tr5', 'tr02', 'tr1', 'tf22', 'tq81', 't5j', 'tnf', 'tpk', 'tzb1', 'tp61', 'tlx1', 'tds', 't892'},
#  id= (550,), tags= {'t2m1', 't34', 't13', 'twb2', 'tc21', 'tn51', 't2m', 't3q', 't3c1', 'tfc2', 'tn61', 'tg52', 't0h', 'tzn'},
#  id= (69, 885), tags= {'tlv', 't63', 'tnl', 'ttb1', 'tlz1', 'tk', 'tsd1', 't6t', 't49', 't65', 'ttw1', 't3g', 'tgp1', 't4m1', 'tc02', 't76', 't9j', 'tbv1'},
#  id= (741,), tags= {'t7d', 'thh1', 'th1', 't8b1', 't38', 't0b1'},
#  id= (164,), tags= {'tjq1', 't4x', 'twz', 'tc61', 't21', 'tj22'},
#  id= (181,), tags= {'t31', 'tnw', 'tkr1', 'tdn1', 'trm', 't261', 'tmn', 'ttb1', 'tnn1', 'tdp', 'tz02', 'tz22', 'tbf1'},
#  id= (680,), tags= {'ts92', 't8t1', 't4d2', 'tqx', 'tt', 'tl5', 'tf42'},
#  id= (442,), tags= {'txk1', 't8w', 'tg71', 'txf1', 't87', 't4d1', 'tqn', 'tf21', 't881'},
#  id= (724,), tags= {'tr5', 'tpc', 'tn12', 'tt82', 'tsq1', 'tgv1', 't0z1', 'tpc1'},
#  id= (541,), tags= {'t1r', 't6j', 't672', 'tnl', 'trf', 'tms', 't6h', 't8b', 'tjl', 'tk61', 'tg3', 'tnv1'},
#  id= (593,), tags= {'tqd1', 'tk4', 't641', 't7j1', 'tdg1', 't361', 't6q1', 'tv21'},
#  id= (989,), tags= {'t4m1', 't462', 'tb91', 'tjb2', 'tgt1'},
#  id= (722,), tags= {'td81', 'tlz1', 't031', 'td62', 't002'},
#  id= (663,), tags= {'twr', 'tv', 'tf2', 't1s', 't1v1', 'tvs1', 't4m1', 'tpd', 't76', 't001'},
#  id= (489,), tags= {'tfc2', 'ttc', 'ts42', 'tlp', 'tgx', 'tgd', 't86'},
#  id= (449, 392), tags= {'thw1', 'tp62', 'tj82', 't861', 'thb1', 'tk52', 't382', 'tbm', 'tqh', 'tqg1', 'thd', 't41', 't3p1', 'tql', 'tn4', 'tch', 'tm42', 'tlm', 'tgt1'},
#  id= (899,), tags= {'t4r', 'tkr1', 'tgp1', 'ttg', 'tzg', 'tts1', 'tbm', 'tvr', 't7c2', 't3p', 't2m', 'tvh'},
#  id= (921,), tags= {'t1w', 'th61', 'td31', 'tr02', 'tkf', 'tjj1', 't212', 'tpn1', 't351', 't7n1'},
#  id= (645,), tags= {'ttb', 'tdz1', 'tr02', 'tf72', 't64', 't7w', 'tkt1', 'tdv', 'tvr', 't6h', 'tm81', 't57', 'twp', 'tt11'},
#  id= (604,), tags= {'tf2', 'tz31', 'tb62', 'tt82', 't8n', 't76', 'tkg1', 'twn1', 't7n1'},
#  id= (685, 386), tags= {'tt41', 'td62', 't161', 't6c', 'tc5', 'tp82', 'ts61', 'twj', 'trr', 't252', 'tkc1', 'tjc', 't511', 'txb', 'ts22', 't6h1', 't2m', 'tgt1', 'tdm1'},
#  id= (669,), tags= {'tgc', 't4r', 'tqv', 'tbj', 'tss1', 't7s', 't88', 't752', 't812'},
#  id= (19,), tags= {'td7', 't1c', 't4w', 't7z1', 'tc01', 'tqb1', 'thb1', 'thn', 'tt', 'tdg1', 'tk6', 'tv1', 'tnb2'},
#  id= (948,), tags= {'t071', 'tkc1', 'tgn', 'tsx1', 't1d1'},
#  id= (502,), tags= {'t3v1', 'thc1', 'tlr1', 't78', 't34', 'tb5', 't4n1', 't021', 't38', 'tn3'},
#  id= (468,), tags= {'t5q', 'tpg1', 't4n1', 't1w', 't9j1', 'tbb1', 'tpc', 'tw', 'tc6', 'tn3', 'td41', 'ttx', 'tk62'},
#  id= (955,), tags= {'t0j1', 'tn3', 'thh1', 'tv8', 't012', 't2c1'},
#  id= (919, 147), tags= {'t3c2', 'tk22', 'tcf', 't13', 'twg1', 't6w', 'tj41', 'tmv', 'tg7', 't381', 't871', 'tzt1', 'tw', 'tqz1', 't3b2', 't1q', 'tkb1', 't7n1', 'tnp1'},
#  id= (56,), tags= {'tp12', 'tdg1', 't8t1', 'tsq1'},
#  id= (775,), tags= {'t621', 'tt9', 'tb2', 'tq3', 'th61', 'ts62', 'tsq1', 't6r1', 'tnf', 't4d1', 'tpq1', 'trj', 'tj61'},
#  id= (904, 67), tags= {'t2m1', 'tk31', 'tvs1', 't332', 'tbd1', 'tnf', 'tff1', 't141', 't5r1', 'tjf1', 'tpb2', 'tkc1', 'tlb1', 'tfr1', 'tn02', 't81', 't4g1', 't7h1', 'tsv'},
#  id= (207, 619), tags= {'t9j1', 'tzg', 't471', 'tn12', 'tvs1', 'tlz1', 'tl51', 'tlr1', 'twd1', 'tnm', 't802', 'tcn1', 'tj41', 'tls1', 't511', 'tld1', 't532', 't002', 't6z'},
#  id= (363, 511), tags= {'tj81', 't1v1', 'tfb2', 'tm9', 'tnl', 't5v1', 't7q1', 't9s1', 'td9', 'tx3', 'th61', 't342', 'tqv1', 't9z1', 't3r1', 't4x', 'tt', 't452', 't181'},
#  id= (331, 612), tags= {'ttk1', 'tkr1', 't481', 't011', 'thg1', 't19', 'tv9', 'tmb2', 'tg81', 'tz12', 'tl31', 't6c', 'tgb2', 'tsv', 'twv1', 'tz22', 'trr', 't812', 't3d1'},
#  id= (963,), tags= {'t162', 'tbj', 'tjp', 't6r1', 't9c1', 'tt', 'tx41', 't601', 'tk91', 't412', 't9r1', 'ttc'},
#  id= (192,), tags= {'thk1', 't6c', 't98', 't882', 't02'},
#  id= (190, 661), tags= {'tvc1', 'tsb', 'thr', 't18', 'ttb1', 't3q', 'tl72', 'tql1', 'tsq', 'tct1', 'tmz1', 'tn4', 't6r1', 'tjj1', 'tn71', 't9s', 't5h', 'tdg1', 't532'},
#  id= (258,), tags= {'t33', 't9h', 'tmh', 'tv91', 't231', 't3p'},
#  id= (538,), tags= {'tpw1', 'tzk1', 'tv8', 'tf81', 'tfb1', 'tt11'},
#  id= (970,), tags= {'t3j1', 'tj92', 'tp41', 'tjr1', 'tdd1', 'trz', 'tx71', 'tms', 'tqz', 't7x'},
#  id= (517, 355), tags= {'t861', 'tpw', 't0t1', 't5r', 'tlc1', 't55', 'tt21', 't4t1', 'tfq1', 't6c', 'tms1', 'tm42', 'tx12', 'tz61', 'tlm', 'tnx1', 'ttc', 't2', 't8b1'},
#  id= (378,), tags= {'tv81', 'tpj1', 'tjs1', 't19', 'tgt1', 'ttc2', 'tpc1'},
#  id= (238, 566), tags= {'tb5', 't011', 't501', 't8w', 'ts62', 'th42', 't381', 'tnh', 'tjb1', 'tvf', 'tm3', 't332', 'tpd', 'tdp', 't9r', 't452', 't0f1', 'tm7', 't3g'},
#  id= (545, 443), tags= {'ts92', 't4d2', 'tc21', 'tzl', 'thr', 'tr1', 'tg2', 'tnq1', 'tq91', 'tdg1', 't512', 'thb1', 'th31', 't042', 'tg01', 't2w', 'tl01', 'tt11', 'tw9'},
#  id= (623,), tags= {'tw11', 'thg1', 't021', 't38', 'txf1', 't4k1', 'tqc1', 'tj02', 't452', 't5b1', 'tkl1', 't412', 'tc'},
#  id= (215, 858), tags= {'t78', 'tj82', 'thz', 'tv1', 'ttw1', 'tp6', 'tc2', 'tj41', 'thg1', 'tm52', 'tbj', 'tx72', 'tjb1', 'trk', 'trq1', 'tmf', 't0f1', 'tk82'},
#  id= (851,), tags= {'tnm', 't7v1', 'tf71', 'thz', 't7q1', 'tr82', 'thp1', 'tx1'},
#  id= (180, 721), tags= {'td7', 't4r', 't19', 'ttb1', 't2x1', 'tww', 'twz1', 'thc', 'tv9', 'tt6', 'tcj', 't4', 'tp9', 'th52', 't1l1', 'tb41', 't4p', 't361', 'tzb'},
#  id= (320,), tags= {'tn6', 'tlr1', 't19', 'tss1', 't3k', 't0t1', 'tx71', 'th62', 'tb1', 't161', 'tn01', 'tbc1', 'tdg1'},
#  id= (33,), tags= {'t96', 'tw22', 'tvt', 'tv9', 'tc31'},
#  id= (436,), tags= {'tj41', 't471', 'tf71', 'tjz', 'tv22', 't2d', 't161', 't8h1', 'tk02', 't6z'},
#  id= (506,), tags= {'tn6', 'twg1', 't861', 'tpr1', 'tcb'},
#  id= (786,), tags= {'tv1', 'tv02', 'tm52', 'tx1', 't3c1', 't181', 't5f1', 'tp21', 't2r'},
#  id= (125,), tags= {'t2m1', 'tx', 'th42', 'tx71', 'tfz1', 'tq91', 't2m', 'tdq1', 't692', 'trt', 't8p', 'tx7', 'tc52', 't7n1'},
#  id= (159,), tags= {'t74', 'tc2', 't561', 't3b1', 'tt6', 'tzq1', 'txf1', 't82', 't711', 'tgt1'},
#  id= (197,), tags= {'tv32', 't3m', 't8l1', 't72', 'th1', 'tcv1', 'th81', 'tj3', 'tbm', 'thn', 't5f1', 'tqt', 't5j1', 'tzb'},
#  id= (429,), tags= {'t13', 't011', 'twg1', 'tvb1', 'tbq', 't8t', 'tg52', 't1p', 't0b1', 'tkg1', 'tz4', 't8f'},
#  id= (687,), tags= {'tbj', 't3h1', 'thj1', 't4g1', 'ttq', 'tvb1', 'tr82', 'th91', 'tqh'},
#  id= (254,), tags= {'t31', 't3w', 'tl62', 't6z1', 't63', 'tkf', 'tqq', 'tbf1', 'tqz1', 't2', 'th11', 'tm4', 'tt11'},
#  id= (897, 52), tags= {'tcf', 'tp62', 'tv41', 'tlg1', 'tf71', 't25', 'th8', 'tbc1', 'tz8', 'tzn', 'tsg', 't9s1', 'tv81', 'tpb2', 'tpb', 't3b1', 'tn81', 'tcc', 'tb02'},
#  id= (636, 394), tags= {'tvc1', 't34', 't13', 'tw22', 'tbm1', 'thh1', 't5v1', 'tnf', 'ttw1', 'thv', 'tlw1', 'tfs', 'tv9', 'tl6', 'tgb2', 't692', 'tf12', 't99', 't881'},
#  id= (976,), tags= {'t2z1', 'thl1', 't66', 't2', 'td51', 't6n1'},
#  id= (908,), tags= {'t3w', 'tp62', 'tv32', 't74', 't55', 't7g1', 'tx41', 't68'},
#  id= (754,), tags= {'thc1', 't12', 't75', 't471', 'tbm', 't692', 'tt', 'tzh', 't002'},
#  id= (944,), tags= {'tcq1', 'tz21', 'tcw1', 'trm', 'tmj1', 'tfw', 'tls1', 'tk92', 't952', 'thr1'},
#  id= (87,), tags= {'tqb', 't6d2', 't9d1', 'tlr', 'tj41', 't38', 't3p', 'tx52', 'tm1', 'tht1', 't21', 'tdg1', 'tg71'},
#  id= (131, 977), tags= {'t7d', 't911', 'tkr1', 'tzr', 'td41', 't6t', 'tx82', 'tph', 'tz61', 'tcl', 'tdb2', 't8b1', 'thc', 'tfr1', 'tbj', 'th41', 'tjb1', 'tkq', 't421'},
#  id= (196,), tags= {'t3w', 'tsw', 'tj41', 'tf71', 'tc61', 'tvk', 'tk92', 'tv8', 'txn', 'tfz1', 'tjf', 't1l1', 't6z', 'tt11'},
#  id= (616,), tags= {'ts92', 't7d', 't4n1', 't9c', 'tw12', 't6r1', 'twt', 'ttb2', 'tr42', 't952', 't5p', 'tk6'},
#  id= (219,), tags= {'tck', 't0j1', 't252', 'thh1', 'tnl1', 'trv', 'tt21', 'tc6', 'tbm', 'tvb', 't4h1', 't0f1', 't0b1', 'tw51'},
#  id= (397,), tags= {'t2j1', 't7c2', 't452', 'tn21', 't38', 't5v1'},
#  id= (660, 376), tags= {'t33', 'tn51', 'tzg', 'tfj', 't0m', 'tvb', 't2', 'ts91', 'tsw', 'tc21', 'tfr1', 'tpb', 't8t', 'tdl1', 'tn31', 'tz62', 't691', 't9b', 't351'},
#  id= (2, 833), tags= {'tg11', 'td7', 'tgc1', 'tmj1', 'tbj', 't81', 't201', 'tlm1', 't6r1', 't4t1', 'tfs1', 't7b2', 't5r1', 'tb7', 't4q', 't652', 'tgt1', 't001', 'tb6'},
#  id= (485,), tags= {'t2f1', 'th61', 'tq82', 'tg62', 't6k', 'tcv1', 'tkf', 'thb1', 'tvb', 'tbs1', 't2m', 'twz1'},
#  id= (580, 407), tags= {'t8d1', 'tzk1', 'tn51', 'tm12', 'tb61', 't0t1', 't48', 'tqq', 't59', 't5v1', 'tn4', 't762', 'thb1', 'tt72', 'tcx', 't462', 'txc', 'tww', 'tbz1'},
#  id= (9,), tags= {'tqg', 'td42', 't3x', 'tj82', 't391', 't471', 't762', 'tzw', 'tcc', 'tr42', 'ts12'},
#  id= (733,), tags= {'tm32', 'tc21', 't5q1', 'tn51', 'tjs1', 't701', 't141'},
#  id= (672,), tags= {'tc32', 't3c1', 'th61', 't322', 'tbs', 'trr', 't141'},
#  id= (62,), tags= {'tqb', 'tw52', 'tr5', 'tp32', 'tt', 't5f', 'txh', 't8b1'},
#  id= (757,), tags= {'twz', 'th32', 't2n', 't6l', 'tm91', 't161', 'tj8', 'ttd', 't512', 'trk', 'tvb1', 't7g'},
#  id= (827,), tags= {'tgc', 'thc', 'tcf', 'td62', 'tx01', 'tsq1', 'tg32', 'tmx1'},
#  id= (946, 10), tags= {'tr02', 'tfj', 't55', 'tkp', 'tb82', 'th8', 'ttb2', 't6t', 't141', 'thd', 't2j', 'tft1', 'ts1', 't3r1', 't692', 'ts3', 'tv8', 'tw6', 't582'},
#  id= (98,), tags= {'tz21', 't491', 'tc2', 't1s', 't09', 'th5', 'tvk', 'tkt1', 't8t1', 'trk', 'trb'},
#  id= (406,), tags= {'t4d2', 't33', 't041', 'tdd1', 'tv01', 't462', 'tk6', 'thw', 'tpc1'},
#  id= (495, 382), tags= {'t1v1', 'tnj', 'tr1', 't4r1', 't8l', 'tq91', 't672', 'tt82', 'trk', 'tvk1', 'tsl1', 'tl', 'tqw1', 't0h1', 't462', 't882', 't7c2', 'tg71', 't232'},
#  id= (216,), tags= {'tjx1', 't1w', 'tr1', 'tg7', 't0t1', 'tn4', 't762', 'tv7', 'td41', 't7c2', 'ttm', 'tw51', 'tzv1'},
#  id= (787,), tags= {'tw11', 'tmj1', 'th42', 't0g1', 'trx1', 'tz7', 'tf01', 'tt8'},
#  id= (777,), tags= {'t27', 'tv02', 't9g1', 'tbj', 't5p1', 'ttd', 'tl72', 'tq21', 'tvr', 't58', 'tlm', 'tjl'},
#  id= (132,), tags= {'twg1', 't771', 'tfm1', 't8q', 'ttn', 'tw02'},
#  id= (496, 372), tags= {'tgj', 't4r', 'tgn', 'tv31', 'tz82', 'tj8', 'tbm', 'tfc2', 'tx41', 'tm81', 't0s', 't3k1', 'tcw1', 'tt6', 'tkf', 't3p1', 'tz9', 'tpr1', 't511'},
#  id= (738,), tags= {'tb5', 'tn5', 'tm7', 'tv1', 'trt1', 't6m1'},
#  id= (337, 716), tags= {'tjx1', 't471', 'tpc', 'tv22', 't072', 'thz', 'trv', 'tq62', 't7q1', 't3p', 'tqn1', 'tkf1', 'tx51', 'tjb1', 'tn4', 't4t1', 'tdv', 't991', 'twc'},
#  id= (576,), tags= {'tw52', 't1w', 'tsh1', 't0m1', 'thg1', 'tcn1', 't341', 'tp8', 'tqz1', 'tdv', 'tz01', 'th8', 't8b1'},
#  id= (959,), tags= {'t6w1', 'tsw', 'tv32', 'tzw', 't8n'},
#  id= (978,), tags= {'tpg1', 'thf', 'td62', 't86', 'tbz1', 'tf4', 't031', 'tll1', 'tft'},
#  id= (821,), tags= {'t3j1', 'tp12', 't8l', 'tl31', 'tjj1', 'tpk1', 'tmf', 'tww', 't351'},
#  id= (286,), tags= {'tlb1', 't8w', 'tm9', 'tx1', 'tcv1', 'trt', 't2x1', 'tl72', 'tsj1', 'ttr', 'td62', 'th11', 'ttw1', 'tk6'},
#  id= (739,), tags= {'tpg1', 't4b1', 'tc2', 't1v1', 't7v1', 'tfp', 'twc2', 'tzj1', 'tlw', 't452', 'tsj1', 'tsg', 'ttw1'},
#  id= (860,), tags= {'ts92', 'tqj1', 't13', 't491', 't561', 'tjw1', 't332', 'tjj1', 'tn3', 'tdv1', 'tsm'},
#  id= (535, 455), tags= {'t011', 't1v1', 'tmm1', 'tq72', 'tr1', 'tlg1', 't3l', 't5v1', 'tc5', 't121', 't462', 'txh', 'tc21', 't071', 't1s', 'tds1', 't9c1', 'tm42', 't942'},
#  id= (606,), tags= {'t0g', 'tm7', 'tnq1', 'tt6', 'tb62', 'tb3', 'tgj1', 'ts5', 't622', 'thp1', 't0s', 't8b2', 't6z'},
#  id= (346,), tags= {'tlm', 't7p1', 'tl9', 'tl91', 'tsx1', 'tth1', 'tpc1'},
#  id= (715, 151), tags= {'tdp1', 'tk22', 'thc1', 'tzk1', 't3q1', 't3w', 't302', 'tkc1', 'thx1', 't9k', 'tjw1', 't692', 't602', 'tgj1', 'tx41', 't921', 'tx1', 't7n1', 'tfk1'},
#  id= (110,), tags= {'td7', 't481', 'tfc2', 't7j1', 't021', 'tqm1'},
#  id= (235,), tags= {'tgc', 'ts7', 'tlb1', 't38', 'ttc1', 'tjl'},
#  id= (874,), tags= {'t0g1', 't4r', 'tq52', 't91', 'twz', 'tm81', 'twx1'},
#  id= (626,), tags= {'t512', 'tjq1', 'tjr', 't011', 't6t'},
#  id= (848,), tags= {'t54', 't38', 'tng', 'tcl', 't5s1', 't0f1'},
#  id= (43,), tags= {'td7', 'tzk1', 'tkr1', 'trs1', 't9z1'},
#  id= (771,), tags= {'tfd', 't4d2', 'tw11', 'tks1', 'tn81', 'tx01', 't762', 'trk', 't461', 't9b2', 't0d1', 'tq21', 'tx31', 'ttz1'},
#  id= (746,), tags= {'tm22', 'tpb2', 'tbv1', 'tf7', 'tfr1', 't342', 'tt6', 't3k', 'thz', 't85', 't21', 'tb7', 'tf01'},
#  id= (601, 371), tags= {'tqh1', 't481', 'tdz1', 'tj82', 'th1', 'tsl', 'tcq', 't6w', 'tlg1', 'tqq', 'tbv', 'tms', 'tf71', 'ttz', 't4d1', 't7j1', 'tqr1', 't7n1', 'txg1'},
#  id= (261,), tags= {'tb5', 'tk7', 't6d1', 'tjw1', 'tj91', 'tjc', 'tf12', 't452', 't361'},
#  id= (997,), tags= {'t19', 't311', 't6c', 'thh', 't452', 't3b2', 'tpn1', 't881'},
#  id= (834, 947), tags= {'t3w', 't0k1', 't4n1', 'tpg1', 't9p1', 'tn12', 't9q1', 'tbq1', 'ttb1', 'tvk', 't2t', 't3c1', 't6c', 'tx41', 'trt', 'ttm', 'tl72', 'tlm', 't141', 'tvg'},
#  id= (82, 30), tags= {'tbs', 'tlg1', 't7j', 't762', 't08', 'tr21', 'tz3', 'tqc', 'tpb2', 't8l1', 't221', 'tx01', 't3r1', 't3c1', 'tr12', 'thn', 't1q'},
#  id= (500,), tags= {'tvb1', 'tc8', 'tmb', 'tr2', 'txf1', 'tt21', 't0h1', 'tsj1', 'tk6', 'tt11', 't232'},
#  id= (774, 6), tags= {'tj62', 't951', 't011', 'tgn', 'tpz1', 'tzt1', 'tlb', 't291', 'tr51', 'tgd1', 't9c1', 't9s', 't3p', 't14', 't502', 'tcl', 'td82', 'trx', 't7q'},
#  id= (570,), tags= {'tqc', 't2m1', 'tcf1', 't19', 'tzh1', 'tfb1', 'tkk', 'tm02', 'tr51', 'txh1'},
#  id= (121,), tags= {'td2', 'tq01', 'tpp1', 'th8', 't3b1', 'tr3', 't0f1'},
#  id= (65, 920), tags= {'tp2', 'tzj', 'tpv', 'tdg', 'tr02', 't3b2', 't0t1', 'tm7', 'tsg', 'trv', 'tht1', 'tlw', 'tc5', 'tgg', 'tcl', 'ttt1', 't351', 'tf21', 'tr2'},
#  id= (39,), tags= {'t401', 'th1', 'tvc2', 'tqz', 'trq1', 'tdq', 'tgt1', 'tv1', 't4w1'},
#  id= (480,), tags= {'tqc', 'tf2', 'tc3', 't791', 'td51', 'tkx', 't871', 'tpr1', 'tvb', 'txx', 'trt', 't76', 't7l1'},
#  id= (559,), tags= {'tr5', 'tkp1', 'tv61', 'tk22', 'td32', 'tkf', 't9q1', 'tsb1', 'tf01', 'thn', 't6h', 'trr', 't002'},
#  id= (750, 114), tags= {'td7', 't2h1', 'tbt', 'tq6', 'tz61', 't5f1', 'tdb2', 'tf01', 'trx', 't1j1', 't4m1', 't472', 't511', 'tbk', 'thn', 'ttr', 't412', 'tfj1', 't361'},
#  id= (614,), tags= {'tkj1', 't2m1', 't621', 't6r', 'twg1', 'tdd1', 'trq1', 'tb51', 'ts6', 'tqc2', 'tbz1'},
#  id= (867,), tags= {'tpg1', 't67', 't8l1', 't041', 't221', 't0l1', 't4g1', 't8n', 'tlz1', 'tdg1', 'tld1', 'tz81', 't9s1'},
#  id= (381,), tags= {'twf', 't54', 'tgv', 't38', 't561', 'tz42', 'tss', 't2x1', 't8x1', 'tv8', 'tf9', 'tcl', 'tk61'},
#  id= (170,), tags= {'tl71', 't692', 'tqq1', 'tx82', 't3k', 't342'},
#  id= (939,), tags= {'tsq', 'tdf1', 't621', 't33', 'tvc1', 't771', 'tr02', 't3b1', 't7g1', 't662', 'ttb2', 't5f1', 'tj'},
#  id= (362,), tags= {'tc11', 'td', 't5q1', 'txm1', 'tp92', 'tmb1', 'tnq', 'tf92', 't451'},
#  id= (361,), tags= {'t9x1', 'tw22', 't63', 't9j1', 'tcn1', 'th12', 'tz82', 'tf42', 'tl22', 'tz91'},
#  id= (985, 15), tags= {'td7', 'tz21', 't471', 'tg7', 'txf1', 'tkt1', 'tc5', 'tdp1', 'tm62', 'tzg1', 'tlb1', 't6d1', 'td4', 't82', 't9n1', 't2w1', 't452', 'tjq', 'td91'},
#  id= (201,), tags= {'tqc', 't0c2', 't1w1', 't9c', 'ts81', 'tpc', 'tcp', 'tt82', 't422', 't8x', 't0f1', 'th8', 'td91'},
#  id= (48,), tags= {'td7', 'tk22', 'tt9', 't78', 'tpg1', 'tmd', 't3c1', 'tlm', 'twz', 'tr82', 'tb9'},
#  id= (688,), tags= {'t3x1', 'tk22', 'tt9', 't33', 't3q1', 'tc8', 't9k', 'tvs1', 't3p', 't131', 'tc9'},
#  id= (747,), tags= {'t0j1', 'tc5', 'tl21', 'tpb', 'tcv1', 'tpc'},
#  id= (678,), tags= {'t0j1', 't9c1', 'tb02', 'tcv1', 'tt6', 'tx51'},
#  id= (229,), tags= {'tzm1', 't3m', 'tz72', 'tfj', 'tc7', 't9k', 't3t', 'tqz1', 'tdv'},
#  id= (838, 937), tags= {'t951', 't1n', 'tr02', 'tfr1', 'tr1', 'tc61', 'tt71', 'tz9', 'tlg1', 'tpr1', 'tz61', 'tg72', 'tnf', 'td41', 'tdb2', 'tb02', 'tx1', 'tq81', 't3g', 'tk11'},
#  id= (884, 150), tags= {'t9d1', 'tsp', 'twg1', 't1', 'tpc', 'tz82', 't9', 't59', 't212', 'tm81', 'tq01', 't7g', 't872', 't242', 'tjw1', 'tf12', 'tz11', 'tb02', 'tg71'},
#  id= (348,), tags= {'tqc', 't7d', 't0j1', 'tqp1', 'tmn', 'tdc', 'tbj', 'tv9', 't9h', 't3z', 't1d1', 'tg71'},
#  id= (203,), tags= {'twg1', 'tv9', 't7w', 't332', 'tv7', 'tz61', 't131', 'tgp', 't7n1'},
#  id= (385, 571), tags= {'t9d1', 'tqv', 'tw11', 't981', 't3t1', 'tx71', 't2m', 't9w', 't762', 't151', 't2x1', 'trq1', 't031', 'tcl1', 'tq01', 't131', 'tq81', 't062'},
#  id= (47, 952), tags= {'td', 'tv61', 'tq3', 'tdn1', 'tvd1', 't29', 'tdj', 't8h', 't561', 't6h', 'trx1', 'tzk', 'tqz1', 't76', 'twz', 'tc62', 'tzn', 'tb02', 'ttc'},
#  id= (64, 960), tags= {'td7', 'tk22', 't011', 't391', 't512', 't6d', 't141', 'twj1', 'tf2', 't0m1', 't561', 'tzt1', 'trk', 'tl41', 't4x', 't181', 'tfb1', 'tf21', 't002'},
#  id= (712,), tags= {'t74', 't19', 't1j1', 'tnj', 't84', 'tl31', 't511', 'tx41', 'tm42', 't622', 'th92'},
#  id= (871, 188), tags= {'tqh1', 'tjx1', 't74', 't011', 't19', 'tp72', 'tw1', 'tt6', 'tk31', 'tz41', 't81', 'tl3', 't8h1', 't7q1', 'tq21', 'ts9', 'tdw', 't7n1', 't46'},
#  id= (214, 881), tags= {'tgc', 'ts92', 'tfh', 'tn51', 'tz42', 't8t1', 'twz', 'tsj1', 'tf91', 'tv1', 't41', 'tm52', 'tb62', 't6v1', 'tk1', 't7p1', 'tv8', 'tfb1', 'tk82'},
#  id= (476, 524), tags= {'t9d1', 't911', 'tfl', 'tc61', 't1n1', 'tns', 'tc5', 't2', 't5c', 'tq92', 't5n1', 'tqj1', 't48', 'tt61', 'tn4', 't5p1', 'trq1', 't0f1', 'txh1'},
#  id= (772,), tags= {'tk22', 'tq52', 'tn51', 't8z1', 'tj52', 'tsw1'},
#  id= (930, 903), tags= {'tk22', 't34', 'tw11', 't26', 't802', 'tjr1', 't2q', 'tbq1', 't6x', 'tjj1', 'tqx', 'tj1', 'tzw', 't7j1', 'tcc', 'td41', 'tb02', 'tx41', 't46'},
#  id= (92,), tags= {'tvl1', 'tvs1', 't9k', 't86', 'tqx', 't4d1', 'tl9', 't0f1', 't691', 't4c2', 't9s1', 'tz12'},
#  id= (267,), tags= {'ttk1', 'tlr1', 'tbj', 't2c', 'tq52', 'tz02', 'tv8', 'tsg', 't7d1'},
#  id= (854,), tags= {'t1q', 't1k', 'tnx', 'tf62', 't002', 'tt3'},
#  id= (941, 26), tags= {'t9d1', 'tg82', 'tjr1', 't0c', 't3q', 'tls', 'tv1', 't7d1', 't9x', 'tc21', 'tfr1', 'tzt1', 'tg92', 't0h1', 't3m1', 'tjc', 'tmr', 't2m', 'tz91'},
#  id= (807,), tags= {'thc1', 'tww', 'txg', 'tg6', 'td62', 'tpc', 'tms'},
#  id= (299,), tags= {'thh1', 't0l1', 't55', 't6c', 'tc5', 't0p1', 'tcc', 'tqt', 'twh1'},
#  id= (896,), tags= {'tqc', 'td7', 'tr5', 'tn51', 'tdg', 'tr02', 'tpr1', 'tpx', 't3v', 't4g', 'tv1'},
#  id= (748,), tags= {'t621', 'tbw', 't73', 't8v', 't172'},
#  id= (940, 31), tags= {'tt01', 'tx81', 't6w', 't2g1', 'tvs1', 'tsb2', 'tm7', 't542', 't1c', 'tkc1', 't4c2', 't7q', 't4m1', 't692', 't73', 'tv8', 't882', 't0j', 'tg71'},
#  id= (100,), tags= {'tv', 'tcf', 'tj41', 'txp1', 'tz42', 'tdd1', 'tq91', 'tvk'},
#  id= (902, 88), tags= {'tk22', 'tv61', 't12', 't4d', 't932', 't212', 'trt', 'trj1', 't971', 'tpt1', 't2x', 'tnp1', 't0j1', 'tlr1', 'tst1', 'th42', 't81', 'tqq', 't351'},
#  id= (761,), tags= {'tgc', 't3m', 'th61', 'tmv', 'tmj1', 'txg', 't3p1', 'tg5', 'ttj', 'tjr', 'tds1', 'tz02', 'tfc2', 'tcl'},
#  id= (945, 27), tags= {'tgc', 'thh1', 'tbb1', 'tnl1', 'thr', 'tx71', 'tn12', 'tc41', 'tr82', 'tx1', 'tl51', 'thv', 't1w', 't242', 'tpr1', 't692', 'tf9', 'td62', 't361'},
#  id= (324, 521), tags= {'t621', 'trm', 'tdc1', 'ttz', 't47', 'tq52', 't2t', 'tm51', 't6t', 'tt72', 't1w', 'tg31', 'tpr1', 't4t1', 't4x1', 'tx52', 't961', 't181', 't6'},
#  id= (374,), tags= {'t492', 't3c1', 't8l1', 'tfz1', 't6', 'tm8'},
#  id= (75,), tags= {'t6r1', 'thv', 't0k1', 't6t', 'tr42', 'tqs', 'tg32'},
#  id= (193,), tags= {'tz21', 't8l1', 'tdg', 'tx71', 'tzq1', 'tfb1', 'tb72', 'tpc1'},
#  id= (526,), tags= {'t621', 'tf41', 'tg7', 't9k', 't661', 't8n', 'ttb2', 't64', 'tb9'},
#  id= (987,), tags= {'t102', 'tgn', 'tr02', 'thr', 'tcv1', 'twl', 't8t1', 'tht1', 't4n', 'tj5'},
#  id= (141,), tags= {'t3q', 'tdp', 't9v', 'tdp1', 'txf1'},
#  id= (431,), tags= {'tm42', 't8k', 'tp02', 't622', 'ttb1', 't4p1'},
#  id= (274,), tags= {'tw52', 'tcw1', 'ttw1', 'tr7', 'td22', 'tz61', 'td82', 'ts51'},
#  id= (782, 195), tags= {'tz31', 'tgn', 'tfc', 't092', 't9h', 't0d2', 'tr51', 't5c', 'txc2', 'trn', 't3g', 'tcn1', 'tft1', 't8w1', 't7p1', 't6h1', 'tp5', 't002', 't881'},
#  id= (279,), tags= {'tg11', 't6w', 'tzl', 'tcn1', 'tpd', 'tzw', 'tr51', 'tst', 'tt11'},
#  id= (332,), tags= {'t291', 't4w', 't392', 'ts2', 't8w', 't861', 'tf42'},
#  id= (218, 662), tags= {'tvd', 't8l1', 'tjs1', 'tm02', 't38', 'tg62', 'twv', 't342', 'tr1', 'tcz1', 't6x', 't332', 'tts1', 'tk52', 'tvk', 't8h1', 'tbn1', 'tr82', 'tdp1'},
#  id= (878,), tags= {'t1v1', 't221', 't4m', 'tjr1', 'thr', 't2b1', 'tc82', 'tt', 'tr42', 't532'},
#  id= (404,), tags= {'tgc', 'txk', 'tc11', 'tn51', 't8w', 't1', 'tvs1', 'tnc1', 'tdp', 'tqz', 'tll1', 'th71', 'tc51'},
#  id= (120,), tags= {'tzm1', 't3x1', 'tkc1', 't38', 'tm9', 'tr1', 'tzg', 'tnf', 'trh', 't6k1'},
#  id= (727,), tags= {'tp62', 'tvw1', 'tmp', 'tz9', 'tt82', 'tn4', 'tpd', 'tvp'},
#  id= (692,), tags= {'tq52', 't6k1', 't9f1', 'tbj', 't2q1', 'ttw1', 't232'},
#  id= (111,), tags= {'tqc', 'txz1', 't9w1', 'tg7', 't991', 'tl9', 't3p', 'tcl', 't2m', 'tqk1'},
#  id= (119, 988), tags= {'twg1', 'tn7', 'tc61', 'tvf', 't332', 'tnq', 't6c', 't902', 'tfc2', 'td', 'tmj1', 'tt21', 'tjb', 'tdp', 'ts22', 'txc', 'tf02', 'tvl', 't001'},
#  id= (393,), tags= {'t9d1', 'thc', 'tpb', 'tq52', 'trt', 'tlz1', 'td41', 't2x1', 'tl4', 't3g'},
#  id= (477,), tags= {'thb1', 'tr5', 'tv9', 'trr', 'tjf1'},
#  id= (785,), tags= {'t55', 'tzk1', 't572', 'tz02', 'td71', 't0f1', 'tzr'},
#  id= (347,), tags= {'tvc1', 'tz21', 'tf2', 'tfj', 'tdn', 'th5', 'tv7', 't6t', 'tjq', 'ttc1'},
#  id= (575,), tags= {'tp41', 'tm42', 'tjs1', 'tx71', 't0l1', 'tsg'},
#  id= (399, 670), tags= {'t4d2', 't19', 'tr1', 'tlk', 'thb1', 'ts4', 'thp1', 'tf42', 't7n1', 't0j1', 'thc', 'tlr1', 'tpb2', 'tz9', 't79', 'tcc', 'th8', 'td62', 'tn31'},
#  id= (128, 697), tags= {'t3j1', 't0j1', 'td', 'td82', 'thg1', 'tdk1', 't381', 't2c', 'tz9', 't0c', 't032', 't831', 't3p', 't4d1', 'tqb2', 'thp1', 'tx1', 't9d', 'tf01'},
#  id= (530,), tags= {'tzm1', 'trn', 'tn51', 'tt1', 't1v1', 'tlf1', 't0h1', 't692', 't66', 'tz61', 't6s1'},
#  id= (491,), tags= {'tfd', 't9h', 'tn32', 't6t', 't2', 't88', 'tc81'},
#  id= (398, 471), tags= {'t7d', 'tp41', 't861', 't1t', 't3b', 't8t1', 't2x1', 'tdt', 'tz4', 'tl51', 't5w1', 't3x', 'tl02', 't001', 'tzw', 't6h', 't622', 'trw1', 't3l1'},
#  id= (628, 345), tags= {'tb11', 'tpb1', 'trc1', 'tb5', 'thg', 'tbj', 'tjr1', 'tkf', 't0l1', 't831', 'tj91', 'tc91', 't3q', 'tv7', 'trt', 'tz22', 'tb02', 't2m', 't351'},
#  id= (191, 817), tags= {'t33', 'tzl', 't0l1', 't672', 'tnl', 'tn12', 't332', 'tvk', 'tr42', 't432', 'th42', 'tc81', 't4x1', 't8h1', 't4d1', 'tl9', 't942', 'tl72', 'th11'},
#  id= (926,), tags= {'tgr', 'thc1', 'ttg1', 't391', 't1f1', 't86', 't2k1', 't2t', 'tk6', 'tf11', 't002'},
#  id= (102, 805), tags= {'t002', 't4d2', 't33', 'tf3', 'tss1', 't3k', 't471', 't0l1', 'th42', 'tmj1', 't161', 't9p1', 'tn4', 't8t1', 'tm42', 'td41', 't7n', 'tr91', 't39'},
#  id= (618, 447), tags= {'t2r1', 'tnk1', 'td32', 't682', 't2d2', 'tc61', 'tr42', 't5f1', 't701', 'trh1', 'tgd', 'tmf1', 'tl6', 't4d1', 't452', 'tr81', 't622', 'tvh1', 'tdm1'},
#  id= (587, 249), tags= {'t4r', 'tjx1', 'tvr1', 'ttv', 'thw1', 't9j1', 'tjr1', 'tw71', 't5f1', 'txx1', 'tdp1', 'ttc1', 't091', 'tvc2', 't9z1', 'tx01', 't76', 'th11', 't2b2'},
#  id= (980, 20), tags= {'t6w', 't8q', 'tvs1', 't2x1', 'tj21', 't112', 't5x', 'tcl', 'trh1', 't3g', 'tqc', 'tv32', 'txr', 'tvc2', 't0g1', 'tvr', 'tf', 'tmf', 'tvw'},
#  id= (928, 993), tags= {'t3w', 'tw4', 't6m1', 'tm9', 'tww', 'tpn1', 't571', 't8l1', 't5w1', 'tmj1', 'tf22', 'tjb1', 't9k', 'tht1', 'tkq', 't1q1', 'ts5', 't921', 'tz91', 't6z'},
#  id= (769, 18), tags= {'t1w', 't13', 't271', 'tf7', 'tr82', 'tjb1', 'txf1', 'tc12', 'tkj', 'tsv1', 't332', 'tcb2', 'tgb2', 't572', 'tq7', 'tl21', 't2m', 'tq01', 't5r1'},
#  id= (291, 740), tags= {'tqp1', 't171', 't8l', 'tsv1', 'thb', 'ts42', 't21', 'tw8', 't141', 'tt11', 't1w', 'tvs', 'tdn1', 'tx92', 'tpg1', 'tnj', 'tdb', 't4x1', 't0r'},
#  id= (673, 402), tags= {'t9d1', 't2f', 'tmp1', 'tlg1', 'tzm', 't0c', 'tmg1', 'tz6', 'tgm1', 'tvd', 't3x', 't6r1', 'tdp', 't9c1', 't321', 'tr81', 't532', 't351', 'tqf'},
#  id= (35,), tags= {'t35', 'tm81', 't34', 'td3', 'tm02', 't3b1', 't3k', 't6r1', 'tvr', 't0b1', 'tvv'},
#  id= (400,), tags= {'tzm1', 'tw52', 'tm52', 'tkh1', 'tj91', 'tn4', 'tbw', 'tww', 't6q1'},
#  id= (127,), tags= {'tvq1', 'tw52', 'tgj', 't2m1', 'thh1', 't0b', 'tm9', 't0g1', 'tjj1', 'tg', 'tc92', 'tm1', 't3g', 'tzb'},
#  id= (306, 553), tags= {'t2m1', 't09', 't9p', 'tx71', 't8z', 'tn12', 'tbv', 'tm1', 'tx41', 'tzn', 'tzc1', 'tt82', 'tl6', 't181', 't76', 't52', 'tgt1', 't6z'},
#  id= (198, 622), tags= {'t7d1', 'tpg1', 'thh1', 'thk1', 't63', 'tsr1', 't74', 'tn41', 'tdd1', 'tqq', 't5v1', 'tlm', 'tfc2', 'tx41', 'tm42', 'th8', 'tm81', 't141', 't6z'},
#  id= (463,), tags= {'t3x1', 'tqv', 'tq3', 'tc61', 'tkx', 'tt82', 'tjt', 'tpd', 'tc6', 'tsr1', 'tqh'},
#  id= (319,), tags= {'t33', 'thf', 'ttg1', 'tvf', 'tbx', 't452', 't2', 't6c1'},
#  id= (448,), tags= {'tl6', 'trd1', 't6b1', 'tfc1', 'tn81'},
#  id= (818, 953), tags= {'t3x1', 't0l', 'tv02', 'tnm', 't9c', 'tn81', 'tl8', 't7w', 't4q1', 't762', 'tq52', 't4', 'tdn', 'tvc2', 'tzt1', 'tlj1', 't751', 't0b1', 'trg1', 't6z'},
#  id= (720, 270), tags= {'tqv', 't911', 'tbg', 'tnl1', 't8s1', 't7b', 'ttf', 'tcd1', 'tpb2', 'tz', 't5w1', 'thg1', 't0g1', 'tzw', 't4d1', 'tmf', 't6m', 'tld1', 'tgt1'},
#  id= (512, 344), tags= {'tkr1', 't6w', 't77', 'tm9', 'tg7', 't3q', 't212', 't7q1', 'trr', 'tqh', 't511', 't4x', 'tmf', 'th8', 'ttd1', 'tbr', 't361', 'tm92', 't7t1'},
#  id= (632, 422), tags= {'t3x1', 'td7', 'tn5', 'thr', 'tm9', 't0l1', 'ttx1', 'tw72', 't55', 'tgk1', 'tr82', 'tr72', 't141', 'tw81', 'tjj1', 't1p1', 't691', 'txc1', 't0w1'},
#  id= (152, 744), tags= {'tv', 'thh1', 't011', 'tqm', 'tc61', 'ttb1', 'th31', 'tm7', 'tpx1', 'tdb2', 't8l1', 't7s1', 'tdc2', 'trk', 'tqz1', 't991', 'tm42', 'tld1', 'tz91'},
#  id= (723,), tags= {'tgj', 't6r', 'tpb2', 't4n1', 't1', 'tz82', 'tn12', 'ttf', 't0x', 'tnv', 't622', 'tgt1', 't001', 'tc51'},
#  id= (329,), tags= {'tv32', 't252', 't1j1', 'tkb2', 'tjr1', 'tfj', 't82', 'tdn', 'tx4', 'thf1', 't9w1', 't2', 'tc51'},
#  id= (901, 101), tags= {'tnl', 't55', 'tz02', 't851', 'tst', 't5w1', 'tgp1', 'tnj', 'tjd1', 'tv9', 'tm52', 't4x1', 'twg', 't5k', 't6s', 'tzq', 'tx12', 'tq81'},
#  id= (11,), tags= {'tkn', 'th61', 'tp72', 't0t1', 'tnl', 'tkc2', 't4q1', 'tt', 't991', 'ttx1', 'twn1', 't7n1'},
#  id= (717, 304), tags= {'t4r', 't34', 'tz72', 'tpc', 'tc61', 't291', 'tnf', 't3p', 'tl01', 'ttw1', 'tcw1', 'tdx', 'tg12', 'tt82', 'tl6', 'tn', 'tl21', 'th11', 't1g'},
#  id= (954,), tags= {'trw', 'tm31', 'ttg', 'tg42', 't3b1', 'tx91', 'tcg1', 'tjj1', 't4x1', 't291', 't7p1', 'tnr', 'trz1'},
#  id= (139,), tags= {'t4w', 'tzf1', 'tk9', 'tzt1', 'tht1', 'tl', 't991', 'tfc2', 'tq41', 'tzn', 't6z', 'tv21'},
#  id= (220,), tags= {'trk', 'tfq1', 'tq01', 'td51', 'tvf'},
#  id= (247,), tags= {'tsw', 'tw11', 't5w1', 't331', 'tf71', 'tmd', 't192', 't711', 't2p', 'tm1', 't66', 't9s1', 't7d1'},
#  id= (667,), tags= {'t7x', 'tw11', 't292', 'tqz1', 'tjs1', 'tfr1', 't651'},
#  id= (282,), tags= {'t1h', 'tqz', 'tbj', 'tnh', 'tjw1'},
#  id= (565,), tags= {'tpd1', 't012', 't1', 't1q', 't882', 't5f1', 't7n1', 'tz51'},
#  id= (671,), tags= {'t7d1', 'tvl1', 'thv', 'tn22', 'tmj1', 't7k1', 't711', 't3q', 't3v', 't8f'},
#  id= (990, 129), tags= {'tmn', 't011', 't5x1', 'thg1', 'tzl', 'tgx', 'tft1', 'tdn1', 't2n', 't221', 't342', 't391', 'tts1', 't6l', 'trx1', 't55', 't511', 't3p', 'tdm1'},
#  id= (389,), tags= {'t832', 't5g', 'td32', 'tfc1', 'tl3', 't1s1', 't3r1', 'tmf', 'tqs', 'tt51', 't1g'},
#  id= (338, 474), tags= {'td7', 'tl51', 't78', 't4d2', 'tnj', 't0t1', 'tdd1', 'tqs', 't161', 't0c', 't3q', 't881', 'tdq1', 't3r1', 'tsj', 't9b1', 'tvh', 'tmj', 'tv52'},
#  id= (241,), tags= {'tq92', 'tj31', 'tp31', 'tv32', 't6z1', 't19', 't1j1', 'tm02', 'tfd1', 't9c1', 'tbn1', 'tb02', 'tfz1', 'trr'},
#  id= (305,), tags= {'tsw', 'tzj', 't7v', 'tn4', 'tsq1', 'tf12', 't211', 'tk91', 'tdb2', 'tb12', 'th9'},
#  id= (613,), tags= {'tg8', 't82', 'tz9', 'tn4', 't9k', 't1f', 'tzp', 't7r1', 'tt', 'tq21', 't1g'},
#  id= (112,), tags= {'t911', 'thc1', 'txf', 'tg7', 'ttn', 'tzt1'},
#  id= (86, 873), tags= {'tp32', 'tdr1', 'tn51', 'tdw1', 'tnn1', 't402', 't6c', 't3n1', 'tj41', 't1s', 'tnj', 'tcv1', 'tj4', 'tjb1', 'tdn', 't4q1', 'tzw', 'tj5', 't3j'},
#  id= (710, 321), tags= {'t3w', 'tr92', 't4s1', 'tv9', 'tgz1', 'tc51', 'tn91', 'txz', 't4x1', 'tht1', 'tzw', 'td41', 'trt', 'twz', 't2', 'tfv1', 'tv8', 'tz91', 'tcp1'},
#  id= (961, 991), tags= {'tk22', 'tqp1', 't9j1', 'tmm1', 'tpd', 't7q1', 'tbc2', 'tnf', 't0s', 'td5', 'th01', 'tt9', 'tp7', 'tn4', 'tc6', 't7p1', 't991', 't76', 't622', 'tk82'},
#  id= (13,), tags= {'th61', 'ttx', 'tg62', 'tnf1', 'tb62', 't86', 't0n1', 't5k1', 't622', 'tm7', 'tsr1', 't4t', 'tt11'},
#  id= (659, 413), tags= {'tkr1', 't09', 't7v', 'tzl', 'tjr1', 'tbv', 't161', 't512', 'tpd', 't141', 'thc', 'tsw', 'tj41', 'tls1', 't2p', 't8h1', 'tms1', 'tlm', 't1g'},
#  id= (809,), tags= {'tmp1', 't512', 'trc1', 't1w', 'th61', 'twd', 't732'},
#  id= (287,), tags= {'tgj', 'tz21', 'tws', 'tmn', 'tj82', 'tb62', 'twm1', 'tsv1', 't4x', 'tvm1', 'tm42', 't0s', 'ttn'},
#  id= (599, 388), tags= {'tk6', 'thc1', 'tzg', 'tjr1', 'tg7', 't5w', 'td62', 't651', 'tw', 't55', 'tvb', 'ts4', 't962', 'ttr', 'tn61', 'ttw1', 't2b', 'tt11', 'tqt1'},
#  id= (749, 118), tags= {'tgj', 'tsp', 't721', 'txf1', 't651', 'tjt', 't762', 'tz02', 'tlb', 't21', 't1b2', 'tv1', 't39', 'tnj', 'tmz1', 'tcc', 'tb7', 'tk8', 't2c1'},
#  id= (880,), tags= {'txw', 't3w', 't2m1', 'th61', 'tj41', 'tpb', 'tjr1', 't592', 't2t', 't6h', 'td01', 't4z1'},
#  id= (657, 199), tags= {'tb5', 'tp21', 'tr1', 'th42', 'tx71', 'tn81', 't5v1', 't512', 'tts1', 't55', 'tr52', 'tc82', 'tlv1', 't0f1', 'txq1', 'tf21', 'tq81', 't8b1', 'tj72'},
#  id= (548, 481), tags= {'tr5', 't4d2', 't13', 't7v', 't861', 'tx71', 't7k1', 'tw', 't07', 'tr51', 'tm62', 'tjs1', 'tf02', 't242', 't86', 't511', 'tld1', 'tcs1', 'tgw'},
#  id= (981, 982), tags= {'tqb', 'twf', 't1', 't651', 't3q', 'tpd', 'tz61', 'th91', 'tdb2', 'tpz1', 'tr21', 't9x', 'tt9', 't8l1', 'tcj', 't242', 'tm42', 'tld1', 't412', 'tk61'},
#  id= (158, 956), tags= {'tz21', 'th02', 'tjr1', 't391', 'tw32', 'tvk', 't9h', 't7q1', 'td41', 't21', 'trs', 'tpg', 'tfr1', 'tn71', 'txb', 'tn3', 'tqb2', 't6h1', 't8b'},
#  id= (234, 573), tags= {'tz21', 'td', 't3m', 'tr1', 't471', 'tx9', 'tc72', 't4q1', 'tc6', 't9c1', 't4x', 'tz22', 'tfl1', 'tqb2', 't0d1', 'td41', 'tz4', 't141', 't581'},
#  id= (63,), tags= {'t9d1', 'tkc1', 't0s1', 'tkf', 'tl72', 't4f', 'tn92', 't1l1'},
#  id= (546,), tags= {'tqv', 't051', 'twg1', 'tmd1', 't332', 'tt32', 'tdp', 'tqz', 'tz22', 't6f', 'tm51', 'tww', 'tqr1', 'tjm1'},
#  id= (116, 705), tags= {'t6d2', 'tkm1', 'tcw1', 'tv02', 'twg1', 'tjs1', 'tpb', 't072', 'tmt1', 't86', 'tq91', 't711', 'thb1', 'tgg1', 'tdp', 't76', 't0c1', 't6t', 'tr82'},
#  id= (780,), tags= {'t4x', 't481', 't681', 't7', 'tn3'},
#  id= (935,), tags= {'tk22', 't8j1', 'tvz', 't7v1', 't861', 'tg7', 'tqv1', 'twz', 't141'},
#  id= (253, 581), tags= {'t8c2', 'tkr1', 't8h', 't0b', 't88', 'tbm', 'ttz1', 'ttw1', 't3g', 'tfn1', 'tkm1', 'tv32', 'thc1', 'tfv', 't0t1', 'trv1', 'tt21', 't601', 't8m'},
#  id= (719,), tags= {'t3h', 'tgc2', 'tpc', 'tls1', 't17', 'tgb2', 'tq21', 't2m', 'tt11'},
#  id= (16,), tags= {'td8', 'tvh', 'tf01', 't8b1', 'tr2'},
#  id= (23,), tags= {'tk22', 'tf2', 't74', 't1c', 't1s', 'tg22', 'tzt1', 't402', 'ttm', 't0d2', 't952', 'tt11'},
#  id= (228,), tags= {'tzk1', 'tfc1', 't001', 'tnl', 'tkj', 'th21', 't2x1', 't181', 'tdg1', 'tfz1', 'tzx1', 'tg71'},
#  id= (240,), tags= {'tnw', 'tm41', 't5g', 'tcq', 'tg7', 't0l1', 't511', 't1q'},
#  id= (186,), tags= {'t55', 'ttd', 'tsk', 'tx', 't6k', 'tt81', 'tjp'},
#  id= (50,), tags= {'t31', 'tgn', 't4b2', 't682', 'tr1', 'tl2', 'txf1', 'tbd1', 't6r1', 'trr', 'tr11', 't3g', 'tpc1'},
#  id= (78,), tags= {'t4r', 'th82', 'tj41', 'tlb1', 'tsl', 't8w', 'tpb', 'tmc', 't2z', 'tr41', 't1z1', 'th11', 'tf21', 'tmj'},
#  id= (103,), tags= {'tvt1', 'tcv1', 'td62', 'txf1', 'ttb1', 't55', 'tzs', 'tkt1', 'tj8', 'tq52', 'tl72', 'tmc1'},
#  id= (806, 133), tags= {'tzm1', 'tgz', 't88', 'tsk1', 't332', 't512', 'tlz1', 'trt', 'tdb2', 'tn62', 't771', 't3k', 'tkf', 't452', 'tpl1', 'tb02', 't2q1', 't6', 'tqf'},
#  id= (605,), tags= {'t8j', 't8l1', 'tkw1', 'tj7', 'trk', 'tlz1', 'tz91', 'tzn', 'tq81'},
#  id= (225,), tags= {'tpb', 't38', 't9k', 'tsq1', 'tlm', 'trt', 'tww', 'trr', 'tsw1'},
#  id= (123, 763), tags= {'tzm1', 't9d1', 'thc', 'tfx', 't5q', 'tdc1', 'tgm', 't29', 't342', 't6z1', 'tx2', 't501', 'thg1', 'td51', 'tt21', 't7p1', 'tb02', 't7n1', 'tvj1'},
#  id= (0, 115), tags= {'tjx1', 'txm', 'tg6', 'tvh', 't8b1', 'tw52', 'thc1', 't8g1', 't8l1', 'twd1', 'tjb1', 't17', 'tmz1', 't1l', 'tgb2', 't5b1', 't7c2', 't361'},
#  id= (483,), tags= {'t3m', 'tc2', 't4c2', 't4q1', 't7q1', 'tq01', 'tpn1', 't141', 'tm11'},
#  id= (582, 290), tags= {'tk22', 'tqv', 'tdr1', 'tp62', 'tm81', 'tjr1', 'tl42', 'tvc2', 't311', 't8t1', 't511', 'tjj', 'tq21', 't991', 't112', 'tfb1', 'tpn1', 't0q', 't881'},
#  id= (466, 617), tags= {'ttk1', 'ts92', 'tpc', 't7w', 't2t', 't2x1', 't7q1', 'tfc2', 'tbd', 't141', 'tqc', 't0j1', 'tlw1', 't561', 't86', 't0h1', 'tn71', 't7p1', 'tdg1'},
#  id= (22,), tags= {'tb4', 'tnh1', 'tdn1', 'tq3', 'th61', 't471', 'tsq1', 't402', 'tz02', 'tp82', 'tb02', 'tr42', 'tv71', 'thr1'},
#  id= (927, 144), tags= {'t8j', 'tk22', 'tvq1', 't5d1', 'tb21', 't802', 't1', 't1x', 't0b2', 'tcv', 't9q1', 't512', 'tjt', 'tz02', 't061', 'tfz1', 'th91', 'twt1', 't8b1'},
#  id= (353, 459), tags= {'tw52', 't612', 'td', 'tzk1', 'tdg', 'tp3', 't3k', 'ttb1', 't192', 'tl31', 't64', 'tqw', 'tbn1', 't7m1', 't66', 'tb7', 'tlj', 'tbz1', 'tt22'},
#  id= (59, 794), tags= {'thc1', 'tzk1', 'tt41', 'tvc', 'ttx1', 'tfj', 'tb62', 'tls1', 'tn4', 't5m1', 't9c1', 'th51', 'tqb2', 'tb7', 'td62', 'tpp', 'tc1', 't7d1', 'tk6'},
#  id= (706,), tags= {'tn51', 'tr02', 'tr1', 't7f', 't8w1', 't312', 'twk1', 't181', 't452', 't622', 'tpx1', 'tk82', 'trx'},
#  id= (900,), tags= {'tvx', 'tsp', 'tw91', 'tw61', 'tks1', 'tkj', 'tjt', 'tdp', 't7k', 't852', 't5r1'},
#  id= (57, 80), tags= {'t63', 'twg1', 'tx71', 'tvn1', 't2t', 'th6', 'tww', 'tjl', 'tcl', 't7d1', 'tb11', 'tw81', 'tm72', 'tx51', 'tn81', 't9k', 't76', 'tfb1'},
#  id= (831,), tags= {'t4w', 'td32', 'tzl', 't7k1', 'tpr', 'tgt1', 'tqz1', 'tb7', 'tm81', 'trr'},
#  id= (584,), tags= {'t5c1', 'tp41', 't1', 't3p1', 't161', 't8t1', 't692', 't8h1', 't532', 't0w1'},
#  id= (792,), tags= {'tb8', 'td', 'th42', 'tpp', 'tx72', 'tpr', 'tvf', 't202', 'tlz1', 't6c', 'tgn1', 'ttc1'},
#  id= (971,), tags= {'t7d', 'trt', 'ttb2', 't921', 'td62'},
#  id= (729,), tags= {'tpb2', 'tpb', 'tnq1', 't242', 't032', 't0g1', 'tdp', 't8z1', 'th7', 'tb7', 't031', 't2c2'},
#  id= (185, 840), tags= {'t0c2', 't33', 'tlk', 'tnl', 't6x', 'tbd', 'ttc1', 'tdb2', 'tsq', 'tgp1', 'tdd1', 'tv62', 'tl6', 't8h1', 'tvm', 't4d1', 'thn', 't972', 't361'},
#  id= (648,), tags= {'tdp1', 't911', 'td', 't481', 'tbh', 't011', 't8h', 't1', 'tkp', 'tq52', 't6r1', 'th11'},
#  id= (677,), tags= {'t8j', 'tpm1', 'tp42', 't0l1', 'tnl', 'ttb1', 'tfz1', 't81', 'tc61', 't9q1', 'tb81', 'tqf'},
# ...
#  id= (390, 562), tags= {'tvc1', 'tck', 'twf', 't5g', 'tgn', 'th', 't9m', 'tqp', 't82', 'tvf', 'tpc', 'tl6', 'ttb2', 't7c2', 'tz01', 't181', 't272', 'tml1', 'trx'},
#  id= (484, 544), tags= {'tf61', 't7v', 't471', 'tm9', 'td41', 'tz61', 'tww', 't272', 'tj41', 'twd1', 'tcv1', 'txg', 't81', 't5z', 'tjj1', 'tfb1', 'tkv', 't4z1', 'tg71'},
#  id= (296,), tags= {'t3j1', 'tkr1', 't7z', 'tkb2', 'tfr1', 'tw41', 'tg42', 'thr', 'tgb2', 'tn71', 'tlz1', 't8c1'},
#  id= (555,), tags= {'tw81', 'tbw1', 't0p', 'tjt1', 't7p1', 'tpq1', 'ttl1', 'tb7', 'tr42', 'tf42', 'tk61', 'thr1', 't0t'},
#  id= (126, 737), tags= {'tr5', 't911', 'tn51', 'tdg', 'tnm1', 'tx01', 't711', 'tsq1', 't1h', 't8t1', 't212', 't622', 't7j1', 't0p1', 'ttb2', 'tr42', 'tnb2', 'tbz1', 'tqh'},
#  id= (514,), tags= {'t11', 'tf2', 'trm', 'tft1', 't86', 't4d1', 't8b1', 'tv21'},
#  id= (179,), tags= {'tzp1', 'tjs1', 'tq81', 't9k', 'tms', 'tjx', 'tvv1', 'tlm', 'tx41', 'tl72', 'tm7', 'tr51', 't002', 'tpq'},
#  id= (54, 837), tags= {'t14', 'tr02', 't9t1', 'tjt', 't8k', 'tf01', 't7n1', 't8p1', 'tw11', 'tjs1', 't5g1', 't3k', 'tv9', 'tzt1', 'tc81', 't4t1', 't3c1', 'tjc', 'tq11'},
#  id= (37, 93), tags= {'t271', 't6z1', 'tmq', 't9h', 't7q1', 't58', 't0s', 'tf42', 't3g', 'tpc1', 'tc2', 'ts7', 't221', 'tq32', 't86', 'tjj1', 't532', 'tff'},
#  id= (97, 796), tags= {'t9d1', 't78', 't4n1', 'tm9', 't6x', 'tz02', 'tv3', 'thp1', 't74', 't221', 't3k', 'tg62', 't7r1', 'tbn1', 'tdg1', 'tdm', 't4t', 'tm11', 't97'},
#  id= (292,), tags= {'t3x1', 't911', 'tcv1', 't81', 'tpt', 't202', 'tkp', 'tt21', 'tkn1', 't882', 'tp1'},
#  id= (184,), tags= {'t5f1', 'tp62', 'tzw', 'ts5', 'tbs', 'tnl', 'trn1'},
#  id= (163, 689), tags= {'t3h', 't3r', 'tp62', 't4n1', 'twd1', 'tr02', 'tm52', 't0c1', 'tt82', 't762', 'tsb1', 't4x1', 'tv7', 't392', 'txb2', 'tz61', 't1l1', 't2h', 'tfj1'},
#  id= (314,), tags= {'t2m1', 'tv81', 'tm', 't011', 'th1', 'tx62', 'tn42', 'tb32', 'tvk', 't7p1', 'ttb2', 'tjl', 'tz91', 'tr2'},
#  id= (844,), tags= {'tkc1', 'txk1', 't161', 't651', 't5v', 'tc82', 't4r1', 't031', 'tm7', 't5l1'},
#  id= (194,), tags= {'tz02', 'ttf1', 'tx41', 'tl72', 't07'},
#  id= (732,), tags= {'t5f1', 'tvq', 'txr1', 't2', 'tn81', 't5v1', 'twp1', 'tkq', 't92', 'tm71', 't361', 't7n1', 't002', 't4p1'},
#  id= (666, 368), tags= {'tr5', 'trw', 't33', 't1', 't8n', 'tzx', 'tj8', 't6c', 'tdb2', 'tmx', 'ttw1', 'tqh', 'thc1', 'tdd1', 'tj4', 'tf21', 't4s', 't5p', 'tm01'},
#  id= (478, 426), tags= {'tdn1', 'tdg', 't012', 't5g1', 't75', 't0t1', 'tl8', 'tvs1', 't032', 'twf1', 't762', 'tdq1', 'tpm', 't442', 't7b2', 'tqb2', 'tp01', 'ttw1', 't002'},
#  id= (74,), tags= {'tv', 'thc1', 'tj41', 'ths1', 'tpn1', 'tqh'},
#  id= (269, 765), tags= {'tb5', 'tr9', 't19', 't5s', 'tq52', 'tr22', 't3p', 'tpn1', 't8b1', 'tpb2', 't38', 'tdd1', 'ttj', 't9z1', 't4x', 't4d1', 'tr81', 't1q', 't232'},
#  id= (895,), tags= {'t35', 't212', 'ts8', 't6z1', 'tmj1', 't0l1', 'tn12'},
#  id= (644,), tags= {'tsc1', 'tz21', 't221', 'tbv', 'tvs1', 't9z1', 't762', 'tcc', 't6f', 'tx7', 'thp1', 'tf01'},
#  id= (564, 289), tags= {'tzm1', 't4r', 't88', 'tw21', 'tlz1', 'tlm', 'tcg', 't462', 't222', 'ts21', 't0f1', 'tk6', 'ttg1', 'tg12', 't82', 'tn81', 'tts1', 'tt61', 't031'},
#  id= (914,), tags= {'tsw', 'tgf1', 't971', 'tv72', 'tn81', 'tc51'},
#  id= (656,), tags= {'tq61', 'td6', 't33', 'tzw1', 'tcv1', 'tt32', 'tr51', 't39'},
#  id= (883, 153), tags= {'tp32', 'tj82', 'tr02', 'tvs1', 't161', 't7q1', 'tx41', 't462', 'ttz1', 'tqh', 'trl', 'tbl1', 't3p1', 't9k', 'tdj1', 't4x', 'tb7', 't1l1', 't881'},
#  id= (217,), tags= {'t5f1', 'tsb', 't2m1', 't13', 'tdn1', 'tt31', 't47', 'td92', 'tp91', 't1l', 'tm1', 'tqz1', 'tr42', 'tqf'},
#  id= (140,), tags= {'tr5', 't9d1', 't2r1', 't1s', 'tm52', 'tfw', 'tkt1', 't991'},
#  id= (423,), tags= {'t4r', 't33', 'th1', 't851', 'thp1', 't7j1', 'tl9', 't882', 'tb7', 'tmf', 't991', 'tdb2'},
#  id= (578, 262), tags= {'t9d1', 'tj82', 't1v1', 'tgn', 'thr', 'tf71', 'tc72', 'ts01', 't0f1', 't39', 'tc2', 'tn4', 't711', 'tn71', 'tz22', 't3c1', 't66', 'tl72', 'tf21'},
#  id= (918, 156), tags= {'tk22', 'tkv1', 'thh1', 'tgn', 'tm9', 't1j', 't7j', 'txf1', 't6x', 't311', 't5b2', 'tdp', 't692', 'tzw', 'tsd1', 't64', 'th11', 'trz1', 'tpc1'},
#  id= (58, 40), tags= {'td32', 'tsp1', 'tbv', 't84', 'tq62', 'tq52', 'tv7', 'tlz1', 't6x1', 'tcl1', 't0s', 'ts21', 'tx1', 'tr51', 'tfx', 'tdn1', 't6h', 'tsf'},
#  id= (171, 664), tags= {'td7', 'tgj', 't7d1', 'tr5', 'tf2', 'tdn1', 'tdg', 't561', 'tm52', 'tcv1', 'tkf', 't8l', 'td62', 't5v1', 'tk52', 'tqs', 'tb9', 't7p', 'tg71'},
#  id= (803,), tags= {'tqc', 'tqv', 't4d2', 't302', 'tj82', 'tjn1', 'th42', 'tg62', 't711', 'thb1', 't4x1', 'tb02'},
#  id= (819,), tags= {'t2x1', 't4h', 'tj82', 'tl9', 't9c', 't81', 't0r1'},
#  id= (892, 91), tags= {'t621', 'thh1', 't381', 'tn12', 't8l', 'tbv', 'tjt', 'tlz1', 'tnt', 't6t', 'tm7', 'tqh', 'tw11', 'tdn1', 't0g', 'tcn1', 't6r1', 'tx52', 'tgt1'},
#  id= (839,), tags= {'t9x1', 'tc11', 'thc1', 'tkc1', 't1s', 't3c1', 'tm32', 'tq01'},
#  id= (226, 609), tags= {'tjx1', 'tsc2', 't9j1', 't221', 'tzg', 't0t1', 't381', 't672', 'tmr1', 't2m', 't4x1', 't4x', 't8t1', 'tf01', 't462', 'tlm', 'tjl', 'tbz1', 't7p'},
#  id= (595, 244), tags= {'t3x1', 't6d2', 't2m1', 't4b1', 'tlb1', 't221', 'tmd', 'tkf', 'tn12', 'thp1', 'tb32', 'tm1', 'tzw', 'tx41', 'tb51', 'twz', 'tl9', 't081', 'txs1'},
#  id= (142,), tags= {'tvc1', 'thv', 'tc11', 'tnt1', 'tt4', 'trk1', 'tzh', 'tk82', 't0w1'},
#  id= (501, 373), tags= {'trn', 'tqp1', 'tq3', 'ttt1', 'tbr1', 'tlc1', 'tkf', 't6n', 't9n1', 't3r1', 't8h1', 'trq1', 'tl9', 'tmz', 'th8', 'tq01', 't0w1', 'td82', 'tc71'},
#  id= (520,), tags= {'t522', 't0h1', 't5t', 't8l1', 'tld1', 'tnj', 't3g'},
#  id= (922,), tags= {'t3w', 'thh1', 'tnj', 'tpb', 't242', 'tsm1', 'tlz1', 't7p1', 'tf91'},
#  id= (351,), tags= {'t1w', 'tnz1', 't9h', 'tk21', 'tzn', 't862'},
#  id= (42,), tags= {'thc', 'tp7', 't2f', 't88', 'tj9'},
#  id= (852,), tags= {'tkc1', 't6z1', 'tkx', 't2d', 't0c', 't76', 'tr42', 't532', 'tdp1'},
#  id= (753, 146), tags= {'t7d', 'tb5', 't13', 'tv81', 'tbb1', 't8h', 'tlc1', 't0t1', 'tj9', 't8l', 'ttb1', 'tj91', 't711', 'tt21', 't3r1', 'tt', 't1p1', 'tvl', 'tr2'},
#  id= (783, 108), tags= {'tjx1', 'tg6', 'tjg1', 't0m', 't6c', 'ttm', 'tkb1', 't74', 't4g1', 't6n1', 'tms', 'tt82', 't922', 'twp1', 't4d1', 'thn', 'tz62', 'tl72', 'tjm1'},
#  id= (523, 341), tags= {'t9d1', 't7d', 't4w', 't532', 'tsp1', 'tzr', 'ttb1', 'ts01', 'tnx1', 'thp1', 'tn52', 'thm', 'tzt', 't9l1', 'tbh', 't9k', 'tt82', 'tdl1', 't811'},
#  id= (281,), tags= {'tgp1', 'tq91', 't9n', 't5p1', 't651', 't5v1', 'tt21', 'tzr', 'tq7', 't181', 'tdg1', 't532'},
#  id= (375, 437), tags= {'t8j', 'tk22', 't33', 'tdj', 'twz', 'txf1', 'tzt1', 't332', 't2t', 't4m1', 'tqb2', 'tkx1', 'trp1', 't3t', 't0f1', 'ttl1', 'tqf', 'ttc2', 'tn72'},
#  id= (647,), tags= {'t3q1', 't9q', 'tk6', 'tt72', 'tt11', 't881'},
#  id= (462,), tags= {'tsq', 't1n', 'tx71', 'td92', 't762', 'tvk', 'tx41', 't0b1', 't532', 'tl1', 'tdm1'},
#  id= (343, 703), tags= {'tgc', 't6d2', 'tw91', 't19', 't9p', 't8l', 't2t', 't2x1', 'tmg1', 't462', 't5f1', 'tw51', 't832', 'tcv1', 'tr4', 't5h1', 't692', 't0j', 't6z'},
#  id= (540,), tags= {'t7p1', 't3s1', 'tq01', 'txg', 'tln', 'tbf1', 'twc2'},
#  id= (3,), tags= {'tqp1', 'twd1', 'tg02', 'tl3', 'tms', 't0c', 'tqz1', 't21', 't351', 't8b1'},
#  id= (295, 735), tags= {'tv02', 't9j1', 'tc61', 't7k1', 't5v1', 't2t', 't572', 'tsg', 'tkw', 'twm', 'tpb2', 'tjs1', 'tdd1', 'tdn', 'tn4', 't4x', 't4d1', 'tbz1', 't582'},
#  id= (718,), tags= {'tr5', 't0j1', 'tgp1', 'ttz', 'tqq', 'tbc', 'thx', 't4d1', 'tq2', 'tt11'},
#  id= (793, 137), tags= {'tv02', 'twg1', 'tlg1', 'ttq1', 't8l', 'thz', 't3q', 'tfc2', 'tnf', 'ts61', 'tdp1', 't7n1', 'tlr1', 'tpb2', 't192', 'trk', 'tb41', 'tx12', 't1g'},
#  id= (334,), tags= {'thn', 'twg1', 'tzg', 'tbv', 'tpr1', 't001'},
#  id= (913,), tags= {'tgq1', 'tb7', 'tnc2', 't3k', 'tr1', 'ts02', 't161', 'tpc2', 'tn61', 'tb02', 'tww', 'tqs', 'txv1'},
#  id= (223, 653), tags= {'t33', 'tl32', 'tj41', 'tgp1', 't8n1', 'tj9', 'tz82', 'trr', 't562', 'tht1', 'tpx', 'ts22', 't9l', 'ths', 't49', 'tcc2', 't361', 't6z'},
#  id= (591,), tags= {'t5w1', 'txm', 'tn12', 'tl61', 'tjc', 'tlm', 'ttz1', 'tzn'},
#  id= (725,), tags= {'tr5', 'th1', 't861', 'tfj', 'tr32', 't7j', 't0g1', 'tb', 't921', 'th6', 'th8', 'tg21', 't361', 'tt3'},
#  id= (992,), tags= {'tt01', 'tqp1', 'thc', 'tpb2', 'tp41', 'tqv1', 'tpc', 'tpr1', 'tfc2', 'tqs', 'tk82'},
#  id= (527, 522), tags= {'t6d2', 'trc1', 'tlc', 't1', 'tfj', 't7l', 'tbw', 't841', 'tzn', 't39', 'tt11', 'tf52', 'ttl', 'tx51', 'tmf', 't321', 'ttc', 'tq81', 'tfb'},
#  id= (160, 695), tags= {'t7d1', 'tt9', 't1w', 'tpg1', 'tm6', 'tbm1', 't1v1', 'tjs1', 'tmj1', 't19', 't381', 't5v1', 'td41', 't982', 'tp82', 'ttz1', 't412', 'tq01', 't8b1'},
#  id= (869,), tags= {'t311', 'tmt', 'tcc2', 'trm', 'tz61', 'tz82', 't8b1'},
#  id= (713,), tags= {'tcj1', 't8h1', 't76', 't9p', 'tp21', 'tg12', 't8n'},
#  id= (284,), tags= {'t3w', 'tvz', 'ts31', 't5s1', 't88', 'tbv', 'ts6', 'tsj1', 't3g'},
#  id= (966,), tags= {'tkx1', 'tfh', 't511', 'tpk1', 'tvr', 't0c'},
#  id= (276,), tags= {'t55', 'th01', 'thc', 'trp', 't771'},
#  id= (257, 770), tags= {'tk42', 't63', 'tk31', 't8l', 'tlq', 'tvf', 'tkt1', 'tz02', 't6t', 'tw8', 'tv1', 'tpc1', 'tsq', 't3k', 't3c', 't242', 'tl72', 'tz91', 't881'},
#  id= (812,), tags= {'tt9', 't011', 'tpb', 'tbv', 't931', 'tt21', 'tdp', 'tvr', 'tq21', 'tf01'},
#  id= (828, 99), tags= {'t2m1', 't13', 't0m', 'tfn', 'tf42', 'td82', 'tn2', 'td', 't082', 'twb2', 't1s', 't221', 'tjb1', 'tx01', 't711', 'tt21', 't3r1', 't982', 't622'},
#  id= (446,), tags= {'t33', 'tb5', 't0c', 'th5', 'thb1', 'tk', 'tk6', 'tbb2'},
#  id= (924,), tags= {'tb5', 'tsw', 'tp41', 'txg', 'tdc2', 'trv', 'tcb1', 't0c', 'tt21', 'tlj', 't361', 't39', 'tt11'},
#  id= (577, 414), tags= {'tvc1', 'tf2', 'tsw', 'tv32', 'tr62', 'tdt1', 'tgp1', 't232', 'td61', 'tbv', 'tt82', 't2x1', 'tvr', 'tz61', 't2m', 'tcl', 'tws1', 't591', 'tr2'},
#  id= (731, 236), tags= {'tgn', 't8n', 't161', 't8t1', 'tsh', 't7q1', 'tfg1', 'tv1', 't862', 'thc', 'twb2', 'tsw', 'tk3', 'trb2', 't82', 'td81', 't452', 'tqb2', 'tws1'},
#  id= (298,), tags= {'thb1', 'thc1', 'tt', 'ttm', 't901', 'tzb1', 't0t1'},
#  id= (76, 879), tags= {'t2m1', 'tc21', 'tmn', 'thr', 'tqv1', 't391', 'tg51', 't86', 'tn81', 'tsq1', 'ts11', 't4x1', 'tqx', 'tf12', 'trt', 't462', 'td22', 'tfz1', 't3g'},
#  id= (637, 383), tags= {'tjq1', 'tqv', 't5b', 'tj82', 'tq51', 'thr', 'tbv', 't762', 'tx41', 't2', 'th61', 't5w1', 't221', 'tnm', 't3b1', 'txg', 't6r1', 't9t', 't2m'},
#  id= (175, 846), tags= {'tvc1', 't011', 'tr02', 'tsv1', 'tz5', 't7q1', 't142', 'tph', 't5f1', 'th42', 't8t', 'tvc2', 't5p1', 'tl6', 't8g', 'tvm1', 'tz22', 'th8', 'tbv1'},
#  id= (700, 256), tags= {'tqv', 'tdz1', 't672', 'tx4', 't3t', 'tx1', 't5r1', 't7d1', 't832', 't3m', 'ttp', 't36', 'tq91', 'ttm1', 'tpc2', 't362', 'thj', 't361', 't05'},
#  id= (445, 408), tags= {'t6d2', 't0b', 'tlg1', 't2g', 't2t', 'tvv1', 'tz71', 'tr22', 't74', 't4c2', 'tf41', 'tmj1', 't38', 'tzt1', 't6r1', 'tn', 'tk6', 'twn1', 't131'},
#  id= (957, 872), tags= {'trn', 'td7', 'ts91', 't4n1', 't6r', 'tsp', 't221', 'thg1', 'tkc1', 'tpr1', 't332', 'tj8', 't0h1', 'tbm', 'tlp1', 't1l1', 'thp1', 'tll1', 'tst', 't3g'},
#  id= (497,), tags= {'tgc', 't9d1', 'tc21', 'tdz1', 'tc2', 't19', 'tnm', 'tzg', 'tt71', 'tqw1', 'tqz1', 'trq1', 't6z', 't2r'},
#  id= (822,), tags= {'tk51', 't8h1', 'tpb2', 'tt4', 'tsz1', 'tcw', 'tg9'},
#  id= (699, 162), tags= {'tgj', 'th82', 'tsp', 'tq3', 'tmc2', 'tx71', 'tkm', 'ttb2', 'td41', 'tzn', 'tr82', 'tcl', 'tdp1', 'tt72', 'tq1', 'tbf', 't4x', 't532', 'th11'},
#  id= (923,), tags= {'tqc', 'tv', 'tz21', 'tc11', 'tp22', 'tsw', 'tf22', 'tzg', 'tb52', 'tl72', 't462', 'tzn'},
#  id= (288, 528), tags= {'tv', 'tcf', 'tpb2', 't2s1', 'thr', 'tg62', 'tb62', 't0c', 'tcb', 'tr61', 'tt21', 'tnd1', 'tbm', 't291', 't8h1', 'tn1', 'tvr', 'th8', 'tf01'},
#  id= (316,), tags= {'tnd1', 't2t', 't4c1', 'tpd', 'tdn1', 'tbv'},
#  id= (45,), tags= {'tgc', 'tqb2', 'thg1', 'tzc2', 't0t1', 'tfj', 'tls1'},
#  id= (634, 438), tags= {'tkr1', 'tf71', 't0l1', 'tnl', 't1m1', 'tgk1', 'tr82', 'tcl', 'tdp1', 't9s1', 'tv32', 't22', 'tt21', 'tn3', 'tlg', 'tmf', 'tb7', 'tk32', 't2n1'},
#  id= (607, 454), tags= {'tkr1', 'tr02', 'tvk', 'tg72', 'tq01', 'tf01', 'thk1', 'tpb2', 'thg1', 'tg4', 't342', 'tb62', 'tts1', 'tjc', 'tz22', 't961', 'tpp1', 't131', 'tvh'},
#  id= (271, 643), tags= {'tzm1', 'tqv', 't74', 't2v', 't1w', 't1s', 'tp52', 'txq', 'tl6', 't5v', 't2t', 't4x', 'tm1', 'tsn1', 'tld1', 'tfz1', 'tl4', 'ttw1', 'tz91'},
#  id= (440,), tags= {'tc11', 'tgc2', 'tpc', 'tl3', 't562', 't8r1', 'tns', 'tk6'},
#  id= (999, 8), tags= {'t3j1', 'tr5', 't911', 't1', 'tm9', 'tpc', 'tc61', 'tcd', 't3t', 't4q', 'tk6', 'tl51', 't561', 'tdd1', 'tz9', 'tqx', 't76', 't031', 'tlf'},
#  id= (268,), tags= {'t81', 'tzn', 't342', 't0l1', 'tx01'},
#  id= (652,), tags= {'t311', 'tn3', 'tn51', 'tvr', 't771', 'tt11', 'tcz'},
#  id= (354,), tags= {'tq42', 't291', 'twj', 'thn', 'tqq', 't7l1'},
#  id= (766,), tags= {'tts1', 'tm81', 'tt31', 'ths', 'tq91'},
#  id= (842,), tags= {'tz1', 'tfm', 't7p1', 'tn8', 't101', 'txf1', 'tz9'},
#  id= (815,), tags= {'t771', 'tkf', 'trk', 'tn71', 'tht1', 'tm42', 't2', 'tlm', 't4k'},
#  id= (71, 760), tags= {'tgc', 't002', 'thn1', 'tnb1', 'tkc1', 'tsr', 'tfr1', 't3p1', 'tqx', 't3t', 'tbm', 'tdv', 'tmf', 't712', 'th8', 'tww', 'tpn1', 'tgt1', 't001'},
#  id= (498, 494), tags= {'tn51', 'tzg', 'tc61', 't7k1', 'ttd', 'tq52', 't212', 't3p', 'twz', 'tlh', 'tqc', 'tv32', 'tv81', 'thb2', 't4g1', 't9w', 'tl6', 'tdp', 't881'},
#  id= (428, 525), tags= {'tk22', 'ttk1', 'tb5', 'ts92', 'tzd', 'tgp1', 't1', 't55', 'tjj1', 't801', 'tc5', 't1v', 't2c1', 'ttb2', 'txx1', 't4f', 't351', 'tst', 't8b1'},
#  id= (996, 835), tags= {'tb5', 'tmn', 'tw11', 't1s', 'tgp1', 'tfz1', 'thk', 'thb1', 'tlb', 'txw1', 'tf12', 'ttb2', 'tx82', 't351', 'trg1', 'tv1', 't9d', 'tft', 't8b1', 't0w1'},
#  id= (503, 365), tags= {'th01', 'trw', 't1w', 'tm02', 'th41', 'tz61', 'tn81', 'tq22', 'tt92', 't8t1', 't3t', 'tbd1', 'td41', 't882', 't9t', 't181', 'tqr1', 'tkl', 't351'},
#  id= (222,), tags= {'tf2', 'tdc', 'trm', 't032', 'tbt', 'tvb', 't902', 't8b1'},
#  id= (933,), tags= {'tw11', 't7v', 't3p', 'tkz1', 'tng', 'tgt1', 'tq81', 't0w1'},
#  id= (557,), tags= {'tgr1', 'thc1', 'tz21', 't4w', 't2s1', 'tn7', 'tmd1', 't5m1', 't4t1', 'tcc', 'td41', 'tmz', 'tm02', 'tdb2'},
#  id= (709, 330), tags= {'t7d', 't621', 'tw11', 't091', 't861', 'th42', 't391', 't242', 'tks', 'tl6', 'tqx', 'tbm', 't1b1', 'tst', 'tf82', 'tsr1', 'td01', 'tjv1', 'tk82'},
#  id= (294,), tags= {'tsc2', 'tjs1', 't6w', 'tk71', 'txf1', 't55', 't4t1', 'tj12', 'twr1', 'tnz', 'tf91', 'tpf', 't6c2', 'tdh'},
#  id= (507,), tags= {'td32', 'tgx', 'tcn1', 'tzg', 'trk', 't4x1', 'tt4', 't2d1', 'tbn1', 'tz22', 'tph'},
#  id= (135,), tags= {'tv51', 'trq1', 'tgs1', 'tcq1', 'tvh'},
#  id= (113,), tags= {'tsq', 't9d1', 't8h', 't9j1', 'tc61', 'tb62', 't8n', 'tsv1', 'ttd', 'tl6', 'tl', 'tld', 't691', 'tq81'},
#  id= (486,), tags= {'t782', 't051', 't3k', 'tx72', 'tqk1', 'tdb1', 'thr'},
#  id= (419, 620), tags= {'tgc', 'tk22', 'tcf', 't78', 't34', 'tr5', 't1', 't3s', 'ttb1', 'tbd1', 'tsb2', 't492', 'thv', 'tvd1', 't4t1', 't801', 'tf12', 'tmf', 'trg1'},
#  id= (868, 72), tags= {'tsb', 't34', 'tj82', 'tg7', 't531', 'tx71', 't332', 'tq8', 't651', 't71', 'tpn1', 'tnb2', 'thk1', 'tn41', 'tc4', 'th42', 'tj1', 't6q', 'tt12'},
#  id= (77,), tags= {'t512', 'tr51', 't3n', 't76', 'tr92', 'tdb2', 'tz42'},
#  id= (542, 513), tags= {'tzk1', 'tx22', 'tn12', 't5v', 'tlz1', 't462', 't2', 'tzn', 'tr42', 'thp1', 'thk1', 't5w1', 'twd1', 'tfr1', 'tjb1', 't032', 'tjc', 't882', 'tdm1'},
#  id= (266, 534), tags= {'t8j', 'tjx1', 'tv32', 'tl71', 'tb5', 'tmj1', 'thd1', 't81', 'tfj', 'tmw', 'tps', 'tn71', 't4d1', 'twz1', 'tr42', 'trr', 'tst', 't1b2', 'tpq'},
#  id= (5,), tags= {'t071', 't771', 't3b1', 't332', 't51', 'tn3', 'tbn1', 't882', 't822', 'ttc1', 'tfg1', 't7d1'},
#  id= (859,), tags= {'tq52', 'tlz1', 'ttb2', 'tr82', 't312'},
#  id= (590, 252), tags= {'t4r', 'tf2', 't4d2', 'tn51', 'tz21', 't2s1', 't1p1', 't412', 'tk31', 'tqs', 't711', 'tw', 'tjt', 't94', 't7b1', 'tw8', 'tld1', 't611', 't912'}]

# %%
sh = SlideShow(a, None)

# %%
write_Slideshow_to_file(sh, "output_c.txt")

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("b_lovely_landscapes.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals

# %%
b_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-23-b75d635abc2c> in <module>()
# ----> 1 b_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200)
#
# <ipython-input-13-d6fbcc2763c8> in geneticAlgorithm(population, popSize, eliteSize, mutationRate, generations)
#       1 def geneticAlgorithm(population, popSize, eliteSize, mutationRate, generations):
#       2     pop = initialPopulation(popSize, population)
# ----> 3     print("Initial distance: " + str(1 / rankRoutes(pop)[0][1]))
#       4
#       5     for i in range(0, generations):
#
# <ipython-input-5-6f9bb3becd19> in rankRoutes(population)
#       2     fitnessResults = {}
#       3     for i in range(0,len(population)):
# ----> 4         fitnessResults[i] = Fitness(population[i]).routeFitness()
#       5     return sorted(fitnessResults.items(), key = operator.itemgetter(1), reverse = True)
#
# <ipython-input-2-cdf36b3043a7> in routeFitness(self)
#      21     def routeFitness(self):
#      22         if self.fitness == 0:
# ---> 23             self.fitness = 1 / float(self.routeDistance())
#      24         return self.fitness
#
# ZeroDivisionError: float division by zero

# %%
sh_b = SlideShow(b_file, None)
write_Slideshow_to_file(sh_b, "output_b.txt")

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("d_pet_pictures.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals
d_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200)

# %%
sh_d = SlideShow(d_file, None)
write_Slideshow_to_file(sh_d, "output_d.txt")

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("e_shiny_selfies.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals
e_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200) 
sh_e = SlideShow(e_file, None)
write_Slideshow_to_file(sh_e, "output_e.txt")

# %%
Photo.id_counter = 0

# %%
import input_output as io
photos = io.read("a_example.txt")
slides_fromVerticals, slides_fromHorizontals = get_horizontals_from_collection(photos, groupby="average")
slides = slides_fromVerticals + slides_fromHorizontals
a_file = geneticAlgorithm(population=slides, popSize=100, eliteSize=20, mutationRate=0.01, generations=200) 
sh_a = SlideShow(a_file, None)
write_Slideshow_to_file(sh_a, "output_a.txt")
